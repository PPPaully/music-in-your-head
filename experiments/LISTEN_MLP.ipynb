# %%
import mne
import librosa
import numpy as np
import pandas as pd
import torch as th
import torch.nn as nn
from time import time

from torchinfo import summary

# from https://github.com/Po-Hsun-Su/pytorch-ssim
import pytorch_ssim as ssim

import matplotlib.pyplot as plt
import librosa.display
from ipywidgets import IntProgress
from IPython.display import display, Audio

# %% [markdown]
# # Music Data

# %%
musics = np.load('omiir_music.npy', allow_pickle=True).item()

# %% [markdown]
# ## Preparation - Resampling, STFT, etc.

# %%
def prepare_downsampling(target_sr, stft=False, stft_window=256):
    for version in musics.keys():
        for mid, music in musics[version].items():
            wav = (music['wav'] - music['wav'].mean())/music['wav'].std()
            music['wav-low'] = librosa.resample(wav, orig_sr=music['rate'], target_sr=target_sr)
            music['rate-low'] = target_sr
            music['sample-low'] = music['wav-low'].shape[0]
            music['onset-low'] = np.round(music['onset']/music['rate']*music['rate-low']).astype(int)
            music['onset_woc-low'] = np.round(music['onset_woc']/music['rate']*music['rate-low']).astype(int)
            music['beat-low'] = np.round(music['beat']/music['rate']*music['rate-low']).astype(int)
            music['beat_woc-low'] = np.round(music['beat_woc']/music['rate']*music['rate-low']).astype(int)
            
            if stft:
                music['stft-low'] = librosa.stft(music['wav-low'], hop_length=stft_window, win_length=stft_window)

            music['audio'] = Audio(data=wav, rate=music['rate'])
            music['audio-low'] = Audio(data=librosa.resample(music['wav-low'], orig_sr=target_sr, target_sr=music['rate']), rate=music['rate'])

# %% [markdown]
# # EEG Data

# %%
data_eeg = mne.io.read_raw_fif('omiir_all_preprocessed.fif', preload=True)
EEG_RATE = data_eeg.info['sfreq']
data_eeg
# Out:
# Opening raw data file omiir_all_preprocessed.fif...
#     Range : 0 ... 1287637 =      0.000 ... 20119.328 secs
# C:\Users\Paul\AppData\Local\Temp\ipykernel_137336\1980649454.py:1: RuntimeWarning: This filename (omiir_all_preprocessed.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data_eeg = mne.io.read_raw_fif('omiir_all_preprocessed.fif', preload=True)
# Ready.
# Reading 0 ... 1287637  =      0.000 ... 20119.328 secs...
# <Raw | omiir_all_preprocessed.fif, 70 x 1287638 (20119.3 s), ~687.8 MB, data loaded>

# %% [markdown]
# ## Preprocess - Standardization + Trim

# %%
data_eeg_raw = data_eeg.get_data('eeg')

print(f"Size in memory: {data_eeg_raw.size * data_eeg_raw.itemsize / 1e6:.2f} mb")

subids_idx = data_eeg.get_data('SUBID').reshape(-1).astype(int)
subids = sorted(set(subids_idx))

z_cutoff = 2
start_idx = 0
for subid in subids:
    end_idx = np.searchsorted(subids_idx, subid, side='right')
    mean = data_eeg_raw[:, start_idx:end_idx].mean(axis=1)
    std = data_eeg_raw[:, start_idx:end_idx].std(axis=1)
    t = data_eeg_raw[:, start_idx:end_idx].transpose()
    standardized = ((t - mean)/std).transpose()
    
    data_eeg_raw[:, start_idx:end_idx] = np.clip(standardized, a_min=-z_cutoff, a_max=z_cutoff)/z_cutoff  # Clip + Scale to -1>1
# Out:
# Size in memory: 659.27 mb

# %% [markdown]
# ## Events

# %%
def sep_event_id(eid):
    '''
        return: music-id(str), trial_type(int), version(str)
    '''
    return f'{int(str(eid)[:-2]):02d}', int(str(eid)[-2]), f'v{str(eid)[-1]}'

# %%
data_events = mne.find_events(data_eeg, initial_event=True)
data_events_info = np.hstack([
    data_events[:, 0].reshape(-1, 1),  # start
    np.concatenate([data_events[1:, 0], [data_eeg.last_samp - 1]]).reshape(-1, 1), # end
    np.asarray([sep_event_id(eid) for eid in data_events[:, 2]], dtype='object'),  # music-id, trial_type, version
    data_eeg.get_data('SUBID')[0, data_events[:, 0]].astype(int).reshape(-1, 1)  # subid
])
# Out:
# 1620 events found
# Event IDs: [ 111  112  121  122  131  132  211  212  221  222  231  232  311  312
#   321  322  331  332  411  412  421  422  431  432 1111 1112 1121 1122
#  1131 1132 1211 1212 1221 1222 1231 1232 1311 1312 1321 1322 1331 1332
#  1411 1412 1421 1422 1431 1432 2111 2112 2121 2122 2131 2132 2211 2212
#  2221 2222 2231 2232 2311 2312 2321 2322 2331 2332 2411 2412 2421 2422
#  2431 2432]

# %% [markdown]
# # Dataset Selection

# %%
idx_EEG_START, idx_EEG_STOP, idx_MID, idx_TRIAL, idx_VERSION, idx_SUBID = 0, 1, 2, 3, 4, 5
TRIAL = dict(
    LISTEN=1,
    IMAGE=2,
    IMAGE_WOC=3,
)

# %%
def events_iter(batch_size, filter_trial_type=None, filter_subject_ids=None, custom_filter=None, shuffle=False):
    # Filter
    events_filter = np.ones(data_events_info.shape[0]).astype(bool)
    if filter_trial_type is not None:
        events_filter &= data_events_info[:, idx_TRIAL] == filter_trial_type
    if filter_subject_ids is not None:
        events_filter &= np.isin(data_events_info[:, idx_SUBID], filter_subject_ids)
    if custom_filter is not None:
        events_filter &= custom_filter
    
    events_idx = np.argwhere(events_filter).reshape(-1)
    
    # Shuffle
    if shuffle:
        np.random.shuffle(events_idx)
    
    # Return
    res = []
    for i in range(0, events_idx.shape[0], batch_size):
        j = min(events_idx.shape[0], i+batch_size)
        res.append(events_idx[i: j])
    return res

# %%
def array_iter(arr, shuffle=False, extend=None):
    indices = np.arange(arr.shape[0])
    if shuffle:
        np.random.shuffle(indices)
    
    res = []
    for idx in indices:
        res.append(arr[idx])
    
    if extend is not None:
        length = len(indices)
        for idx in range(extend-length):
            res.append(arr[indices[idx % length]])
    
    return res

# %%
def padding(arr, window_length, axis=0):
    if arr.shape[axis] < window_length:
        return np.pad(arr, [(0, window_length-d) if i == axis else (0, 0) for i, d in enumerate(arr.shape)], constant_values=(0))
    return arr

# %%
def make_iteration(indices, window_length, testing_mode=False, shuffle=True):
    io_indices = []
    music_data = []
    for eeg_start, eeg_stop, mid, _, version, _ in data_events_info[indices]:
        music = musics[version][mid]
        music_data.append(music['wav-low'])
        music_window_length = window_length/EEG_RATE*music['rate-low']
        if not music_window_length.is_integer():
            print(f'Warning: music_window_length is not integer ({music_window_length}), will be floored to {int(music_window_length)}')
        music_window_length = int(music_window_length)

        eeg_indices = [
            np.arange(eeg_start, eeg_stop, window_length),  # EEG-start
            np.concatenate([np.arange(eeg_start + window_length, eeg_stop, window_length), [eeg_stop]]) # EEG-stop
        ]
        
        cutoff = eeg_indices[0].shape[0]  # Bug: music fraction after eeg end.
        music_indices = [
            np.arange(0, music['sample-low'], music_window_length)[:cutoff],  # Music-start
            np.concatenate([np.arange(music_window_length, music['sample-low'], music_window_length), [(music['sample-low'])]])[:cutoff]  # Music-stop
        ]
        start_stop = np.stack(eeg_indices + music_indices, axis=1)
        io_indices.append(start_stop)

    max_iter = max(map(lambda x: len(x), io_indices))
    io_list = [array_iter(io, shuffle=shuffle, extend=None if testing_mode else max_iter) for io in io_indices]
    
    return max_iter, io_list, music_data

# %%
def training_iter(indices, window_length, shuffle=True):
    max_iter, io_list, music_data = make_iteration(indices, window_length, shuffle=shuffle)

    batch_data = []
    for it in range(max_iter):
        batch_input = []
        batch_output = []
        for io, wav in zip(io_list, music_data):
            sample_start, sample_stop, music_start, music_stop = io[it]
            batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
            batch_output.append(padding(wav[music_start: music_stop], window_length=music_window_length))
        batch_data.append((np.stack(batch_input), np.stack(batch_output)))
    return batch_data

# %%
def testing_iter(indices, window_length, shuffle=False):
    _, io_list, music_data = make_iteration(indices, window_length, testing_mode=True, shuffle=shuffle)
    
    batch_data = []
    for io, wav in zip(io_list, music_data):
        batch_input = []
        batch_output = []
        for sample_start, sample_stop, music_start, music_stop in io:
            batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
            batch_output.append(padding(wav[music_start: music_stop], window_length=music_window_length))
        batch_data.append((np.stack(batch_input), np.stack(batch_output)))
        
    return batch_data

# %% [markdown]
# ## Train-Test Split

# %% [markdown]
# ```
# Training Set - SUB[MID(------), (------),        ]
# Testing Set -  SUB[                   NEW(------)]
#            NEW-SUB[(------),            ,(------)]
# ```

# %% [markdown]
# SUBJECT v1 {1, 4, 6, 7} v2 {9, 11, 12, 13, 14}

# %% [markdown]
# | ID | Name                                | Meter | Length | Tempo   | Train/Test | Note |
# |----|-------------------------------------|-------|--------|---------|------------|------|
# |  1 | Chim Chim Cheree (lyrics)           |   3/4 |  13.3s | 212 BPM | Mixed      |
# |  2 | TakeMe Out to the Ballgame (lyrics) |   3/4 |   7.7s | 189 BPM | Mixed      |
# |  3 | Jingle Bells (lyrics)               |   4/4 |   9.7s | 200 BPM | Mixed      | Train/Test: Training Subject/Testing Only Subject (v1 == v2)
# |  4 | Mary Had a Little Lamb (lyrics)     |   4/4 |  11.6s | 160 BPM |  Test Only | (v1 == v2) > Unknown Song Experiment
# | 11 | Chim Chim Cheree                    |   3/4 |  13.5s | 212 BPM | Mixed      | No lyrics
# | 12 | TakeMe Out to the Ballgame          |   3/4 |   7.7s | 189 BPM | Mixed      | No lyrics
# | 13 | Jingle Bells                        |   4/4 |   9.0s | 200 BPM | Mixed      | Nixing - No lyrics (v1 == v2)
# | 14 | Mary Had a Little Lamb              |   4/4 |  12.2s | 160 BPM |  Test Only | Piano -  No lyrics (v1 == v2) > Unknown Song Experiment
# | 21 | EmperorWaltz                        |   3/4 |   8.3s | 178 BPM | Mixed      | Orchestra
# | 22 | Hedwig’s Theme (Harry Potter)       |   3/4 |  16.0s | 166 BPM | Mixed      | "Celesta" > Instrument Experiment
# | 23 | ImperialMarch (StarWars Theme)      |   4/4 |   9.2s | 104 BPM | Mixed      | "Trombone" > Instrument Experiment
# | 24 | Eine Kleine Nachtmusik              |   4/4 |   6.9s | 140 BPM | Mixed      | "Violin" > Instrument Experiment
# |    |                                mean |       |  10.4s | 176 BPM |

# %%
TRAIN_IDS = [
    ('02', 1),
    ('03', 1),
    ('12', 1),
    ('13', 1),
    ('21', 1),
    ('23', 1),
    ('24', 1),
    
    ('01', 4),
    ('03', 4),
    ('11', 4),
    ('13', 4),
    ('21', 4),
    ('22', 4),
    ('24', 4),
    
    ('01', 6),
    ('02', 6),
    ('11', 6),
    ('12', 6),
    ('21', 6),
    ('22', 6),
    ('23', 6),
    
    ('02', 7),
    ('03', 7),
    ('12', 7),
    ('13', 7),
    ('22', 7),
    ('23', 7),
    ('24', 7),
    
]

# %%
VALID_IDS = [
    ('01', 1),
    ('11', 1),
    ('22', 1),
    
    ('02', 4),
    ('12', 4),
    ('23', 4),
    
    ('03', 6),
    ('13', 6),
    ('24', 6), 
    
    ('01', 7),
    ('11', 7),
    ('21', 7),
]

# %%
TEST_NEW_SUB = [
    # New Subject (SUBID=9)
    ('01', 9),
    ('02', 9),
    ('03', 9),
    ('11', 9),
    ('12', 9),
    ('13', 9),
    ('21', 9),
    ('22', 9),
    ('23', 9),
    
    # New Subject (SUBID=11)
    ('01', 11),
    ('02', 11),
    ('03', 11),
    ('11', 11),
    ('12', 11),
    ('13', 11),
    ('21', 11),
    ('22', 11),
    ('23', 11),
]

TEST_NEW_MUSIC = [
    # New Music '04' '14'
    ('04', 1),
    ('04', 4),
    ('04', 6),
    ('04', 9),
    ('04', 11),
    
    ('14', 1),
    ('14', 4),
    ('14', 6),
    ('14', 9),
    ('14', 11),
]

TEST_INSTRUMENT_CELESTA = [
    # Celesta
    ('22', 9),
    ('22', 11),
]
TEST_INSTRUMENT_TROMBONE = [
    # Trombone
    ('23', 9),
    ('23', 11),
]
TEST_INSTRUMENT_VIOLIN = [
    # Violin
    ('24', 9),
    ('24', 11),
]

# %%
train_custom_filter = list(map(lambda x: tuple(x) in TRAIN_IDS, data_events_info[:, [idx_MID, idx_SUBID]]))
valid_custom_filter = list(map(lambda x: tuple(x) in VALID_IDS, data_events_info[:, [idx_MID, idx_SUBID]]))

experiments_list = [TEST_NEW_SUB, TEST_NEW_MUSIC, TEST_INSTRUMENT_CELESTA, TEST_INSTRUMENT_TROMBONE, TEST_INSTRUMENT_VIOLIN]
ID_TEST_NEW_SUB    = 0
ID_TEST_NEW_MUSIC  = 1
ID_TEST_INSTRUMENT_CELESTA  = 2
ID_TEST_INSTRUMENT_TROMBONE = 3
ID_TEST_INSTRUMENT_VIOLIN   = 4

test_filter_list = [list(map(lambda x: tuple(x) in exp, data_events_info[:, [idx_MID, idx_SUBID]])) for exp in experiments_list]
# These filter will be merged with filter_trial_type

# %% [markdown]
# ## Debug

# %%
# batch_size = 16
# window_length = 32
# trial_type = TRIAL['LISTEN']
# sub_ids = [1]
# seed = 42
# np.random.seed(seed)

# from collections import Counter
# Counter(data_events_info[(data_events_info[:, idx_TRIAL] == 1) & np.isin(data_events_info[:, idx_SUBID], [1])][:, idx_MID])

# %%
# total_time = 0
# last = time()
# progress = IntProgress(min=0, max=296, style={'description_width': '250px'})
# progress.description = '0/296'
# display(progress)

# epoch = 0
# for indices in events_iter(batch_size=batch_size, filter_trial_type=trial_type, filter_subject_ids=sub_ids, shuffle=True):
#     for batch_input, batch_output in training_iter(indices, window_length=window_length):
#         now = time()
#         epoch += 1
#         total_time += now - last
#         last = now
#         progress.value = epoch
#         if epoch % 10 == 0:
#             progress.description = f'total: {total_time:.2f}, avg: {total_time/epoch*1000:.2f} ms, {epoch}/296'
# progress.description = f'total: {total_time:.2f} secs, avg: {total_time/epoch*1000:.2f} ms, Done'

# %% [markdown]
# # Model

# %% [markdown]
# ## MLP (WAV)

# %%
class MLPModel(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        
        self.linears = nn.Sequential(
            nn.Linear(input_size, 2 ** 10),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 10),
            nn.Linear(2 ** 10, 2 ** 9),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 9),
            nn.Linear(2 ** 9, 2 ** 8),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 8),
            nn.Linear(2 ** 8, output_size),
            nn.Tanh(),
        )
        
    def forward(self, X):
        return self.linears(X)
    
    @staticmethod
    def transform_input(X):
        # batch_input = (batch_size, number_channel, window_length)
        # target (batch, input)
        return X.reshape(X.shape[0], -1)

# %% [markdown]
# ## BiLSTM (WAV)

# %%
# class LSTMModel(nn.Module):
#     def __init__(self, input_size, feature_size, num_layer, hidden_size, output_size):
#         super().__init__()
        
#         self.linears = nn.Sequential(
#             nn.Linear(input_size, feature_size),
#             nn.Tanh(),
#         )
        
#         self.lstm = nn.LSTM(
#             input_size=feature_size,
#             hidden_size=hidden_size,
#             num_layers=num_layer,
#             bidirectional=True,
#             batch_first=True
#         )
#         self.tanh = nn.Tanh()
        
#         self.mlp = nn.Sequential(
#             nn.Linear(hidden_size*2, hidden_size),
#             nn.Tanh(),
#             nn.Linear(hidden_size, hidden_size//2),
#             nn.Tanh(),
#             nn.Linear(hidden_size//2, output_size),
#         )
    
#     def forward(self, X, state=None):
#         out_1 = self.linears(X)
#         state = None
#         out_2 = []
#         for inp in out_1:
#             out, (hn, cn) = self.lstm(inp, state)
#             out_2.append(out)
#         out_2 = self.tanh(th.stack(out_2))
        
#         out_3 = self.mlp(out_2).flatten(start_dim=1)
        
#         return out_3, (hn, cn)
    
#     @staticmethod
#     def transform_input(X):
#         # batch_input = (batch_size, number_channel, window_length)
#         # target (batch, length, input)
#         return X.transpose(0, 2, 1)

# %% [markdown]
# # Configure

# %%
# Music Data
music_rate = 64
enable_stft = False
stft_window = None

# Data
trial_type = 'LISTEN' # 'IMAGE' 'IMAGE_WOC'
filter_trial_type = TRIAL[trial_type]
sub_ids = None

# Model
batch_size = 16
number_channel = 64
window_length = 32
feature_size = 256
hidden_size = 256
num_layer = 4

# Train/Test
num_iteration = 200

# State
seed = 42
np.random.seed(seed)



# DO NOT CHANGE
prepare_downsampling(target_sr=music_rate, stft=enable_stft, stft_window=stft_window)
music_window_length = window_length/EEG_RATE*music_rate
if not music_window_length.is_integer():
    raise Exception('Configure Error: music_window_length must be integer')
music_window_length = int(music_window_length)

output_size = 1

# %% [markdown]
# # Initialize

# %%
device = th.device('cuda' if th.cuda.is_available() else 'cpu')

# %%
# net = LSTMModel(
#     input_size=number_channel,
#     feature_size=feature_size,
#     num_layer=num_layer,
#     hidden_size=hidden_size,
#     output_size=output_size,
# ).to(device)
# net_has_state = True

# %%
net = MLPModel(
    input_size=number_channel * window_length,
    output_size=music_window_length,
).to(device)
net_has_state = False

# %%
summary(net, (1, number_channel * window_length))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPModel                                 [1, 32]                   --
# ├─Sequential: 1-1                        [1, 32]                   --
# │    └─Linear: 2-1                       [1, 1024]                 2,098,176
# │    └─Tanh: 2-2                         [1, 1024]                 --
# │    └─BatchNorm1d: 2-3                  [1, 1024]                 2,048
# │    └─Linear: 2-4                       [1, 512]                  524,800
# │    └─Tanh: 2-5                         [1, 512]                  --
# │    └─BatchNorm1d: 2-6                  [1, 512]                  1,024
# │    └─Linear: 2-7                       [1, 256]                  131,328
# │    └─Tanh: 2-8                         [1, 256]                  --
# │    └─BatchNorm1d: 2-9                  [1, 256]                  512
# │    └─Linear: 2-10                      [1, 32]                   8,224
# │    └─Tanh: 2-11                        [1, 32]                   --
# ==========================================================================================
# Total params: 2,766,112
# Trainable params: 2,766,112
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.77
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.03
# Params size (MB): 11.06
# Estimated Total Size (MB): 11.10
# ==========================================================================================

# %%
criterion = nn.L1Loss()  # Must edit a stats_dict if change.
optimizer = th.optim.Adam(net.parameters(), lr=0.001)

# %%
ssim_criterion = ssim.SSIM(size_average=False)

# %% [markdown]
# # Training Model

# %% [markdown]
# ## Stats

# %%
stats = []
stats_dict = dict(
    iteration=0,
    trial_type=trial_type,
    loss_mode='MAE',
    
    train_loss=0.0,
    train_loss_raw=[],
    train_epoch=0,
    train_batch=0,
    
    valid_loss_raw=[],
    valid_loss_data=[],
    valid_loss=0.0,  # Equal micro
    valid_loss_micro=0.0,
    valid_loss_macro=0.0,
    valid_epoch=0,
    valid_batch=0,
    valid_difference=[],
    valid_similarity=[],
    
    best_loss=0.0,
    best_iteration=None,
    
    best_sim=0.0,
    best_sim_iteration=None,
    
    test_epoch=0,
    test_batch=0,
    
    test_loss_data=dict(),
    test_loss_raw=dict(),
    test_loss_micro=[],
    test_loss_macro=[],
    test_difference_raw=dict(),
    test_difference=[],
    test_similarity_raw=dict(),
    test_similarity=[],
)

# %%
def compute_difference(ref_rec, input_rec, weightage=[0.33,0.33,0.33]):
    ## Time domain similarity
    ref_time = np.correlate(ref_rec,ref_rec)
    inp_time = np.correlate(ref_rec,input_rec)
    diff_time = abs(ref_time-inp_time)
    
    ## Freq domain similarity
    ref_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(ref_rec)) 
    inp_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(input_rec))
    diff_freq = abs(ref_freq-inp_freq)
    
    ## Power similarity
    ref_power = np.sum(ref_rec**2)
    inp_power = np.sum(input_rec**2)
    diff_power = abs(ref_power-inp_power)
    
    return diff_time[0], diff_freq[0], diff_power, weightage[0] * diff_time[0] + weightage[1] * diff_freq[0] + weightage[2] * diff_power

# %%
def stft_tensor(wav, n_fft=64):
    stft = th.abs(th.stft(th.Tensor(wav), n_fft=n_fft, return_complex=True))
    return stft.view((1, 1) + tuple(stft.size()))

# %% [markdown]
# ## Train/Valid

# %%
interation_progress = IntProgress(min=0, max=num_iteration)
interation_progress.value = 0
interation_progress.description = f'Iter: 0/{num_iteration}'
display(interation_progress)

train_progress = IntProgress(min=0, max=500)
train_progress.value = 0
max_train_epoch = '???'
train_progress.description = f'Train 0/{max_train_epoch}'
display(train_progress)

valid_progress = IntProgress(min=0, max=100)
valid_progress.value = 0
max_valid_epoch = '???'
valid_progress.description = f'Validate 0/{max_valid_epoch}'
display(valid_progress)

test_progress = IntProgress(min=0, max=100)
test_progress.value = 0
max_test_epoch = '???'
test_progress.description = f'Test 0/{max_test_epoch}'
display(test_progress)

best_loss = None
best_iter = 0

best_sim = None
best_sim_iter = 0

for iteration in range(1, num_iteration + 1):
    interation_progress.value = iteration
    interation_progress.description = f'Iter: {iteration}/{num_iteration}'
    
    monitor_loss = 0
    n_monitor = 50
    
    train_loss = []
    train_epoch = 0
    train_batch = 0
    net.train()
    for indices in events_iter(
            batch_size=batch_size, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=train_custom_filter,
            shuffle=True
    ):
        for batch_input, batch_output in training_iter(indices, window_length=window_length, shuffle=True):
            train_epoch += 1
            train_batch += batch_input.shape[0]
            train_progress.value = train_epoch
            train_progress.description = f'Train {train_epoch}/{max_train_epoch}'
            
            # batch_input = (batch_size, number_channel, window_length)
            X = th.Tensor(net.transform_input(batch_input)).to(device)
            Y = th.Tensor(batch_output).to(device)

            output = net(X)
            if net_has_state:
                output, state = output
            loss = criterion(output, Y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
            monitor_loss += loss.item()
            
            if train_epoch % n_monitor == 0:
                print(f'Iter: {iteration}, Epoch: {train_epoch}/{max_train_epoch}, MAELoss: {monitor_loss/n_monitor*1e6:.3f} / 1e6')
                monitor_loss = 0
    
    train_progress.max = max_train_epoch = train_epoch
    train_progress.description = f'Training Done'
    print(f'Iter: {iteration}, Validating ...')

    valid_loss = []
    valid_loss_data = []
    valid_difference = []
    valid_similarity = []
    valid_epoch = 0
    valid_batch = 0
    net.eval()
    for indices in events_iter(
            batch_size=1, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=valid_custom_filter,
            shuffle=False,
    ):
        valid_loss_data.append(data_events_info[indices][:, [idx_MID, idx_VERSION, idx_SUBID]])
        for batch_input, batch_output in testing_iter(indices, window_length=window_length, shuffle=False):
            valid_epoch += 1
            valid_batch += batch_input.shape[0]
            valid_progress.value = valid_epoch
            valid_progress.description = f'Validate {valid_epoch}/{max_valid_epoch}'
            
            # batch_input = (batch_size, number_channel, window_length)
            X = th.Tensor(net.transform_input(batch_input)).to(device)
            Y = th.Tensor(batch_output).to(device)
            
            with th.no_grad():
                output = net(X)
                if net_has_state:
                    output, state = output
                loss = criterion(output, Y)
            
            valid_loss.append(loss.item())
            
            wy = batch_output.flatten()
            wx = output.flatten().cpu().numpy()
            valid_difference.append(compute_difference(wy, wx))
            valid_similarity.append(ssim_criterion(stft_tensor(wx), stft_tensor(wy)).item())
    
    similarity = np.mean(np.abs(valid_similarity))
    difference = np.mean(valid_difference, axis=0)
    valid_progress.max = max_valid_epoch = valid_epoch
    valid_progress.description = f'Validate Done'
    
    temp_stats = stats_dict.copy()
    temp_stats['iteration'] = iteration
    
    temp_stats['train_epoch'] = train_epoch
    temp_stats['train_batch'] = train_batch
    
    temp_stats['train_loss'] = np.sum(train_loss)/train_batch  # batch
    temp_stats['train_loss_raw'] = np.asarray(train_loss)
    temp_stats['train_loss_epoch'] = np.mean(train_loss)
    temp_stats['train_loss_batch'] = np.sum(train_loss)/train_batch
    
    temp_stats['valid_epoch'] = valid_epoch
    temp_stats['valid_batch'] = valid_batch
    
    temp_stats['valid_loss_raw'] = np.asarray(valid_loss)
    temp_stats['valid_loss'] = np.sum(valid_loss)/valid_batch  # batch (*best model)
    temp_stats['valid_loss_micro'] = np.sum(valid_loss)/valid_batch  # by batch
    temp_stats['valid_loss_macro'] = np.mean(valid_loss)  # by number of songs
    temp_stats['valid_loss_data'] = np.concatenate(valid_loss_data)
    
    temp_stats['valid_similarity_raw'] = np.asarray(valid_similarity)
    temp_stats['valid_similarity'] = np.mean(np.abs(valid_similarity))  # (*best similar model)
    temp_stats['valid_difference_raw'] = np.asarray(valid_difference)
    temp_stats['valid_difference'] = difference[3]
    
    print(f'''====================================================================================================
Iter: {iteration},\tTraining-MAELoss: {temp_stats['train_loss_epoch']*1e6:.3f} / 1e6 (epoch), {temp_stats['train_loss_batch']*1e6:.3f} / 1e6 (batch)
\t\t Validating-MAELoss: {temp_stats['valid_loss_macro']*1e6:.3f} / 1e6 (song),  {temp_stats['valid_loss_micro']*1e6:.3f} / 1e6 (batch)
\t\tSimilarity: {similarity:.3f} Difference: {difference[3]:.2f} (Time: {difference[0]:.2f}, Frequency: {difference[1]:.2f}, Power: {difference[2]:.2f})
====================================================================================================''')
        
    if iteration % 20 == 0:
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-iter-{iteration:03d}.pt')
    
    if best_loss is None or temp_stats['valid_loss'] < best_loss:
        best_iter = iteration
        best_loss = temp_stats['valid_loss']
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-loss-iter-{best_iter:03d}.pt')
    
    if best_sim is None or similarity > best_sim:
        best_sim_iter = iteration
        best_sim = similarity
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-sim-iter-{best_sim_iter:03d}.pt')
        
    
    temp_stats['best_loss'] = best_loss
    temp_stats['best_iteration'] = best_iter
    
    temp_stats['best_sim'] = best_sim
    temp_stats['best_sim_iteration'] = best_sim_iter
    
    
    test_epoch = 0
    test_batch = 0
    test_loss_data = dict()
    test_loss = dict()
    test_difference = dict()
    test_similarity = dict()
    
    for test_id, experiment_filter in enumerate(test_filter_list):
        test_loss_data[test_id] = []
        test_loss[test_id] = []
        test_difference[test_id] = []
        test_similarity[test_id] = []
        
        for indices in events_iter(
            batch_size=1, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=experiment_filter,
            shuffle=False,
        ):
            test_loss_data[test_id].append(data_events_info[indices][:, [idx_MID, idx_VERSION, idx_SUBID]])
            for batch_input, batch_output in testing_iter(indices, window_length=window_length, shuffle=False):
                test_epoch += 1
                test_batch += batch_input.shape[0]
                test_progress.value = test_epoch
                test_progress.description = f'Test {test_epoch}/{max_test_epoch}'

                # batch_input = (batch_size, number_channel, window_length)
                X = th.Tensor(net.transform_input(batch_input)).to(device)
                Y = th.Tensor(batch_output).to(device)

                with th.no_grad():
                    output = net(X)
                    if net_has_state:
                        output, state = output
                    loss = criterion(output, Y)

                test_loss[test_id].append(loss.item())

                wy = batch_output.flatten()
                wx = output.flatten().cpu().numpy()
                test_difference[test_id].append(compute_difference(wy, wx))
                test_similarity[test_id].append(ssim_criterion(stft_tensor(wx), stft_tensor(wy)).item())
    
    test_progress.max = max_test_epoch = test_epoch
    test_progress.description = f'Test Done'
    
    temp_stats['test_epoch'] = test_epoch
    temp_stats['test_batch'] = test_batch
    
    temp_stats['test_loss_data'] = test_loss_data
    temp_stats['test_loss_raw'] = test_loss
    temp_stats['test_difference_raw'] = test_difference
    temp_stats['test_similarity_raw'] = test_similarity
    
    temp_stats['test_loss_micro'] = []
    temp_stats['test_loss_macro'] = []
    temp_stats['test_difference'] = []
    temp_stats['test_similarity'] = []
    for test_id in range(len(experiments_list)):
        temp_stats['test_loss_micro'].append(np.sum(test_loss[test_id])/test_batch)
        temp_stats['test_loss_macro'].append(np.mean(test_loss[test_id]))
        temp_stats['test_difference'].append(np.mean(test_difference[test_id], axis=0)[3])
        temp_stats['test_similarity'].append(np.mean(np.abs(test_similarity[test_id])))
    
    stats.append(temp_stats)
# Out:
# IntProgress(value=0, description='Iter: 0/200', max=200)
# IntProgress(value=0, description='Train 0/???', max=500)
# IntProgress(value=0, description='Validate 0/???')
# IntProgress(value=0, description='Test 0/???')
# Iter: 1, Epoch: 50/???, MAELoss: 138168.058 / 1e6
# Iter: 1, Epoch: 100/???, MAELoss: 52605.092 / 1e6
# Iter: 1, Epoch: 150/???, MAELoss: 45501.336 / 1e6
# Iter: 1, Epoch: 200/???, MAELoss: 39947.265 / 1e6
# Iter: 1, Epoch: 250/???, MAELoss: 36596.319 / 1e6
# Iter: 1, Epoch: 300/???, MAELoss: 34186.502 / 1e6
# Iter: 1, Validating ...
# ====================================================================================================
# Iter: 1,	Training-MAELoss: 56611.533 / 1e6 (epoch), 3640.899 / 1e6 (batch)
# 		 Validating-MAELoss: 47282.178 / 1e6 (song),  1806.962 / 1e6 (batch)
# 		Similarity: 0.035 Difference: 1050.53 (Time: 2.76, Frequency: 3176.88, Power: 3.76)
# ====================================================================================================
# Iter: 2, Epoch: 50/328, MAELoss: 40716.441 / 1e6
# Iter: 2, Epoch: 100/328, MAELoss: 40207.834 / 1e6
# Iter: 2, Epoch: 150/328, MAELoss: 35977.366 / 1e6
# Iter: 2, Epoch: 200/328, MAELoss: 36775.276 / 1e6
# Iter: 2, Epoch: 250/328, MAELoss: 40499.104 / 1e6
# Iter: 2, Epoch: 300/328, MAELoss: 42837.549 / 1e6
# Iter: 2, Validating ...
# ====================================================================================================
# Iter: 2,	Training-MAELoss: 39875.396 / 1e6 (epoch), 2565.688 / 1e6 (batch)
# 		 Validating-MAELoss: 40523.052 / 1e6 (song),  1548.652 / 1e6 (batch)
# 		Similarity: 0.047 Difference: 1046.68 (Time: 2.76, Frequency: 3165.79, Power: 3.22)
# ====================================================================================================
# Iter: 3, Epoch: 50/323, MAELoss: 31817.031 / 1e6
# Iter: 3, Epoch: 100/323, MAELoss: 42150.158 / 1e6
# Iter: 3, Epoch: 150/323, MAELoss: 39932.313 / 1e6
# Iter: 3, Epoch: 200/323, MAELoss: 38988.521 / 1e6
# Iter: 3, Epoch: 250/323, MAELoss: 45392.643 / 1e6
# Iter: 3, Epoch: 300/323, MAELoss: 38092.861 / 1e6
# Iter: 3, Validating ...
# ====================================================================================================
# Iter: 3,	Training-MAELoss: 39148.550 / 1e6 (epoch), 2517.789 / 1e6 (batch)
# 		 Validating-MAELoss: 40999.548 / 1e6 (song),  1566.862 / 1e6 (batch)
# 		Similarity: 0.044 Difference: 1046.56 (Time: 2.76, Frequency: 3165.45, Power: 3.19)
# ====================================================================================================
# Iter: 4, Epoch: 50/328, MAELoss: 34373.961 / 1e6
# Iter: 4, Epoch: 100/328, MAELoss: 46118.394 / 1e6
# Iter: 4, Epoch: 150/328, MAELoss: 39899.755 / 1e6
# Iter: 4, Epoch: 200/328, MAELoss: 38818.268 / 1e6
# Iter: 4, Epoch: 250/328, MAELoss: 38009.472 / 1e6
# Iter: 4, Epoch: 300/328, MAELoss: 33030.332 / 1e6
# Iter: 4, Validating ...
# ====================================================================================================
# Iter: 4,	Training-MAELoss: 38578.905 / 1e6 (epoch), 2480.072 / 1e6 (batch)
# 		 Validating-MAELoss: 35904.362 / 1e6 (song),  1372.141 / 1e6 (batch)
# 		Similarity: 0.057 Difference: 1046.75 (Time: 2.76, Frequency: 3166.26, Power: 2.95)
# ====================================================================================================
# Iter: 5, Epoch: 50/333, MAELoss: 32666.124 / 1e6
# Iter: 5, Epoch: 100/333, MAELoss: 35404.721 / 1e6
# Iter: 5, Epoch: 150/333, MAELoss: 34540.583 / 1e6
# Iter: 5, Epoch: 200/333, MAELoss: 35889.027 / 1e6
# Iter: 5, Epoch: 250/333, MAELoss: 49114.290 / 1e6
# Iter: 5, Epoch: 300/333, MAELoss: 45235.542 / 1e6
# Iter: 5, Validating ...
# ====================================================================================================
# Iter: 5,	Training-MAELoss: 39107.780 / 1e6 (epoch), 2514.072 / 1e6 (batch)
# 		 Validating-MAELoss: 43391.638 / 1e6 (song),  1658.279 / 1e6 (batch)
# 		Similarity: 0.026 Difference: 1063.02 (Time: 2.80, Frequency: 3215.41, Power: 3.06)
# ====================================================================================================
# Iter: 6, Epoch: 50/333, MAELoss: 33744.196 / 1e6
# Iter: 6, Epoch: 100/333, MAELoss: 45464.741 / 1e6
# Iter: 6, Epoch: 150/333, MAELoss: 44643.290 / 1e6
# Iter: 6, Epoch: 200/333, MAELoss: 35970.103 / 1e6
# Iter: 6, Epoch: 250/333, MAELoss: 43332.713 / 1e6
# Iter: 6, Epoch: 300/333, MAELoss: 39698.708 / 1e6
# Iter: 6, Validating ...
# ====================================================================================================
# Iter: 6,	Training-MAELoss: 39704.026 / 1e6 (epoch), 2544.524 / 1e6 (batch)
# 		 Validating-MAELoss: 44101.084 / 1e6 (song),  1685.392 / 1e6 (batch)
# 		Similarity: 0.032 Difference: 1043.84 (Time: 2.75, Frequency: 3156.70, Power: 3.70)
# ====================================================================================================
# Iter: 7, Epoch: 50/323, MAELoss: 42731.816 / 1e6
# Iter: 7, Epoch: 100/323, MAELoss: 40873.043 / 1e6
# Iter: 7, Epoch: 150/323, MAELoss: 40241.477 / 1e6
# Iter: 7, Epoch: 200/323, MAELoss: 44390.599 / 1e6
# Iter: 7, Epoch: 250/323, MAELoss: 36337.665 / 1e6
# Iter: 7, Epoch: 300/323, MAELoss: 45028.342 / 1e6
# Iter: 7, Validating ...
# ====================================================================================================
# Iter: 7,	Training-MAELoss: 41823.124 / 1e6 (epoch), 2691.504 / 1e6 (batch)
# 		 Validating-MAELoss: 95899.139 / 1e6 (song),  3664.935 / 1e6 (batch)
# 		Similarity: 0.040 Difference: 1048.52 (Time: 2.74, Frequency: 3157.29, Power: 17.30)
# ====================================================================================================
# Iter: 8, Epoch: 50/321, MAELoss: 48556.742 / 1e6
# Iter: 8, Epoch: 100/321, MAELoss: 48222.254 / 1e6
# Iter: 8, Epoch: 150/321, MAELoss: 40807.982 / 1e6
# Iter: 8, Epoch: 200/321, MAELoss: 34056.160 / 1e6
# Iter: 8, Epoch: 250/321, MAELoss: 40195.776 / 1e6
# Iter: 8, Epoch: 300/321, MAELoss: 32838.318 / 1e6
# Iter: 8, Validating ...
# ====================================================================================================
# Iter: 8,	Training-MAELoss: 40396.408 / 1e6 (epoch), 2598.044 / 1e6 (batch)
# 		 Validating-MAELoss: 37296.565 / 1e6 (song),  1425.346 / 1e6 (batch)
# 		Similarity: 0.063 Difference: 1049.47 (Time: 2.77, Frequency: 3174.24, Power: 3.21)
# ====================================================================================================
# Iter: 9, Epoch: 50/328, MAELoss: 42386.629 / 1e6
# Iter: 9, Epoch: 100/328, MAELoss: 38903.128 / 1e6
# Iter: 9, Epoch: 150/328, MAELoss: 41643.427 / 1e6
# Iter: 9, Epoch: 200/328, MAELoss: 40866.208 / 1e6
# Iter: 9, Epoch: 250/328, MAELoss: 31603.375 / 1e6
# Iter: 9, Epoch: 300/328, MAELoss: 32352.181 / 1e6
# Iter: 9, Validating ...
# ====================================================================================================
# Iter: 9,	Training-MAELoss: 38743.466 / 1e6 (epoch), 2491.737 / 1e6 (batch)
# 		 Validating-MAELoss: 38698.699 / 1e6 (song),  1478.931 / 1e6 (batch)
# 		Similarity: 0.055 Difference: 1047.22 (Time: 2.76, Frequency: 3167.51, Power: 3.14)
# ====================================================================================================
# Iter: 10, Epoch: 50/328, MAELoss: 51416.760 / 1e6
# Iter: 10, Epoch: 100/328, MAELoss: 37164.864 / 1e6
# Iter: 10, Epoch: 150/328, MAELoss: 30112.559 / 1e6
# Iter: 10, Epoch: 200/328, MAELoss: 34695.440 / 1e6
# Iter: 10, Epoch: 250/328, MAELoss: 36143.592 / 1e6
# Iter: 10, Epoch: 300/328, MAELoss: 34096.299 / 1e6
# Iter: 10, Validating ...
# ====================================================================================================
# Iter: 10,	Training-MAELoss: 38421.801 / 1e6 (epoch), 2471.049 / 1e6 (batch)
# 		 Validating-MAELoss: 34343.683 / 1e6 (song),  1312.497 / 1e6 (batch)
# 		Similarity: 0.084 Difference: 1043.25 (Time: 2.75, Frequency: 3155.71, Power: 2.90)
# ====================================================================================================
# Iter: 11, Epoch: 50/328, MAELoss: 36179.643 / 1e6
# Iter: 11, Epoch: 100/328, MAELoss: 25212.663 / 1e6
# Iter: 11, Epoch: 150/328, MAELoss: 42647.768 / 1e6
# Iter: 11, Epoch: 200/328, MAELoss: 45093.441 / 1e6
# Iter: 11, Epoch: 250/328, MAELoss: 38615.750 / 1e6
# Iter: 11, Epoch: 300/328, MAELoss: 42532.622 / 1e6
# Iter: 11, Validating ...
# ====================================================================================================
# Iter: 11,	Training-MAELoss: 38994.498 / 1e6 (epoch), 2511.374 / 1e6 (batch)
# 		 Validating-MAELoss: 35283.448 / 1e6 (song),  1348.412 / 1e6 (batch)
# 		Similarity: 0.064 Difference: 1035.34 (Time: 2.73, Frequency: 3131.95, Power: 2.72)
# ====================================================================================================
# Iter: 12, Epoch: 50/313, MAELoss: 38570.723 / 1e6
# Iter: 12, Epoch: 100/313, MAELoss: 34276.747 / 1e6
# Iter: 12, Epoch: 150/313, MAELoss: 39098.783 / 1e6
# Iter: 12, Epoch: 200/313, MAELoss: 43562.287 / 1e6
# Iter: 12, Epoch: 250/313, MAELoss: 40523.993 / 1e6
# Iter: 12, Epoch: 300/313, MAELoss: 40599.936 / 1e6
# Iter: 12, Validating ...
# ====================================================================================================
# Iter: 12,	Training-MAELoss: 39986.565 / 1e6 (epoch), 2571.685 / 1e6 (batch)
# 		 Validating-MAELoss: 35159.404 / 1e6 (song),  1343.671 / 1e6 (batch)
# 		Similarity: 0.078 Difference: 1048.98 (Time: 2.76, Frequency: 3172.88, Power: 3.07)
# ====================================================================================================
# Iter: 13, Epoch: 50/328, MAELoss: 38534.294 / 1e6
# Iter: 13, Epoch: 100/328, MAELoss: 44979.026 / 1e6
# Iter: 13, Epoch: 150/328, MAELoss: 35283.598 / 1e6
# Iter: 13, Epoch: 200/328, MAELoss: 36008.176 / 1e6
# Iter: 13, Epoch: 250/328, MAELoss: 32975.571 / 1e6
# Iter: 13, Epoch: 300/328, MAELoss: 40176.113 / 1e6
# Iter: 13, Validating ...
# ====================================================================================================
# Iter: 13,	Training-MAELoss: 41249.748 / 1e6 (epoch), 2651.770 / 1e6 (batch)
# 		 Validating-MAELoss: 41937.285 / 1e6 (song),  1602.699 / 1e6 (batch)
# 		Similarity: 0.035 Difference: 1056.23 (Time: 2.78, Frequency: 3194.57, Power: 3.33)
# ====================================================================================================
# Iter: 14, Epoch: 50/333, MAELoss: 40033.103 / 1e6
# Iter: 14, Epoch: 100/333, MAELoss: 37646.761 / 1e6
# Iter: 14, Epoch: 150/333, MAELoss: 30538.639 / 1e6
# Iter: 14, Epoch: 200/333, MAELoss: 42648.092 / 1e6
# Iter: 14, Epoch: 250/333, MAELoss: 46954.552 / 1e6
# Iter: 14, Epoch: 300/333, MAELoss: 35932.081 / 1e6
# Iter: 14, Validating ...
# ====================================================================================================
# Iter: 14,	Training-MAELoss: 38626.632 / 1e6 (epoch), 2484.223 / 1e6 (batch)
# 		 Validating-MAELoss: 35663.369 / 1e6 (song),  1362.931 / 1e6 (batch)
# 		Similarity: 0.046 Difference: 1050.24 (Time: 2.77, Frequency: 3176.87, Power: 2.91)
# ====================================================================================================
# Iter: 15, Epoch: 50/328, MAELoss: 37517.857 / 1e6
# Iter: 15, Epoch: 100/328, MAELoss: 46741.529 / 1e6
# Iter: 15, Epoch: 150/328, MAELoss: 35380.729 / 1e6
# Iter: 15, Epoch: 200/328, MAELoss: 31290.158 / 1e6
# Iter: 15, Epoch: 250/328, MAELoss: 39355.590 / 1e6
# Iter: 15, Epoch: 300/328, MAELoss: 40135.169 / 1e6
# Iter: 15, Validating ...
# ====================================================================================================
# Iter: 15,	Training-MAELoss: 39274.107 / 1e6 (epoch), 2527.464 / 1e6 (batch)
# 		 Validating-MAELoss: 34387.059 / 1e6 (song),  1314.155 / 1e6 (batch)
# 		Similarity: 0.060 Difference: 1042.78 (Time: 2.75, Frequency: 3154.36, Power: 2.82)
# ====================================================================================================
# Iter: 16, Epoch: 50/321, MAELoss: 47492.157 / 1e6
# Iter: 16, Epoch: 100/321, MAELoss: 44188.298 / 1e6
# Iter: 16, Epoch: 150/321, MAELoss: 34720.454 / 1e6
# Iter: 16, Epoch: 200/321, MAELoss: 37327.208 / 1e6
# Iter: 16, Epoch: 250/321, MAELoss: 41027.603 / 1e6
# Iter: 16, Epoch: 300/321, MAELoss: 34447.116 / 1e6
# Iter: 16, Validating ...
# ====================================================================================================
# Iter: 16,	Training-MAELoss: 39959.740 / 1e6 (epoch), 2569.960 / 1e6 (batch)
# 		 Validating-MAELoss: 33986.539 / 1e6 (song),  1298.849 / 1e6 (batch)
# 		Similarity: 0.058 Difference: 1047.23 (Time: 2.76, Frequency: 3167.58, Power: 3.10)
# ====================================================================================================
# Iter: 17, Epoch: 50/328, MAELoss: 33517.832 / 1e6
# Iter: 17, Epoch: 100/328, MAELoss: 33485.085 / 1e6
# Iter: 17, Epoch: 150/328, MAELoss: 37801.805 / 1e6
# Iter: 17, Epoch: 200/328, MAELoss: 31174.363 / 1e6
# Iter: 17, Epoch: 250/328, MAELoss: 39900.461 / 1e6
# Iter: 17, Epoch: 300/328, MAELoss: 39695.869 / 1e6
# Iter: 17, Validating ...
# ====================================================================================================
# Iter: 17,	Training-MAELoss: 38233.558 / 1e6 (epoch), 2459.380 / 1e6 (batch)
# 		 Validating-MAELoss: 35972.585 / 1e6 (song),  1374.748 / 1e6 (batch)
# 		Similarity: 0.067 Difference: 1037.68 (Time: 2.73, Frequency: 3138.98, Power: 2.78)
# ====================================================================================================
# Iter: 18, Epoch: 50/326, MAELoss: 45821.913 / 1e6
# Iter: 18, Epoch: 100/326, MAELoss: 33800.946 / 1e6
# Iter: 18, Epoch: 150/326, MAELoss: 41637.240 / 1e6
# Iter: 18, Epoch: 200/326, MAELoss: 35726.014 / 1e6
# Iter: 18, Epoch: 250/326, MAELoss: 38045.487 / 1e6
# Iter: 18, Epoch: 300/326, MAELoss: 29363.364 / 1e6
# Iter: 18, Validating ...
# ====================================================================================================
# Iter: 18,	Training-MAELoss: 37218.848 / 1e6 (epoch), 2394.759 / 1e6 (batch)
# 		 Validating-MAELoss: 30606.705 / 1e6 (song),  1169.683 / 1e6 (batch)
# 		Similarity: 0.100 Difference: 1048.14 (Time: 2.76, Frequency: 3170.82, Power: 2.60)
# ====================================================================================================
# Iter: 19, Epoch: 50/323, MAELoss: 43157.750 / 1e6
# Iter: 19, Epoch: 100/323, MAELoss: 36666.343 / 1e6
# Iter: 19, Epoch: 150/323, MAELoss: 41647.787 / 1e6
# Iter: 19, Epoch: 200/323, MAELoss: 33504.517 / 1e6
# Iter: 19, Epoch: 250/323, MAELoss: 27976.313 / 1e6
# Iter: 19, Epoch: 300/323, MAELoss: 29789.492 / 1e6
# Iter: 19, Validating ...
# ====================================================================================================
# Iter: 19,	Training-MAELoss: 35234.264 / 1e6 (epoch), 2266.450 / 1e6 (batch)
# 		 Validating-MAELoss: 48154.954 / 1e6 (song),  1840.317 / 1e6 (batch)
# 		Similarity: 0.048 Difference: 1043.07 (Time: 2.75, Frequency: 3153.11, Power: 4.96)
# ====================================================================================================
# Iter: 20, Epoch: 50/326, MAELoss: 34965.684 / 1e6
# Iter: 20, Epoch: 100/326, MAELoss: 26930.257 / 1e6
# Iter: 20, Epoch: 150/326, MAELoss: 42737.303 / 1e6
# Iter: 20, Epoch: 200/326, MAELoss: 40445.151 / 1e6
# Iter: 20, Epoch: 250/326, MAELoss: 38946.713 / 1e6
# Iter: 20, Epoch: 300/326, MAELoss: 34903.357 / 1e6
# Iter: 20, Validating ...
# ====================================================================================================
# Iter: 20,	Training-MAELoss: 35956.326 / 1e6 (epoch), 2301.033 / 1e6 (batch)
# 		 Validating-MAELoss: 29361.724 / 1e6 (song),  1122.104 / 1e6 (batch)
# 		Similarity: 0.106 Difference: 1042.72 (Time: 2.75, Frequency: 3154.42, Power: 2.60)
# ====================================================================================================
# Iter: 21, Epoch: 50/321, MAELoss: 41831.773 / 1e6
# Iter: 21, Epoch: 100/321, MAELoss: 35734.124 / 1e6
# Iter: 21, Epoch: 150/321, MAELoss: 30849.091 / 1e6
# Iter: 21, Epoch: 200/321, MAELoss: 35339.048 / 1e6
# Iter: 21, Epoch: 250/321, MAELoss: 35723.801 / 1e6
# Iter: 21, Epoch: 300/321, MAELoss: 34168.931 / 1e6
# Iter: 21, Validating ...
# ====================================================================================================
# Iter: 21,	Training-MAELoss: 36367.530 / 1e6 (epoch), 2338.931 / 1e6 (batch)
# 		 Validating-MAELoss: 33626.743 / 1e6 (song),  1285.098 / 1e6 (batch)
# 		Similarity: 0.079 Difference: 1041.25 (Time: 2.74, Frequency: 3149.76, Power: 2.79)
# ====================================================================================================
# Iter: 22, Epoch: 50/328, MAELoss: 31878.667 / 1e6
# Iter: 22, Epoch: 100/328, MAELoss: 41529.324 / 1e6
# Iter: 22, Epoch: 150/328, MAELoss: 33903.829 / 1e6
# Iter: 22, Epoch: 200/328, MAELoss: 35359.112 / 1e6
# Iter: 22, Epoch: 250/328, MAELoss: 40062.728 / 1e6
# Iter: 22, Epoch: 300/328, MAELoss: 32567.272 / 1e6
# Iter: 22, Validating ...
# ====================================================================================================
# Iter: 22,	Training-MAELoss: 36068.024 / 1e6 (epoch), 2320.712 / 1e6 (batch)
# 		 Validating-MAELoss: 29145.284 / 1e6 (song),  1113.832 / 1e6 (batch)
# 		Similarity: 0.110 Difference: 1050.29 (Time: 2.77, Frequency: 3177.17, Power: 2.75)
# ====================================================================================================
# Iter: 23, Epoch: 50/323, MAELoss: 36740.649 / 1e6
# Iter: 23, Epoch: 100/323, MAELoss: 29460.550 / 1e6
# Iter: 23, Epoch: 150/323, MAELoss: 36450.561 / 1e6
# Iter: 23, Epoch: 200/323, MAELoss: 36339.957 / 1e6
# Iter: 23, Epoch: 250/323, MAELoss: 33776.409 / 1e6
# Iter: 23, Epoch: 300/323, MAELoss: 35028.886 / 1e6
# Iter: 23, Validating ...
# ====================================================================================================
# Iter: 23,	Training-MAELoss: 35587.843 / 1e6 (epoch), 2291.312 / 1e6 (batch)
# 		 Validating-MAELoss: 33376.490 / 1e6 (song),  1275.535 / 1e6 (batch)
# 		Similarity: 0.081 Difference: 1045.79 (Time: 2.75, Frequency: 3163.54, Power: 2.76)
# ====================================================================================================
# Iter: 24, Epoch: 50/316, MAELoss: 30510.058 / 1e6
# Iter: 24, Epoch: 100/316, MAELoss: 38107.255 / 1e6
# Iter: 24, Epoch: 150/316, MAELoss: 35035.075 / 1e6
# Iter: 24, Epoch: 200/316, MAELoss: 33265.836 / 1e6
# Iter: 24, Epoch: 250/316, MAELoss: 30989.037 / 1e6
# Iter: 24, Epoch: 300/316, MAELoss: 42002.555 / 1e6
# Iter: 24, Validating ...
# ====================================================================================================
# Iter: 24,	Training-MAELoss: 34647.569 / 1e6 (epoch), 2227.344 / 1e6 (batch)
# 		 Validating-MAELoss: 31857.713 / 1e6 (song),  1217.492 / 1e6 (batch)
# 		Similarity: 0.095 Difference: 1052.47 (Time: 2.77, Frequency: 3183.64, Power: 2.89)
# ====================================================================================================
# Iter: 25, Epoch: 50/333, MAELoss: 38952.124 / 1e6
# Iter: 25, Epoch: 100/333, MAELoss: 31797.779 / 1e6
# Iter: 25, Epoch: 150/333, MAELoss: 42165.341 / 1e6
# Iter: 25, Epoch: 200/333, MAELoss: 34899.234 / 1e6
# Iter: 25, Epoch: 250/333, MAELoss: 34692.910 / 1e6
# Iter: 25, Epoch: 300/333, MAELoss: 28501.887 / 1e6
# Iter: 25, Validating ...
# ====================================================================================================
# Iter: 25,	Training-MAELoss: 34100.963 / 1e6 (epoch), 2184.593 / 1e6 (batch)
# 		 Validating-MAELoss: 33070.815 / 1e6 (song),  1263.853 / 1e6 (batch)
# 		Similarity: 0.090 Difference: 1048.31 (Time: 2.76, Frequency: 3171.00, Power: 2.95)
# ====================================================================================================
# Iter: 26, Epoch: 50/328, MAELoss: 30603.393 / 1e6
# Iter: 26, Epoch: 100/328, MAELoss: 32666.778 / 1e6
# Iter: 26, Epoch: 150/328, MAELoss: 27676.772 / 1e6
# Iter: 26, Epoch: 200/328, MAELoss: 39209.157 / 1e6
# Iter: 26, Epoch: 250/328, MAELoss: 38787.663 / 1e6
# Iter: 26, Epoch: 300/328, MAELoss: 39226.141 / 1e6
# Iter: 26, Validating ...
# ====================================================================================================
# Iter: 26,	Training-MAELoss: 34323.730 / 1e6 (epoch), 2207.487 / 1e6 (batch)
# 		 Validating-MAELoss: 31486.895 / 1e6 (song),  1203.321 / 1e6 (batch)
# 		Similarity: 0.093 Difference: 1051.96 (Time: 2.77, Frequency: 3182.13, Power: 2.87)
# ====================================================================================================
# Iter: 27, Epoch: 50/328, MAELoss: 35599.739 / 1e6
# Iter: 27, Epoch: 100/328, MAELoss: 34271.204 / 1e6
# Iter: 27, Epoch: 150/328, MAELoss: 37710.144 / 1e6
# Iter: 27, Epoch: 200/328, MAELoss: 32209.706 / 1e6
# Iter: 27, Epoch: 250/328, MAELoss: 38107.822 / 1e6
# Iter: 27, Epoch: 300/328, MAELoss: 30120.630 / 1e6
# Iter: 27, Validating ...
# ====================================================================================================
# Iter: 27,	Training-MAELoss: 34479.690 / 1e6 (epoch), 2218.921 / 1e6 (batch)
# 		 Validating-MAELoss: 32516.601 / 1e6 (song),  1242.673 / 1e6 (batch)
# 		Similarity: 0.070 Difference: 1050.43 (Time: 2.77, Frequency: 3177.49, Power: 2.86)
# ====================================================================================================
# Iter: 28, Epoch: 50/321, MAELoss: 35069.021 / 1e6
# Iter: 28, Epoch: 100/321, MAELoss: 26587.269 / 1e6
# Iter: 28, Epoch: 150/321, MAELoss: 33352.526 / 1e6
# Iter: 28, Epoch: 200/321, MAELoss: 39511.784 / 1e6
# Iter: 28, Epoch: 250/321, MAELoss: 38433.601 / 1e6
# Iter: 28, Epoch: 300/321, MAELoss: 26870.708 / 1e6
# Iter: 28, Validating ...
# ====================================================================================================
# Iter: 28,	Training-MAELoss: 33202.891 / 1e6 (epoch), 2134.472 / 1e6 (batch)
# 		 Validating-MAELoss: 34459.187 / 1e6 (song),  1316.912 / 1e6 (batch)
# 		Similarity: 0.092 Difference: 1044.10 (Time: 2.75, Frequency: 3158.34, Power: 2.85)
# ====================================================================================================
# Iter: 29, Epoch: 50/333, MAELoss: 30643.330 / 1e6
# Iter: 29, Epoch: 100/333, MAELoss: 32465.281 / 1e6
# Iter: 29, Epoch: 150/333, MAELoss: 38914.105 / 1e6
# Iter: 29, Epoch: 200/333, MAELoss: 35678.463 / 1e6
# Iter: 29, Epoch: 250/333, MAELoss: 31559.898 / 1e6
# Iter: 29, Epoch: 300/333, MAELoss: 32701.372 / 1e6
# Iter: 29, Validating ...
# ====================================================================================================
# Iter: 29,	Training-MAELoss: 33291.801 / 1e6 (epoch), 2140.187 / 1e6 (batch)
# 		 Validating-MAELoss: 28386.027 / 1e6 (song),  1084.816 / 1e6 (batch)
# 		Similarity: 0.109 Difference: 1048.76 (Time: 2.76, Frequency: 3172.72, Power: 2.59)
# ====================================================================================================
# Iter: 30, Epoch: 50/333, MAELoss: 29282.018 / 1e6
# Iter: 30, Epoch: 100/333, MAELoss: 31870.012 / 1e6
# Iter: 30, Epoch: 150/333, MAELoss: 23901.843 / 1e6
# Iter: 30, Epoch: 200/333, MAELoss: 29550.280 / 1e6
# Iter: 30, Epoch: 250/333, MAELoss: 52131.081 / 1e6
# Iter: 30, Epoch: 300/333, MAELoss: 40857.909 / 1e6
# Iter: 30, Validating ...
# ====================================================================================================
# Iter: 30,	Training-MAELoss: 34640.572 / 1e6 (epoch), 2229.275 / 1e6 (batch)
# 		 Validating-MAELoss: 32121.635 / 1e6 (song),  1227.578 / 1e6 (batch)
# 		Similarity: 0.066 Difference: 1045.58 (Time: 2.75, Frequency: 3162.82, Power: 2.85)
# ====================================================================================================
# Iter: 31, Epoch: 50/321, MAELoss: 29486.592 / 1e6
# Iter: 31, Epoch: 100/321, MAELoss: 35369.212 / 1e6
# Iter: 31, Epoch: 150/321, MAELoss: 30320.154 / 1e6
# Iter: 31, Epoch: 200/321, MAELoss: 39801.427 / 1e6
# Iter: 31, Epoch: 250/321, MAELoss: 26419.904 / 1e6
# Iter: 31, Epoch: 300/321, MAELoss: 37189.394 / 1e6
# Iter: 31, Validating ...
# ====================================================================================================
# Iter: 31,	Training-MAELoss: 32950.233 / 1e6 (epoch), 2119.530 / 1e6 (batch)
# 		 Validating-MAELoss: 30152.321 / 1e6 (song),  1152.318 / 1e6 (batch)
# 		Similarity: 0.096 Difference: 1048.89 (Time: 2.76, Frequency: 3172.93, Power: 2.77)
# ====================================================================================================
# Iter: 32, Epoch: 50/326, MAELoss: 31669.604 / 1e6
# Iter: 32, Epoch: 100/326, MAELoss: 41446.417 / 1e6
# Iter: 32, Epoch: 150/326, MAELoss: 36477.906 / 1e6
# Iter: 32, Epoch: 200/326, MAELoss: 29866.189 / 1e6
# Iter: 32, Epoch: 250/326, MAELoss: 28467.459 / 1e6
# Iter: 32, Epoch: 300/326, MAELoss: 32719.479 / 1e6
# Iter: 32, Validating ...
# ====================================================================================================
# Iter: 32,	Training-MAELoss: 33064.378 / 1e6 (epoch), 2126.493 / 1e6 (batch)
# 		 Validating-MAELoss: 33969.459 / 1e6 (song),  1298.196 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1038.10 (Time: 2.74, Frequency: 3140.13, Power: 2.89)
# ====================================================================================================
# Iter: 33, Epoch: 50/328, MAELoss: 40953.634 / 1e6
# Iter: 33, Epoch: 100/328, MAELoss: 34142.743 / 1e6
# Iter: 33, Epoch: 150/328, MAELoss: 39360.384 / 1e6
# Iter: 33, Epoch: 200/328, MAELoss: 32098.596 / 1e6
# Iter: 33, Epoch: 250/328, MAELoss: 33584.461 / 1e6
# Iter: 33, Epoch: 300/328, MAELoss: 29497.064 / 1e6
# Iter: 33, Validating ...
# ====================================================================================================
# Iter: 33,	Training-MAELoss: 34057.346 / 1e6 (epoch), 2182.989 / 1e6 (batch)
# 		 Validating-MAELoss: 55347.280 / 1e6 (song),  2115.183 / 1e6 (batch)
# 		Similarity: 0.053 Difference: 1049.26 (Time: 2.76, Frequency: 3167.85, Power: 8.97)
# ====================================================================================================
# Iter: 34, Epoch: 50/321, MAELoss: 31949.698 / 1e6
# Iter: 34, Epoch: 100/321, MAELoss: 39729.135 / 1e6
# Iter: 34, Epoch: 150/321, MAELoss: 29615.526 / 1e6
# Iter: 34, Epoch: 200/321, MAELoss: 31103.040 / 1e6
# Iter: 34, Epoch: 250/321, MAELoss: 30744.080 / 1e6
# Iter: 34, Epoch: 300/321, MAELoss: 42438.458 / 1e6
# Iter: 34, Validating ...
# ====================================================================================================
# Iter: 34,	Training-MAELoss: 33968.497 / 1e6 (epoch), 2186.024 / 1e6 (batch)
# 		 Validating-MAELoss: 31465.797 / 1e6 (song),  1202.515 / 1e6 (batch)
# 		Similarity: 0.096 Difference: 1045.41 (Time: 2.75, Frequency: 3162.43, Power: 2.71)
# ====================================================================================================
# Iter: 35, Epoch: 50/321, MAELoss: 31004.209 / 1e6
# Iter: 35, Epoch: 100/321, MAELoss: 28153.737 / 1e6
# Iter: 35, Epoch: 150/321, MAELoss: 30681.220 / 1e6
# Iter: 35, Epoch: 200/321, MAELoss: 27068.161 / 1e6
# Iter: 35, Epoch: 250/321, MAELoss: 37949.869 / 1e6
# Iter: 35, Epoch: 300/321, MAELoss: 43837.114 / 1e6
# Iter: 35, Validating ...
# ====================================================================================================
# Iter: 35,	Training-MAELoss: 33089.744 / 1e6 (epoch), 2128.125 / 1e6 (batch)
# 		 Validating-MAELoss: 29956.531 / 1e6 (song),  1144.836 / 1e6 (batch)
# 		Similarity: 0.088 Difference: 1050.05 (Time: 2.77, Frequency: 3176.48, Power: 2.73)
# ====================================================================================================
# Iter: 36, Epoch: 50/328, MAELoss: 30158.922 / 1e6
# Iter: 36, Epoch: 100/328, MAELoss: 36354.343 / 1e6
# Iter: 36, Epoch: 150/328, MAELoss: 34169.927 / 1e6
# Iter: 36, Epoch: 200/328, MAELoss: 30263.351 / 1e6
# Iter: 36, Epoch: 250/328, MAELoss: 37318.914 / 1e6
# Iter: 36, Epoch: 300/328, MAELoss: 33834.649 / 1e6
# Iter: 36, Validating ...
# ====================================================================================================
# Iter: 36,	Training-MAELoss: 32865.962 / 1e6 (epoch), 2105.476 / 1e6 (batch)
# 		 Validating-MAELoss: 29006.156 / 1e6 (song),  1108.516 / 1e6 (batch)
# 		Similarity: 0.099 Difference: 1048.55 (Time: 2.76, Frequency: 3171.92, Power: 2.74)
# ====================================================================================================
# Iter: 37, Epoch: 50/328, MAELoss: 43932.109 / 1e6
# Iter: 37, Epoch: 100/328, MAELoss: 37421.499 / 1e6
# Iter: 37, Epoch: 150/328, MAELoss: 27386.552 / 1e6
# Iter: 37, Epoch: 200/328, MAELoss: 31734.572 / 1e6
# Iter: 37, Epoch: 250/328, MAELoss: 22323.168 / 1e6
# Iter: 37, Epoch: 300/328, MAELoss: 28165.705 / 1e6
# Iter: 37, Validating ...
# ====================================================================================================
# Iter: 37,	Training-MAELoss: 32515.306 / 1e6 (epoch), 2091.180 / 1e6 (batch)
# 		 Validating-MAELoss: 27031.838 / 1e6 (song),  1033.064 / 1e6 (batch)
# 		Similarity: 0.100 Difference: 1045.98 (Time: 2.76, Frequency: 3164.23, Power: 2.66)
# ====================================================================================================
# Iter: 38, Epoch: 50/328, MAELoss: 26957.421 / 1e6
# Iter: 38, Epoch: 100/328, MAELoss: 28967.049 / 1e6
# Iter: 38, Epoch: 150/328, MAELoss: 37426.398 / 1e6
# Iter: 38, Epoch: 200/328, MAELoss: 22258.364 / 1e6
# Iter: 38, Epoch: 250/328, MAELoss: 41883.694 / 1e6
# Iter: 38, Epoch: 300/328, MAELoss: 30892.526 / 1e6
# Iter: 38, Validating ...
# ====================================================================================================
# Iter: 38,	Training-MAELoss: 32839.238 / 1e6 (epoch), 2112.014 / 1e6 (batch)
# 		 Validating-MAELoss: 29496.526 / 1e6 (song),  1127.256 / 1e6 (batch)
# 		Similarity: 0.099 Difference: 1044.04 (Time: 2.75, Frequency: 3158.33, Power: 2.69)
# ====================================================================================================
# Iter: 39, Epoch: 50/328, MAELoss: 34171.765 / 1e6
# Iter: 39, Epoch: 100/328, MAELoss: 33459.858 / 1e6
# Iter: 39, Epoch: 150/328, MAELoss: 36984.561 / 1e6
# Iter: 39, Epoch: 200/328, MAELoss: 28118.879 / 1e6
# Iter: 39, Epoch: 250/328, MAELoss: 26645.061 / 1e6
# Iter: 39, Epoch: 300/328, MAELoss: 33427.572 / 1e6
# Iter: 39, Validating ...
# ====================================================================================================
# Iter: 39,	Training-MAELoss: 32629.636 / 1e6 (epoch), 2097.619 / 1e6 (batch)
# 		 Validating-MAELoss: 33249.417 / 1e6 (song),  1270.678 / 1e6 (batch)
# 		Similarity: 0.099 Difference: 1041.09 (Time: 2.74, Frequency: 3149.26, Power: 2.83)
# ====================================================================================================
# Iter: 40, Epoch: 50/333, MAELoss: 27001.463 / 1e6
# Iter: 40, Epoch: 100/333, MAELoss: 31027.761 / 1e6
# Iter: 40, Epoch: 150/333, MAELoss: 36410.533 / 1e6
# Iter: 40, Epoch: 200/333, MAELoss: 28754.578 / 1e6
# Iter: 40, Epoch: 250/333, MAELoss: 28376.584 / 1e6
# Iter: 40, Epoch: 300/333, MAELoss: 39637.597 / 1e6
# Iter: 40, Validating ...
# ====================================================================================================
# Iter: 40,	Training-MAELoss: 31118.351 / 1e6 (epoch), 1994.291 / 1e6 (batch)
# 		 Validating-MAELoss: 28836.855 / 1e6 (song),  1102.045 / 1e6 (batch)
# 		Similarity: 0.114 Difference: 1049.08 (Time: 2.77, Frequency: 3173.55, Power: 2.70)
# ====================================================================================================
# Iter: 41, Epoch: 50/323, MAELoss: 22943.608 / 1e6
# Iter: 41, Epoch: 100/323, MAELoss: 21580.047 / 1e6
# Iter: 41, Epoch: 150/323, MAELoss: 39618.029 / 1e6
# Iter: 41, Epoch: 200/323, MAELoss: 33760.719 / 1e6
# Iter: 41, Epoch: 250/323, MAELoss: 39354.843 / 1e6
# Iter: 41, Epoch: 300/323, MAELoss: 37262.001 / 1e6
# Iter: 41, Validating ...
# ====================================================================================================
# Iter: 41,	Training-MAELoss: 32020.425 / 1e6 (epoch), 2049.930 / 1e6 (batch)
# 		 Validating-MAELoss: 32488.100 / 1e6 (song),  1241.583 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1047.54 (Time: 2.76, Frequency: 3168.77, Power: 2.82)
# ====================================================================================================
# Iter: 42, Epoch: 50/316, MAELoss: 35492.583 / 1e6
# Iter: 42, Epoch: 100/316, MAELoss: 32479.369 / 1e6
# Iter: 42, Epoch: 150/316, MAELoss: 30845.616 / 1e6
# Iter: 42, Epoch: 200/316, MAELoss: 34945.942 / 1e6
# Iter: 42, Epoch: 250/316, MAELoss: 28896.076 / 1e6
# Iter: 42, Epoch: 300/316, MAELoss: 30386.757 / 1e6
# Iter: 42, Validating ...
# ====================================================================================================
# Iter: 42,	Training-MAELoss: 31246.551 / 1e6 (epoch), 2002.507 / 1e6 (batch)
# 		 Validating-MAELoss: 27847.488 / 1e6 (song),  1064.235 / 1e6 (batch)
# 		Similarity: 0.127 Difference: 1050.27 (Time: 2.77, Frequency: 3177.14, Power: 2.72)
# ====================================================================================================
# Iter: 43, Epoch: 50/323, MAELoss: 31847.760 / 1e6
# Iter: 43, Epoch: 100/323, MAELoss: 23159.163 / 1e6
# Iter: 43, Epoch: 150/323, MAELoss: 32198.149 / 1e6
# Iter: 43, Epoch: 200/323, MAELoss: 37417.661 / 1e6
# Iter: 43, Epoch: 250/323, MAELoss: 37476.215 / 1e6
# Iter: 43, Epoch: 300/323, MAELoss: 26842.325 / 1e6
# Iter: 43, Validating ...
# ====================================================================================================
# Iter: 43,	Training-MAELoss: 31163.118 / 1e6 (epoch), 2004.216 / 1e6 (batch)
# 		 Validating-MAELoss: 29282.321 / 1e6 (song),  1119.070 / 1e6 (batch)
# 		Similarity: 0.118 Difference: 1042.38 (Time: 2.75, Frequency: 3153.31, Power: 2.68)
# ====================================================================================================
# Iter: 44, Epoch: 50/328, MAELoss: 29823.449 / 1e6
# Iter: 44, Epoch: 100/328, MAELoss: 36837.569 / 1e6
# Iter: 44, Epoch: 150/328, MAELoss: 33204.690 / 1e6
# Iter: 44, Epoch: 200/328, MAELoss: 23757.114 / 1e6
# Iter: 44, Epoch: 250/328, MAELoss: 37419.610 / 1e6
# Iter: 44, Epoch: 300/328, MAELoss: 28434.581 / 1e6
# Iter: 44, Validating ...
# ====================================================================================================
# Iter: 44,	Training-MAELoss: 31473.631 / 1e6 (epoch), 2024.547 / 1e6 (batch)
# 		 Validating-MAELoss: 29337.370 / 1e6 (song),  1121.173 / 1e6 (batch)
# 		Similarity: 0.109 Difference: 1050.02 (Time: 2.77, Frequency: 3176.31, Power: 2.80)
# ====================================================================================================
# Iter: 45, Epoch: 50/326, MAELoss: 29765.185 / 1e6
# Iter: 45, Epoch: 100/326, MAELoss: 22891.591 / 1e6
# Iter: 45, Epoch: 150/326, MAELoss: 27918.811 / 1e6
# Iter: 45, Epoch: 200/326, MAELoss: 29273.447 / 1e6
# Iter: 45, Epoch: 250/326, MAELoss: 35713.425 / 1e6
# Iter: 45, Epoch: 300/326, MAELoss: 32399.147 / 1e6
# Iter: 45, Validating ...
# ====================================================================================================
# Iter: 45,	Training-MAELoss: 32027.631 / 1e6 (epoch), 2059.816 / 1e6 (batch)
# 		 Validating-MAELoss: 33961.191 / 1e6 (song),  1297.880 / 1e6 (batch)
# 		Similarity: 0.075 Difference: 1045.16 (Time: 2.75, Frequency: 3161.52, Power: 2.87)
# ====================================================================================================
# Iter: 46, Epoch: 50/328, MAELoss: 27682.855 / 1e6
# Iter: 46, Epoch: 100/328, MAELoss: 31505.751 / 1e6
# Iter: 46, Epoch: 150/328, MAELoss: 28408.590 / 1e6
# Iter: 46, Epoch: 200/328, MAELoss: 38285.289 / 1e6
# Iter: 46, Epoch: 250/328, MAELoss: 34544.835 / 1e6
# Iter: 46, Epoch: 300/328, MAELoss: 26288.686 / 1e6
# Iter: 46, Validating ...
# ====================================================================================================
# Iter: 46,	Training-MAELoss: 31862.099 / 1e6 (epoch), 2049.535 / 1e6 (batch)
# 		 Validating-MAELoss: 28983.204 / 1e6 (song),  1107.638 / 1e6 (batch)
# 		Similarity: 0.124 Difference: 1051.57 (Time: 2.77, Frequency: 3181.04, Power: 2.77)
# ====================================================================================================
# Iter: 47, Epoch: 50/326, MAELoss: 29557.018 / 1e6
# Iter: 47, Epoch: 100/326, MAELoss: 32222.658 / 1e6
# Iter: 47, Epoch: 150/326, MAELoss: 27443.969 / 1e6
# Iter: 47, Epoch: 200/326, MAELoss: 39981.003 / 1e6
# Iter: 47, Epoch: 250/326, MAELoss: 25832.651 / 1e6
# Iter: 47, Epoch: 300/326, MAELoss: 30219.984 / 1e6
# Iter: 47, Validating ...
# ====================================================================================================
# Iter: 47,	Training-MAELoss: 30522.776 / 1e6 (epoch), 1962.178 / 1e6 (batch)
# 		 Validating-MAELoss: 30219.038 / 1e6 (song),  1154.868 / 1e6 (batch)
# 		Similarity: 0.089 Difference: 1048.51 (Time: 2.76, Frequency: 3171.81, Power: 2.73)
# ====================================================================================================
# Iter: 48, Epoch: 50/333, MAELoss: 25710.697 / 1e6
# Iter: 48, Epoch: 100/333, MAELoss: 32442.591 / 1e6
# Iter: 48, Epoch: 150/333, MAELoss: 25601.515 / 1e6
# Iter: 48, Epoch: 200/333, MAELoss: 26521.834 / 1e6
# Iter: 48, Epoch: 250/333, MAELoss: 33632.066 / 1e6
# Iter: 48, Epoch: 300/333, MAELoss: 39618.025 / 1e6
# Iter: 48, Validating ...
# ====================================================================================================
# Iter: 48,	Training-MAELoss: 31173.262 / 1e6 (epoch), 2004.869 / 1e6 (batch)
# 		 Validating-MAELoss: 28181.546 / 1e6 (song),  1077.002 / 1e6 (batch)
# 		Similarity: 0.108 Difference: 1051.62 (Time: 2.77, Frequency: 3181.30, Power: 2.67)
# ====================================================================================================
# Iter: 49, Epoch: 50/328, MAELoss: 34814.604 / 1e6
# Iter: 49, Epoch: 100/328, MAELoss: 31742.665 / 1e6
# Iter: 49, Epoch: 150/328, MAELoss: 26535.430 / 1e6
# Iter: 49, Epoch: 200/328, MAELoss: 28586.147 / 1e6
# Iter: 49, Epoch: 250/328, MAELoss: 26475.853 / 1e6
# Iter: 49, Epoch: 300/328, MAELoss: 35841.890 / 1e6
# Iter: 49, Validating ...
# ====================================================================================================
# Iter: 49,	Training-MAELoss: 30879.689 / 1e6 (epoch), 1988.369 / 1e6 (batch)
# 		 Validating-MAELoss: 29456.983 / 1e6 (song),  1125.745 / 1e6 (batch)
# 		Similarity: 0.111 Difference: 1044.82 (Time: 2.75, Frequency: 3160.60, Power: 2.76)
# ====================================================================================================
# Iter: 50, Epoch: 50/315, MAELoss: 30172.986 / 1e6
# Iter: 50, Epoch: 100/315, MAELoss: 30928.877 / 1e6
# Iter: 50, Epoch: 150/315, MAELoss: 24506.846 / 1e6
# Iter: 50, Epoch: 200/315, MAELoss: 36989.291 / 1e6
# Iter: 50, Epoch: 250/315, MAELoss: 28166.743 / 1e6
# Iter: 50, Epoch: 300/315, MAELoss: 25725.970 / 1e6
# Iter: 50, Validating ...
# ====================================================================================================
# Iter: 50,	Training-MAELoss: 30021.258 / 1e6 (epoch), 1929.938 / 1e6 (batch)
# 		 Validating-MAELoss: 25297.246 / 1e6 (song),  966.774 / 1e6 (batch)
# 		Similarity: 0.143 Difference: 1048.34 (Time: 2.76, Frequency: 3171.37, Power: 2.65)
# ====================================================================================================
# Iter: 51, Epoch: 50/333, MAELoss: 48447.761 / 1e6
# Iter: 51, Epoch: 100/333, MAELoss: 30028.178 / 1e6
# Iter: 51, Epoch: 150/333, MAELoss: 23414.737 / 1e6
# Iter: 51, Epoch: 200/333, MAELoss: 23069.887 / 1e6
# Iter: 51, Epoch: 250/333, MAELoss: 28233.203 / 1e6
# Iter: 51, Epoch: 300/333, MAELoss: 26817.958 / 1e6
# Iter: 51, Validating ...
# ====================================================================================================
# Iter: 51,	Training-MAELoss: 30586.693 / 1e6 (epoch), 1968.028 / 1e6 (batch)
# 		 Validating-MAELoss: 28635.469 / 1e6 (song),  1094.349 / 1e6 (batch)
# 		Similarity: 0.113 Difference: 1045.48 (Time: 2.76, Frequency: 3162.75, Power: 2.63)
# ====================================================================================================
# Iter: 52, Epoch: 50/323, MAELoss: 36162.175 / 1e6
# Iter: 52, Epoch: 100/323, MAELoss: 29516.544 / 1e6
# Iter: 52, Epoch: 150/323, MAELoss: 35785.600 / 1e6
# Iter: 52, Epoch: 200/323, MAELoss: 37601.889 / 1e6
# Iter: 52, Epoch: 250/323, MAELoss: 19308.702 / 1e6
# Iter: 52, Epoch: 300/323, MAELoss: 26263.502 / 1e6
# Iter: 52, Validating ...
# ====================================================================================================
# Iter: 52,	Training-MAELoss: 30707.575 / 1e6 (epoch), 1975.806 / 1e6 (batch)
# 		 Validating-MAELoss: 27903.121 / 1e6 (song),  1066.361 / 1e6 (batch)
# 		Similarity: 0.115 Difference: 1049.10 (Time: 2.76, Frequency: 3173.61, Power: 2.72)
# ====================================================================================================
# Iter: 53, Epoch: 50/323, MAELoss: 31680.419 / 1e6
# Iter: 53, Epoch: 100/323, MAELoss: 32496.726 / 1e6
# Iter: 53, Epoch: 150/323, MAELoss: 28454.214 / 1e6
# Iter: 53, Epoch: 200/323, MAELoss: 35212.366 / 1e6
# Iter: 53, Epoch: 250/323, MAELoss: 25752.023 / 1e6
# Iter: 53, Epoch: 300/323, MAELoss: 28354.733 / 1e6
# Iter: 53, Validating ...
# ====================================================================================================
# Iter: 53,	Training-MAELoss: 30126.381 / 1e6 (epoch), 1936.696 / 1e6 (batch)
# 		 Validating-MAELoss: 30626.100 / 1e6 (song),  1170.424 / 1e6 (batch)
# 		Similarity: 0.071 Difference: 1049.22 (Time: 2.77, Frequency: 3173.99, Power: 2.71)
# ====================================================================================================
# Iter: 54, Epoch: 50/333, MAELoss: 23743.932 / 1e6
# Iter: 54, Epoch: 100/333, MAELoss: 20469.517 / 1e6
# Iter: 54, Epoch: 150/333, MAELoss: 34954.608 / 1e6
# Iter: 54, Epoch: 200/333, MAELoss: 39980.599 / 1e6
# Iter: 54, Epoch: 250/333, MAELoss: 31013.157 / 1e6
# Iter: 54, Epoch: 300/333, MAELoss: 35821.327 / 1e6
# Iter: 54, Validating ...
# ====================================================================================================
# Iter: 54,	Training-MAELoss: 30726.950 / 1e6 (epoch), 1957.967 / 1e6 (batch)
# 		 Validating-MAELoss: 31840.466 / 1e6 (song),  1216.833 / 1e6 (batch)
# 		Similarity: 0.096 Difference: 1047.41 (Time: 2.76, Frequency: 3168.40, Power: 2.80)
# ====================================================================================================
# Iter: 55, Epoch: 50/313, MAELoss: 34345.390 / 1e6
# Iter: 55, Epoch: 100/313, MAELoss: 23140.127 / 1e6
# Iter: 55, Epoch: 150/313, MAELoss: 40240.386 / 1e6
# Iter: 55, Epoch: 200/313, MAELoss: 22383.715 / 1e6
# Iter: 55, Epoch: 250/313, MAELoss: 23936.431 / 1e6
# Iter: 55, Epoch: 300/313, MAELoss: 34952.114 / 1e6
# Iter: 55, Validating ...
# ====================================================================================================
# Iter: 55,	Training-MAELoss: 30286.673 / 1e6 (epoch), 1949.082 / 1e6 (batch)
# 		 Validating-MAELoss: 29662.148 / 1e6 (song),  1133.585 / 1e6 (batch)
# 		Similarity: 0.081 Difference: 1046.36 (Time: 2.76, Frequency: 3165.35, Power: 2.68)
# ====================================================================================================
# Iter: 56, Epoch: 50/321, MAELoss: 36659.553 / 1e6
# Iter: 56, Epoch: 100/321, MAELoss: 29088.155 / 1e6
# Iter: 56, Epoch: 150/321, MAELoss: 25244.258 / 1e6
# Iter: 56, Epoch: 200/321, MAELoss: 31956.618 / 1e6
# Iter: 56, Epoch: 250/321, MAELoss: 30687.082 / 1e6
# Iter: 56, Epoch: 300/321, MAELoss: 24687.148 / 1e6
# Iter: 56, Validating ...
# ====================================================================================================
# Iter: 56,	Training-MAELoss: 30131.969 / 1e6 (epoch), 1938.244 / 1e6 (batch)
# 		 Validating-MAELoss: 27489.700 / 1e6 (song),  1050.562 / 1e6 (batch)
# 		Similarity: 0.093 Difference: 1049.24 (Time: 2.76, Frequency: 3174.05, Power: 2.69)
# ====================================================================================================
# Iter: 57, Epoch: 50/326, MAELoss: 26682.925 / 1e6
# Iter: 57, Epoch: 100/326, MAELoss: 31570.233 / 1e6
# Iter: 57, Epoch: 150/326, MAELoss: 31863.384 / 1e6
# Iter: 57, Epoch: 200/326, MAELoss: 28682.872 / 1e6
# Iter: 57, Epoch: 250/326, MAELoss: 33481.070 / 1e6
# Iter: 57, Epoch: 300/326, MAELoss: 25375.539 / 1e6
# Iter: 57, Validating ...
# ====================================================================================================
# Iter: 57,	Training-MAELoss: 29502.565 / 1e6 (epoch), 1896.593 / 1e6 (batch)
# 		 Validating-MAELoss: 26651.362 / 1e6 (song),  1018.523 / 1e6 (batch)
# 		Similarity: 0.124 Difference: 1046.21 (Time: 2.76, Frequency: 3164.97, Power: 2.61)
# ====================================================================================================
# Iter: 58, Epoch: 50/333, MAELoss: 37859.991 / 1e6
# Iter: 58, Epoch: 100/333, MAELoss: 21670.700 / 1e6
# Iter: 58, Epoch: 150/333, MAELoss: 37087.437 / 1e6
# Iter: 58, Epoch: 200/333, MAELoss: 35894.767 / 1e6
# Iter: 58, Epoch: 250/333, MAELoss: 27680.206 / 1e6
# Iter: 58, Epoch: 300/333, MAELoss: 19009.115 / 1e6
# Iter: 58, Validating ...
# ====================================================================================================
# Iter: 58,	Training-MAELoss: 29360.302 / 1e6 (epoch), 1882.682 / 1e6 (batch)
# 		 Validating-MAELoss: 26213.529 / 1e6 (song),  1001.791 / 1e6 (batch)
# 		Similarity: 0.119 Difference: 1049.72 (Time: 2.76, Frequency: 3175.52, Power: 2.68)
# ====================================================================================================
# Iter: 59, Epoch: 50/316, MAELoss: 29784.806 / 1e6
# Iter: 59, Epoch: 100/316, MAELoss: 30805.677 / 1e6
# Iter: 59, Epoch: 150/316, MAELoss: 30731.984 / 1e6
# Iter: 59, Epoch: 200/316, MAELoss: 33231.937 / 1e6
# Iter: 59, Epoch: 250/316, MAELoss: 33000.719 / 1e6
# Iter: 59, Epoch: 300/316, MAELoss: 21509.080 / 1e6
# Iter: 59, Validating ...
# ====================================================================================================
# Iter: 59,	Training-MAELoss: 29791.608 / 1e6 (epoch), 1917.223 / 1e6 (batch)
# 		 Validating-MAELoss: 27586.339 / 1e6 (song),  1054.255 / 1e6 (batch)
# 		Similarity: 0.131 Difference: 1047.77 (Time: 2.76, Frequency: 3169.59, Power: 2.70)
# ====================================================================================================
# Iter: 60, Epoch: 50/321, MAELoss: 33082.184 / 1e6
# Iter: 60, Epoch: 100/321, MAELoss: 32140.707 / 1e6
# Iter: 60, Epoch: 150/321, MAELoss: 30834.687 / 1e6
# Iter: 60, Epoch: 200/321, MAELoss: 26490.450 / 1e6
# Iter: 60, Epoch: 250/321, MAELoss: 35362.841 / 1e6
# Iter: 60, Epoch: 300/321, MAELoss: 21990.954 / 1e6
# Iter: 60, Validating ...
# ====================================================================================================
# Iter: 60,	Training-MAELoss: 29403.325 / 1e6 (epoch), 1885.596 / 1e6 (batch)
# 		 Validating-MAELoss: 24851.320 / 1e6 (song),  949.732 / 1e6 (batch)
# 		Similarity: 0.133 Difference: 1045.98 (Time: 2.76, Frequency: 3164.23, Power: 2.64)
# ====================================================================================================
# Iter: 61, Epoch: 50/315, MAELoss: 22140.288 / 1e6
# Iter: 61, Epoch: 100/315, MAELoss: 17473.531 / 1e6
# Iter: 61, Epoch: 150/315, MAELoss: 23084.211 / 1e6
# Iter: 61, Epoch: 200/315, MAELoss: 37102.108 / 1e6
# Iter: 61, Epoch: 250/315, MAELoss: 27378.225 / 1e6
# Iter: 61, Epoch: 300/315, MAELoss: 42573.390 / 1e6
# Iter: 61, Validating ...
# ====================================================================================================
# Iter: 61,	Training-MAELoss: 30313.386 / 1e6 (epoch), 1951.348 / 1e6 (batch)
# 		 Validating-MAELoss: 28621.082 / 1e6 (song),  1093.799 / 1e6 (batch)
# 		Similarity: 0.106 Difference: 1048.92 (Time: 2.76, Frequency: 3173.02, Power: 2.77)
# ====================================================================================================
# Iter: 62, Epoch: 50/318, MAELoss: 27921.826 / 1e6
# Iter: 62, Epoch: 100/318, MAELoss: 27117.345 / 1e6
# Iter: 62, Epoch: 150/318, MAELoss: 38066.807 / 1e6
# Iter: 62, Epoch: 200/318, MAELoss: 26906.886 / 1e6
# Iter: 62, Epoch: 250/318, MAELoss: 26527.604 / 1e6
# Iter: 62, Epoch: 300/318, MAELoss: 26249.441 / 1e6
# Iter: 62, Validating ...
# ====================================================================================================
# Iter: 62,	Training-MAELoss: 29286.050 / 1e6 (epoch), 1883.830 / 1e6 (batch)
# 		 Validating-MAELoss: 26839.917 / 1e6 (song),  1025.729 / 1e6 (batch)
# 		Similarity: 0.109 Difference: 1046.79 (Time: 2.76, Frequency: 3166.66, Power: 2.67)
# ====================================================================================================
# Iter: 63, Epoch: 50/326, MAELoss: 35525.953 / 1e6
# Iter: 63, Epoch: 100/326, MAELoss: 26734.801 / 1e6
# Iter: 63, Epoch: 150/326, MAELoss: 22105.897 / 1e6
# Iter: 63, Epoch: 200/326, MAELoss: 30657.293 / 1e6
# Iter: 63, Epoch: 250/326, MAELoss: 35291.506 / 1e6
# Iter: 63, Epoch: 300/326, MAELoss: 24634.256 / 1e6
# Iter: 63, Validating ...
# ...
# Iter: 180, Epoch: 300/333, MAELoss: 20373.965 / 1e6
# Iter: 180, Validating ...
# ====================================================================================================
# Iter: 180,	Training-MAELoss: 23839.569 / 1e6 (epoch), 1533.212 / 1e6 (batch)
# 		 Validating-MAELoss: 21449.435 / 1e6 (song),  819.724 / 1e6 (batch)
# 		Similarity: 0.091 Difference: 1047.64 (Time: 2.76, Frequency: 3169.21, Power: 2.70)
# ====================================================================================================
# Iter: 181, Epoch: 50/328, MAELoss: 40796.894 / 1e6
# Iter: 181, Epoch: 100/328, MAELoss: 12587.830 / 1e6
# Iter: 181, Epoch: 150/328, MAELoss: 28062.178 / 1e6
# Iter: 181, Epoch: 200/328, MAELoss: 30490.605 / 1e6
# Iter: 181, Epoch: 250/328, MAELoss: 15533.502 / 1e6
# Iter: 181, Epoch: 300/328, MAELoss: 20017.107 / 1e6
# Iter: 181, Validating ...
# ====================================================================================================
# Iter: 181,	Training-MAELoss: 24358.925 / 1e6 (epoch), 1568.342 / 1e6 (batch)
# 		 Validating-MAELoss: 21594.101 / 1e6 (song),  825.252 / 1e6 (batch)
# 		Similarity: 0.086 Difference: 1049.20 (Time: 2.76, Frequency: 3173.91, Power: 2.72)
# ====================================================================================================
# Iter: 182, Epoch: 50/316, MAELoss: 21795.633 / 1e6
# Iter: 182, Epoch: 100/316, MAELoss: 23490.646 / 1e6
# Iter: 182, Epoch: 150/316, MAELoss: 18838.366 / 1e6
# Iter: 182, Epoch: 200/316, MAELoss: 20340.171 / 1e6
# Iter: 182, Epoch: 250/316, MAELoss: 22312.975 / 1e6
# Iter: 182, Epoch: 300/316, MAELoss: 35075.510 / 1e6
# Iter: 182, Validating ...
# ====================================================================================================
# Iter: 182,	Training-MAELoss: 24111.734 / 1e6 (epoch), 1550.715 / 1e6 (batch)
# 		 Validating-MAELoss: 71407.121 / 1e6 (song),  2728.935 / 1e6 (batch)
# 		Similarity: 0.049 Difference: 1056.75 (Time: 2.77, Frequency: 3185.26, Power: 14.23)
# ====================================================================================================
# Iter: 183, Epoch: 50/328, MAELoss: 24263.140 / 1e6
# Iter: 183, Epoch: 100/328, MAELoss: 43916.999 / 1e6
# Iter: 183, Epoch: 150/328, MAELoss: 30453.738 / 1e6
# Iter: 183, Epoch: 200/328, MAELoss: 21149.337 / 1e6
# Iter: 183, Epoch: 250/328, MAELoss: 12228.703 / 1e6
# Iter: 183, Epoch: 300/328, MAELoss: 15424.364 / 1e6
# Iter: 183, Validating ...
# ====================================================================================================
# Iter: 183,	Training-MAELoss: 24340.167 / 1e6 (epoch), 1567.134 / 1e6 (batch)
# 		 Validating-MAELoss: 28125.412 / 1e6 (song),  1074.857 / 1e6 (batch)
# 		Similarity: 0.081 Difference: 1055.70 (Time: 2.78, Frequency: 3189.64, Power: 6.68)
# ====================================================================================================
# Iter: 184, Epoch: 50/316, MAELoss: 12632.648 / 1e6
# Iter: 184, Epoch: 100/316, MAELoss: 26174.497 / 1e6
# Iter: 184, Epoch: 150/316, MAELoss: 26504.399 / 1e6
# Iter: 184, Epoch: 200/316, MAELoss: 39600.012 / 1e6
# Iter: 184, Epoch: 250/316, MAELoss: 21230.572 / 1e6
# Iter: 184, Epoch: 300/316, MAELoss: 19538.761 / 1e6
# Iter: 184, Validating ...
# ====================================================================================================
# Iter: 184,	Training-MAELoss: 24023.793 / 1e6 (epoch), 1545.754 / 1e6 (batch)
# 		 Validating-MAELoss: 53188.550 / 1e6 (song),  2032.683 / 1e6 (batch)
# 		Similarity: 0.051 Difference: 1057.28 (Time: 2.77, Frequency: 3193.11, Power: 7.99)
# ====================================================================================================
# Iter: 185, Epoch: 50/323, MAELoss: 23986.980 / 1e6
# Iter: 185, Epoch: 100/323, MAELoss: 18136.060 / 1e6
# Iter: 185, Epoch: 150/323, MAELoss: 16763.399 / 1e6
# Iter: 185, Epoch: 200/323, MAELoss: 23562.895 / 1e6
# Iter: 185, Epoch: 250/323, MAELoss: 22645.408 / 1e6
# Iter: 185, Epoch: 300/323, MAELoss: 34835.739 / 1e6
# Iter: 185, Validating ...
# ====================================================================================================
# Iter: 185,	Training-MAELoss: 24651.522 / 1e6 (epoch), 1586.144 / 1e6 (batch)
# 		 Validating-MAELoss: 25466.079 / 1e6 (song),  973.226 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1036.01 (Time: 2.73, Frequency: 3133.07, Power: 3.62)
# ====================================================================================================
# Iter: 186, Epoch: 50/323, MAELoss: 17758.697 / 1e6
# Iter: 186, Epoch: 100/323, MAELoss: 33042.641 / 1e6
# Iter: 186, Epoch: 150/323, MAELoss: 24676.159 / 1e6
# Iter: 186, Epoch: 200/323, MAELoss: 23295.420 / 1e6
# Iter: 186, Epoch: 250/323, MAELoss: 21346.263 / 1e6
# Iter: 186, Epoch: 300/323, MAELoss: 21716.866 / 1e6
# Iter: 186, Validating ...
# ====================================================================================================
# Iter: 186,	Training-MAELoss: 24092.825 / 1e6 (epoch), 1549.499 / 1e6 (batch)
# 		 Validating-MAELoss: 23873.868 / 1e6 (song),  912.377 / 1e6 (batch)
# 		Similarity: 0.085 Difference: 1048.82 (Time: 2.76, Frequency: 3172.38, Power: 3.10)
# ====================================================================================================
# Iter: 187, Epoch: 50/328, MAELoss: 24635.743 / 1e6
# Iter: 187, Epoch: 100/328, MAELoss: 26291.469 / 1e6
# Iter: 187, Epoch: 150/328, MAELoss: 21798.148 / 1e6
# Iter: 187, Epoch: 200/328, MAELoss: 15104.526 / 1e6
# Iter: 187, Epoch: 250/328, MAELoss: 23415.400 / 1e6
# Iter: 187, Epoch: 300/328, MAELoss: 26961.271 / 1e6
# Iter: 187, Validating ...
# ====================================================================================================
# Iter: 187,	Training-MAELoss: 24383.051 / 1e6 (epoch), 1568.165 / 1e6 (batch)
# 		 Validating-MAELoss: 223631.278 / 1e6 (song),  8546.418 / 1e6 (batch)
# 		Similarity: 0.061 Difference: 1106.34 (Time: 2.81, Frequency: 3223.52, Power: 126.23)
# ====================================================================================================
# Iter: 188, Epoch: 50/328, MAELoss: 25375.614 / 1e6
# Iter: 188, Epoch: 100/328, MAELoss: 26896.184 / 1e6
# Iter: 188, Epoch: 150/328, MAELoss: 21363.340 / 1e6
# Iter: 188, Epoch: 200/328, MAELoss: 33169.853 / 1e6
# Iter: 188, Epoch: 250/328, MAELoss: 19870.732 / 1e6
# Iter: 188, Epoch: 300/328, MAELoss: 17694.903 / 1e6
# Iter: 188, Validating ...
# ====================================================================================================
# Iter: 188,	Training-MAELoss: 23691.743 / 1e6 (epoch), 1523.041 / 1e6 (batch)
# 		 Validating-MAELoss: 24729.124 / 1e6 (song),  945.062 / 1e6 (batch)
# 		Similarity: 0.089 Difference: 1058.46 (Time: 2.79, Frequency: 3200.73, Power: 3.94)
# ====================================================================================================
# Iter: 189, Epoch: 50/333, MAELoss: 29281.813 / 1e6
# Iter: 189, Epoch: 100/333, MAELoss: 25738.497 / 1e6
# Iter: 189, Epoch: 150/333, MAELoss: 24774.086 / 1e6
# Iter: 189, Epoch: 200/333, MAELoss: 23498.529 / 1e6
# Iter: 189, Epoch: 250/333, MAELoss: 27735.395 / 1e6
# Iter: 189, Epoch: 300/333, MAELoss: 16485.933 / 1e6
# Iter: 189, Validating ...
# ====================================================================================================
# Iter: 189,	Training-MAELoss: 24070.685 / 1e6 (epoch), 1540.992 / 1e6 (batch)
# 		 Validating-MAELoss: 31727.467 / 1e6 (song),  1212.515 / 1e6 (batch)
# 		Similarity: 0.090 Difference: 1060.48 (Time: 2.79, Frequency: 3201.63, Power: 9.17)
# ====================================================================================================
# Iter: 190, Epoch: 50/316, MAELoss: 12054.507 / 1e6
# Iter: 190, Epoch: 100/316, MAELoss: 25767.412 / 1e6
# Iter: 190, Epoch: 150/316, MAELoss: 27599.513 / 1e6
# Iter: 190, Epoch: 200/316, MAELoss: 31605.024 / 1e6
# Iter: 190, Epoch: 250/316, MAELoss: 30816.312 / 1e6
# Iter: 190, Epoch: 300/316, MAELoss: 20441.527 / 1e6
# Iter: 190, Validating ...
# ====================================================================================================
# Iter: 190,	Training-MAELoss: 24052.164 / 1e6 (epoch), 1542.306 / 1e6 (batch)
# 		 Validating-MAELoss: 37216.515 / 1e6 (song),  1422.287 / 1e6 (batch)
# 		Similarity: 0.062 Difference: 1040.15 (Time: 2.73, Frequency: 3135.42, Power: 13.83)
# ====================================================================================================
# Iter: 191, Epoch: 50/316, MAELoss: 20977.505 / 1e6
# Iter: 191, Epoch: 100/316, MAELoss: 18291.322 / 1e6
# Iter: 191, Epoch: 150/316, MAELoss: 19469.145 / 1e6
# Iter: 191, Epoch: 200/316, MAELoss: 29489.215 / 1e6
# Iter: 191, Epoch: 250/316, MAELoss: 30563.808 / 1e6
# Iter: 191, Epoch: 300/316, MAELoss: 22105.846 / 1e6
# Iter: 191, Validating ...
# ====================================================================================================
# Iter: 191,	Training-MAELoss: 24637.768 / 1e6 (epoch), 1585.259 / 1e6 (batch)
# 		 Validating-MAELoss: 33456.588 / 1e6 (song),  1278.596 / 1e6 (batch)
# 		Similarity: 0.082 Difference: 1055.08 (Time: 2.77, Frequency: 3184.04, Power: 10.40)
# ====================================================================================================
# Iter: 192, Epoch: 50/323, MAELoss: 32730.762 / 1e6
# Iter: 192, Epoch: 100/323, MAELoss: 23220.348 / 1e6
# Iter: 192, Epoch: 150/323, MAELoss: 32820.027 / 1e6
# Iter: 192, Epoch: 200/323, MAELoss: 19303.260 / 1e6
# Iter: 192, Epoch: 250/323, MAELoss: 29002.355 / 1e6
# Iter: 192, Epoch: 300/323, MAELoss: 11680.229 / 1e6
# Iter: 192, Validating ...
# ====================================================================================================
# Iter: 192,	Training-MAELoss: 24032.771 / 1e6 (epoch), 1541.062 / 1e6 (batch)
# 		 Validating-MAELoss: 31098.759 / 1e6 (song),  1188.488 / 1e6 (batch)
# 		Similarity: 0.069 Difference: 1075.05 (Time: 2.83, Frequency: 3246.98, Power: 7.91)
# ====================================================================================================
# Iter: 193, Epoch: 50/316, MAELoss: 19303.280 / 1e6
# Iter: 193, Epoch: 100/316, MAELoss: 24609.550 / 1e6
# Iter: 193, Epoch: 150/316, MAELoss: 27017.153 / 1e6
# Iter: 193, Epoch: 200/316, MAELoss: 23793.382 / 1e6
# Iter: 193, Epoch: 250/316, MAELoss: 16110.253 / 1e6
# Iter: 193, Epoch: 300/316, MAELoss: 34198.604 / 1e6
# Iter: 193, Validating ...
# ====================================================================================================
# Iter: 193,	Training-MAELoss: 23818.142 / 1e6 (epoch), 1531.833 / 1e6 (batch)
# 		 Validating-MAELoss: 24286.977 / 1e6 (song),  928.165 / 1e6 (batch)
# 		Similarity: 0.059 Difference: 1052.49 (Time: 2.77, Frequency: 3182.74, Power: 3.83)
# ====================================================================================================
# Iter: 194, Epoch: 50/328, MAELoss: 19101.309 / 1e6
# Iter: 194, Epoch: 100/328, MAELoss: 31082.882 / 1e6
# Iter: 194, Epoch: 150/328, MAELoss: 27183.271 / 1e6
# Iter: 194, Epoch: 200/328, MAELoss: 18807.356 / 1e6
# Iter: 194, Epoch: 250/328, MAELoss: 31682.636 / 1e6
# Iter: 194, Epoch: 300/328, MAELoss: 20214.557 / 1e6
# Iter: 194, Validating ...
# ====================================================================================================
# Iter: 194,	Training-MAELoss: 24253.406 / 1e6 (epoch), 1560.959 / 1e6 (batch)
# 		 Validating-MAELoss: 33703.456 / 1e6 (song),  1288.030 / 1e6 (batch)
# 		Similarity: 0.071 Difference: 1056.04 (Time: 2.78, Frequency: 3186.36, Power: 10.99)
# ====================================================================================================
# Iter: 195, Epoch: 50/320, MAELoss: 24536.533 / 1e6
# Iter: 195, Epoch: 100/320, MAELoss: 31080.234 / 1e6
# Iter: 195, Epoch: 150/320, MAELoss: 18210.191 / 1e6
# Iter: 195, Epoch: 200/320, MAELoss: 23341.950 / 1e6
# Iter: 195, Epoch: 250/320, MAELoss: 27762.214 / 1e6
# Iter: 195, Epoch: 300/320, MAELoss: 18007.878 / 1e6
# Iter: 195, Validating ...
# ====================================================================================================
# Iter: 195,	Training-MAELoss: 24224.788 / 1e6 (epoch), 1558.687 / 1e6 (batch)
# 		 Validating-MAELoss: 21643.053 / 1e6 (song),  827.123 / 1e6 (batch)
# 		Similarity: 0.070 Difference: 1051.95 (Time: 2.77, Frequency: 3182.51, Power: 2.45)
# ====================================================================================================
# Iter: 196, Epoch: 50/323, MAELoss: 26836.946 / 1e6
# Iter: 196, Epoch: 100/323, MAELoss: 21611.230 / 1e6
# Iter: 196, Epoch: 150/323, MAELoss: 24329.718 / 1e6
# Iter: 196, Epoch: 200/323, MAELoss: 20518.213 / 1e6
# Iter: 196, Epoch: 250/323, MAELoss: 23607.389 / 1e6
# Iter: 196, Epoch: 300/323, MAELoss: 19342.367 / 1e6
# Iter: 196, Validating ...
# ====================================================================================================
# Iter: 196,	Training-MAELoss: 24184.425 / 1e6 (epoch), 1554.713 / 1e6 (batch)
# 		 Validating-MAELoss: 31257.191 / 1e6 (song),  1194.542 / 1e6 (batch)
# 		Similarity: 0.082 Difference: 1067.13 (Time: 2.81, Frequency: 3221.40, Power: 9.52)
# ====================================================================================================
# Iter: 197, Epoch: 50/333, MAELoss: 26739.085 / 1e6
# Iter: 197, Epoch: 100/333, MAELoss: 35453.370 / 1e6
# Iter: 197, Epoch: 150/333, MAELoss: 17323.789 / 1e6
# Iter: 197, Epoch: 200/333, MAELoss: 20974.915 / 1e6
# Iter: 197, Epoch: 250/333, MAELoss: 20899.504 / 1e6
# Iter: 197, Epoch: 300/333, MAELoss: 19623.510 / 1e6
# Iter: 197, Validating ...
# ====================================================================================================
# Iter: 197,	Training-MAELoss: 24147.801 / 1e6 (epoch), 1553.035 / 1e6 (batch)
# 		 Validating-MAELoss: 37703.921 / 1e6 (song),  1440.914 / 1e6 (batch)
# 		Similarity: 0.082 Difference: 1044.55 (Time: 2.74, Frequency: 3148.00, Power: 14.55)
# ====================================================================================================
# Iter: 198, Epoch: 50/328, MAELoss: 21440.684 / 1e6
# Iter: 198, Epoch: 100/328, MAELoss: 29430.277 / 1e6
# Iter: 198, Epoch: 150/328, MAELoss: 21935.528 / 1e6
# Iter: 198, Epoch: 200/328, MAELoss: 25063.092 / 1e6
# Iter: 198, Epoch: 250/328, MAELoss: 24471.443 / 1e6
# Iter: 198, Epoch: 300/328, MAELoss: 25147.989 / 1e6
# Iter: 198, Validating ...
# ====================================================================================================
# Iter: 198,	Training-MAELoss: 23683.199 / 1e6 (epoch), 1515.055 / 1e6 (batch)
# 		 Validating-MAELoss: 26902.577 / 1e6 (song),  1028.124 / 1e6 (batch)
# 		Similarity: 0.083 Difference: 1050.36 (Time: 2.77, Frequency: 3174.59, Power: 5.57)
# ====================================================================================================
# Iter: 199, Epoch: 50/326, MAELoss: 26122.167 / 1e6
# Iter: 199, Epoch: 100/326, MAELoss: 17163.348 / 1e6
# Iter: 199, Epoch: 150/326, MAELoss: 18186.557 / 1e6
# Iter: 199, Epoch: 200/326, MAELoss: 24147.351 / 1e6
# Iter: 199, Epoch: 250/326, MAELoss: 24443.600 / 1e6
# Iter: 199, Epoch: 300/326, MAELoss: 25240.220 / 1e6
# Iter: 199, Validating ...
# ====================================================================================================
# Iter: 199,	Training-MAELoss: 24164.980 / 1e6 (epoch), 1553.463 / 1e6 (batch)
# 		 Validating-MAELoss: 25868.507 / 1e6 (song),  988.605 / 1e6 (batch)
# 		Similarity: 0.083 Difference: 1047.62 (Time: 2.76, Frequency: 3166.53, Power: 5.32)
# ====================================================================================================
# Iter: 200, Epoch: 50/333, MAELoss: 22649.693 / 1e6
# Iter: 200, Epoch: 100/333, MAELoss: 25107.349 / 1e6
# Iter: 200, Epoch: 150/333, MAELoss: 25015.956 / 1e6
# Iter: 200, Epoch: 200/333, MAELoss: 16351.481 / 1e6
# Iter: 200, Epoch: 250/333, MAELoss: 23144.780 / 1e6
# Iter: 200, Epoch: 300/333, MAELoss: 30566.431 / 1e6
# Iter: 200, Validating ...
# ====================================================================================================
# Iter: 200,	Training-MAELoss: 23926.083 / 1e6 (epoch), 1538.776 / 1e6 (batch)
# 		 Validating-MAELoss: 32552.481 / 1e6 (song),  1244.044 / 1e6 (batch)
# 		Similarity: 0.064 Difference: 1059.96 (Time: 2.79, Frequency: 3201.52, Power: 7.70)
# ====================================================================================================

# %% [markdown]
# ## Save Stats

# %%
np.save(f'experiments/{trial_type}_MLP/stats.npy', stats)

# %% [markdown]
# # Results

# %% [markdown]
# # Load Stats to Dataframe

# %%
stats = list(np.load(f'experiments/{trial_type}_MLP/stats.npy', allow_pickle=True))
stats_df = pd.DataFrame(list(stats))
stats_df.to_excel(f'experiments/{trial_type}_MLP/stats.xlsx')
stats_df
# Out:
#      iteration trial_type loss_mode  train_loss  \
# 0            1     LISTEN       MAE    0.003641
# 1            2     LISTEN       MAE    0.002566
# 2            3     LISTEN       MAE    0.002518
# 3            4     LISTEN       MAE    0.002480
# 4            5     LISTEN       MAE    0.002514
# ..         ...        ...       ...         ...
# 195        196     LISTEN       MAE    0.001555
# 196        197     LISTEN       MAE    0.001553
# 197        198     LISTEN       MAE    0.001515
# 198        199     LISTEN       MAE    0.001553
# 199        200     LISTEN       MAE    0.001539
#
#                                         train_loss_raw  train_epoch  \
# 0    [0.24374379217624664, 0.2982974648475647, 0.28...          328
# 1    [0.02829229086637497, 0.025615017861127853, 0....          323
# 2    [0.04696027189493179, 0.035090796649456024, 0....          328
# 3    [0.030347133055329323, 0.045269083231687546, 0...          333
# 4    [0.026779457926750183, 0.022081151604652405, 0...          333
# ..                                                 ...          ...
# 195  [0.03382384777069092, 0.03209744393825531, 0.0...          333
# 196  [0.016055818647146225, 0.018732864409685135, 0...          328
# 197  [0.021082138642668724, 0.012506254017353058, 0...          326
# 198  [0.031104009598493576, 0.029032867401838303, 0...          333
# 199  [0.022228026762604713, 0.026860440149903297, 0...          328
#
#      train_batch                                     valid_loss_raw  \
# 0           5100  [0.056356124579906464, 0.04746891185641289, 0....
# 1           5020  [0.03402983024716377, 0.03762032836675644, 0.1...
# 2           5100  [0.030790939927101135, 0.03678964823484421, 0....
# 3           5180  [0.028609806671738625, 0.02840692177414894, 0....
# 4           5180  [0.054821886122226715, 0.041976358741521835, 0...
# ..           ...                                                ...
# 195         5180  [0.07035327702760696, 0.01492150966078043, 0.1...
# 196         5100  [0.12303337454795837, 0.05975168198347092, 0.1...
# 197         5096  [0.0443667434155941, 0.017064057290554047, 0.1...
# 198         5180  [0.0360972061753273, 0.0343361459672451, 0.151...
# 199         5100  [0.05546727031469345, 0.026280920952558517, 0....
#
#                                        valid_loss_data  valid_loss  ...  \
# 0    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001807  ...
# 1    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001549  ...
# 2    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001567  ...
# 3    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001372  ...
# 4    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001658  ...
# ..                                                 ...         ...  ...
# 195  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001195  ...
# 196  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001441  ...
# 197  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001028  ...
# 198  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.000989  ...
# 199  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001244  ...
#
#                                        test_loss_micro  \
# 0    [0.0008715074352654824, 0.0003872659021210902,...
# 1    [0.000838082866841664, 0.00033077840907288217,...
# 2    [0.000844689700933336, 0.0003305079562121353, ...
# 3    [0.0008427123771226907, 0.0002947680198033908,...
# 4    [0.000837073665204686, 0.0003484691644917285, ...
# ..                                                 ...
# 195  [0.0004943119966803759, 0.00016107215780158002...
# 196  [0.0004922096084043817, 0.00021201050955854445...
# 197  [0.0004924863803942869, 0.00012365465043383896...
# 198  [0.000492681366388466, 0.00010161093740594426,...
# 199  [0.0004913177929955265, 0.00017104851646587943...
#
#                                        test_loss_macro  \
# 0    [0.044882632916172345, 0.03589954912662506, 0....
# 1    [0.043161267642345694, 0.030663158521056177, 0...
# 2    [0.04350151959806681, 0.030638087540864944, 0....
# 3    [0.04339968742181857, 0.027324995435774328, 0....
# 4    [0.04310929375804133, 0.032303091548383234, 0....
# ..                                                 ...
# 195  [0.02545706782903936, 0.014931389028206468, 0....
# 196  [0.02534879483282566, 0.01965337423607707, 0.1...
# 197  [0.02536304859030578, 0.01146278609521687, 0.1...
# 198  [0.025373090369005997, 0.009419333897531032, 0...
# 199  [0.025302866339269613, 0.015856197476387023, 0...
#
#                                    test_difference_raw  \
# 0    {0: [(0.35672290139226087, 228.30265689104715,...
# 1    {0: [(0.3416668271426484, 218.66676937129512, ...
# 2    {0: [(0.32583890392646025, 208.53689851293473,...
# 3    {0: [(0.3247470155476504, 207.8380899504964, 0...
# 4    {0: [(0.34930109212055105, 223.55269895715284,...
# ..                                                 ...
# 195  {0: [(0.34115247065446297, 218.33758121885649,...
# 196  {0: [(0.3394471147448111, 217.24615343667926, ...
# 197  {0: [(0.3410130573079574, 218.24835667709291, ...
# 198  {0: [(0.34028218398041554, 217.7805977474661, ...
# 199  {0: [(0.33930837926705015, 217.15736273091227,...
#
#                                        test_difference  \
# 0    [1410.7057847814353, 34.56937908819747, 11993....
# 1    [1408.7166639747636, 42.297981817661636, 11936...
# 2    [1409.1196806611924, 43.062451924498376, 11942...
# 3    [1397.4375174019942, 36.4023133125038, 11817.2...
# 4    [1403.1159663910018, 39.599600627816265, 11887...
# ..                                                 ...
# 195  [1405.399747882516, 35.808173391503566, 11918....
# 196  [1405.0730769892725, 37.77174281795872, 11917....
# 197  [1405.0571935772032, 36.106303197057365, 11919...
# 198  [1404.4309709407162, 35.4998594389853, 11913.3...
# 199  [1405.270518261262, 37.10853291003001, 11919.0...
#
#                                    test_similarity_raw  \
# 0    {0: [0.0397498719394207, 0.020078472793102264,...
# 1    {0: [0.04911421611905098, 0.027000421658158302...
# 2    {0: [0.0466371551156044, 0.012001543305814266,...
# 3    {0: [0.029819391667842865, -0.0034203240647912...
# 4    {0: [0.014004360884428024, 0.00690278410911560...
# ..                                                 ...
# 195  {0: [0.05884319916367531, 0.10494282096624374,...
# 196  {0: [0.0601755827665329, 0.1098998636007309, 0...
# 197  {0: [0.0606023333966732, 0.11327797174453735, ...
# 198  {0: [0.060921650379896164, 0.10245462507009506...
# 199  {0: [0.04574892669916153, 0.07853922992944717,...
#
#                                        test_similarity  train_loss_epoch  \
# 0    [0.033001346172144015, 0.022101899087429048, 0...          0.056612
# 1    [0.045083711451540394, 0.02786125909537077, 0....          0.039875
# 2    [0.041321008207483426, 0.023674766216427088, 0...          0.039149
# 3    [0.03582321292487904, 0.030796921029686928, 0....          0.038579
# 4    [0.02206641607400444, 0.02804079694673419, 0.0...          0.039108
# ..                                                 ...               ...
# 195  [0.06896456307731569, 0.20694935888051988, 0.0...          0.024184
# 196  [0.06633659496696459, 0.20880974914878606, 0.0...          0.024148
# 197  [0.0689049032309817, 0.21309291534125804, 0.00...          0.023683
# 198  [0.06615384346288111, 0.21835436552762985, 0.0...          0.024165
# 199  [0.04817657703533769, 0.17518084164708853, 0.0...          0.023926
#
#      train_loss_batch                               valid_similarity_raw  \
# 0            0.003641  [0.03183363750576973, 0.017476892098784447, 0....
# 1            0.002566  [0.031564466655254364, 0.03629706799983978, 0....
# 2            0.002518  [0.04128201678395271, 0.06159442290663719, 0.0...
# 3            0.002480  [0.05202455446124077, 0.05024462193250656, 0.0...
# 4            0.002514  [0.023777857422828674, 0.020548194646835327, 0...
# ..                ...                                                ...
# 195          0.001555  [0.08029791712760925, 0.10684320330619812, 0.0...
# 196          0.001553  [0.04093625769019127, 0.07526896148920059, 0.0...
# 197          0.001515  [0.11023809015750885, 0.1004982739686966, 0.03...
# 198          0.001553  [0.0907331183552742, 0.07215011864900589, 0.01...
# 199          0.001539  [0.06515030562877655, 0.06864618510007858, 0.0...
#
#                                   valid_difference_raw
# 0    [[0.2053403013704037, 210.26846860329343, 9.57...
# 1    [[0.2228736385285468, 228.22260585323187, 1.74...
# 2    [[0.22900503226317223, 234.5011530374883, 1.01...
# 3    [[0.225344934038505, 230.7532124554291, 1.0711...
# 4    [[0.20878568678702916, 213.7965432699178, 13.3...
# ..                                                 ...
# 195  [[0.3775456544104385, 386.606750116289, 58.740...
# 196  [[0.298276924163128, 305.4355703430429, 101.83...
# 197  [[0.25558091299586533, 261.7148549077661, 25.6...
# 198  [[0.2678620692376215, 274.2907588993243, 22.02...
# 199  [[0.25699677916772584, 263.1647018677512, 31.4...
#
# [200 rows x 34 columns]

# %% [markdown]
# ## Training - Validating Plots

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot')
line_train = ax.plot(range(1, num_iteration + 1), stats_df['train_loss'], color='tab:blue')
line_valid = ax.plot(range(1, num_iteration + 1), stats_df['valid_loss'], color='tab:orange')
line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

# ax2 = ax.twinx()
# line_valid_macro = ax2.plot(range(1, num_iteration + 1), stats_df['valid_loss_macro'], color='tab:green', alpha=.7)

ax.legend(line_train + line_valid + [line_best], ['Train', 'Valid', 'best'])

ax.set_ylim(stats_df['train_loss'].min() * .2, stats_df['train_loss'].max() * .9)
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.subplots()
ax1.set_title('MAE vs Structural Similarity Plot')
line_train = ax1.plot(range(1, num_iteration + 1), stats_df['train_loss_raw'].apply(lambda x: np.sum(x))/stats_df['train_batch'], color='tab:blue')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
line_valid = ax2.plot(range(1, num_iteration + 1), stats_df['valid_similarity'], color='tab:orange')
line_best = ax2.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')

ax1.legend(line_train + line_valid + [line_best], ['Train (MAE)', 'Valid (SSIM)', 'Best (SSIM)'])
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Mean Absolute Error', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2.set_ylabel('Structural Similarity', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')
# line_best = ax.vlines(stats_df['best_sim'], ymin=0, ymax=stats_df['best_sim'], colors='tab:green', linewidth=0.3, linestyles='--')

ax1.set_xticks(range(0, num_iteration + 1, 10))
plt.show()

# %% [markdown]
# ## Testing Plots

# %% [markdown]
# ### Known / Unknown / New Subjects

# %%
stat_to_plot = np.stack(stats_df['test_loss_micro'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot - Known vs Unknown vs New-Subject')
line_known = ax.plot(range(1, num_iteration + 1), stats_df['valid_loss'], color='tab:blue')
line_unknown = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_MUSIC], color='tab:orange')
line_newsub = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_SUB], color='tab:green', alpha=.7)
line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_known + line_newsub + line_unknown + [line_best], ['Known-Songs (Valid)', 'New-Subject', 'Unknown-Songs', 'Best'])
plt.show()

# %%
stat_to_plot = np.stack(stats_df['test_similarity'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Structural Similarity Plot - Known vs Unknown vs New-Subject')
line_known = ax.plot(range(1, num_iteration + 1), stats_df['valid_similarity'], color='tab:blue')
line_unknown = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_MUSIC], color='tab:orange')
line_newsub = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_SUB], color='tab:green')
line_best = ax.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Structural Similarity')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_unknown + line_known + line_newsub + [line_best], ['Unknown-Songs', 'Known-Songs (Valid)', 'New-Subject', 'Best'])
plt.show()

# %% [markdown]
# ### By Instruments

# %%
stat_to_plot = np.stack(stats_df['test_loss_macro'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot - By Instruments')
line_celesta = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_CELESTA], color='tab:blue')
line_trombone = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_TROMBONE], color='tab:orange')
line_violin = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_VIOLIN], color='tab:green', alpha=.7)
# line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_celesta + line_trombone + line_violin, ['Celesta', 'Trombone', 'Violin'])
plt.show()

# %%
stat_to_plot = np.stack(stats_df['test_similarity'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Structural Similarity Plot - By Instruments')
line_celesta = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_CELESTA], color='tab:blue')
line_trombone = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_TROMBONE], color='tab:orange')
line_violin = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_VIOLIN], color='tab:green', alpha=.7)
line_best = ax.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Structural Similarity')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_celesta + line_trombone + line_violin + [line_best], ['Celesta', 'Trombone', 'Violin', 'Best SSIM'])
plt.show()

# %% [markdown]
# ## Recovered Music

# %%
def predict_sample():
    sample_event_idx = events_iter(batch_size=batch_size, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids, shuffle=True)[0][0]
    eeg_start, eeg_stop, mid, _, version, _ = data_events_info[sample_event_idx]
    sample_music = musics[version][mid]
    
    eeg_indices = [
        np.arange(eeg_start, eeg_stop, window_length),  # EEG-start
        np.concatenate([np.arange(eeg_start + window_length, eeg_stop, window_length), [eeg_stop]]) # EEG-stop
    ]
    batch_input = []
    for sample_start, sample_stop in zip(*eeg_indices):
        batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
    batch_input = net.transform_input(np.stack(batch_input))
    cutoff = eeg_indices[0].shape[0] * music_window_length
    sample_wav = padding(sample_music['wav-low'][:cutoff], cutoff)
    with th.no_grad():
        outputs = net(th.Tensor(batch_input).to(device))
        if net_has_state:
            outputs, states = outputs
        predict_wav = outputs.flatten().cpu().numpy()
    
    fig = plt.figure(figsize=(6, 9))
    axes = fig.subplots(nrows=3)

    axes[0].plot(sample_wav, color='tab:blue')
    axes[0].plot(predict_wav, color='tab:orange')
    axes[0].set_title('Music wave')
    axes[0].set_xticks([])

    org_D = librosa.amplitude_to_db(np.abs(librosa.stft(sample_wav, n_fft=64)), ref=np.max)
    pred_D = librosa.amplitude_to_db(np.abs(librosa.stft(predict_wav, n_fft=64)), ref=np.max)
    librosa.display.specshow(org_D, y_axis='linear', ax=axes[1])
    librosa.display.specshow(pred_D, y_axis='linear',  ax=axes[2])
    axes[1].set(title='Original - Spectrogram')
    axes[2].set(title='Predict - Spectrogram')
    plt.show()
    
    return sample_wav, predict_wav

# %% [markdown]
# ### By Best Similarity Model

# %%
net.load_state_dict(th.load(f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-sim-iter-{best_sim_iter:03d}.pt'))
# Out:
# <All keys matched successfully>

# %%
predict_sample();

# %%
predict_sample();

# %% [markdown]
# ### By Best Loss Model

# %%
net.load_state_dict(th.load(f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-loss-iter-{best_iter:03d}.pt'))
# Out:
# <All keys matched successfully>

# %%
predict_sample();

# %%
predict_sample();
