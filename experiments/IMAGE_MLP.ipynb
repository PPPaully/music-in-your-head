# %%
import mne
import librosa
import numpy as np
import pandas as pd
import torch as th
import torch.nn as nn
from time import time

from torchinfo import summary

# from https://github.com/Po-Hsun-Su/pytorch-ssim
import pytorch_ssim as ssim

import matplotlib.pyplot as plt
import librosa.display
from ipywidgets import IntProgress
from IPython.display import display, Audio

# %% [markdown]
# # Music Data

# %%
musics = np.load('omiir_music.npy', allow_pickle=True).item()

# %% [markdown]
# ## Preparation - Resampling, STFT, etc.

# %%
def prepare_downsampling(target_sr, stft=False, stft_window=256):
    for version in musics.keys():
        for mid, music in musics[version].items():
            wav = (music['wav'] - music['wav'].mean())/music['wav'].std()
            music['wav-low'] = librosa.resample(wav, orig_sr=music['rate'], target_sr=target_sr)
            music['rate-low'] = target_sr
            music['sample-low'] = music['wav-low'].shape[0]
            music['onset-low'] = np.round(music['onset']/music['rate']*music['rate-low']).astype(int)
            music['onset_woc-low'] = np.round(music['onset_woc']/music['rate']*music['rate-low']).astype(int)
            music['beat-low'] = np.round(music['beat']/music['rate']*music['rate-low']).astype(int)
            music['beat_woc-low'] = np.round(music['beat_woc']/music['rate']*music['rate-low']).astype(int)
            
            if stft:
                music['stft-low'] = librosa.stft(music['wav-low'], hop_length=stft_window, win_length=stft_window)

            music['audio'] = Audio(data=wav, rate=music['rate'])
            music['audio-low'] = Audio(data=librosa.resample(music['wav-low'], orig_sr=target_sr, target_sr=music['rate']), rate=music['rate'])

# %% [markdown]
# # EEG Data

# %%
data_eeg = mne.io.read_raw_fif('omiir_all_preprocessed.fif', preload=True)
EEG_RATE = data_eeg.info['sfreq']
data_eeg
# Out:
# Opening raw data file omiir_all_preprocessed.fif...
#     Range : 0 ... 1287637 =      0.000 ... 20119.328 secs
# Ready.
# C:\Users\Paul\AppData\Local\Temp\ipykernel_132416\1980649454.py:1: RuntimeWarning: This filename (omiir_all_preprocessed.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data_eeg = mne.io.read_raw_fif('omiir_all_preprocessed.fif', preload=True)
# Reading 0 ... 1287637  =      0.000 ... 20119.328 secs...
# <Raw | omiir_all_preprocessed.fif, 70 x 1287638 (20119.3 s), ~687.8 MB, data loaded>

# %% [markdown]
# ## Preprocess - Standardization + Trim

# %%
data_eeg_raw = data_eeg.get_data('eeg')

print(f"Size in memory: {data_eeg_raw.size * data_eeg_raw.itemsize / 1e6:.2f} mb")

subids_idx = data_eeg.get_data('SUBID').reshape(-1).astype(int)
subids = sorted(set(subids_idx))

z_cutoff = 2
start_idx = 0
for subid in subids:
    end_idx = np.searchsorted(subids_idx, subid, side='right')
    mean = data_eeg_raw[:, start_idx:end_idx].mean(axis=1)
    std = data_eeg_raw[:, start_idx:end_idx].std(axis=1)
    t = data_eeg_raw[:, start_idx:end_idx].transpose()
    standardized = ((t - mean)/std).transpose()
    
    data_eeg_raw[:, start_idx:end_idx] = np.clip(standardized, a_min=-z_cutoff, a_max=z_cutoff)/z_cutoff  # Clip + Scale to -1>1
# Out:
# Size in memory: 659.27 mb

# %% [markdown]
# ## Events

# %%
def sep_event_id(eid):
    '''
        return: music-id(str), trial_type(int), version(str)
    '''
    return f'{int(str(eid)[:-2]):02d}', int(str(eid)[-2]), f'v{str(eid)[-1]}'

# %%
data_events = mne.find_events(data_eeg, initial_event=True)
data_events_info = np.hstack([
    data_events[:, 0].reshape(-1, 1),  # start
    np.concatenate([data_events[1:, 0], [data_eeg.last_samp - 1]]).reshape(-1, 1), # end
    np.asarray([sep_event_id(eid) for eid in data_events[:, 2]], dtype='object'),  # music-id, trial_type, version
    data_eeg.get_data('SUBID')[0, data_events[:, 0]].astype(int).reshape(-1, 1)  # subid
])
# Out:
# 1620 events found
# Event IDs: [ 111  112  121  122  131  132  211  212  221  222  231  232  311  312
#   321  322  331  332  411  412  421  422  431  432 1111 1112 1121 1122
#  1131 1132 1211 1212 1221 1222 1231 1232 1311 1312 1321 1322 1331 1332
#  1411 1412 1421 1422 1431 1432 2111 2112 2121 2122 2131 2132 2211 2212
#  2221 2222 2231 2232 2311 2312 2321 2322 2331 2332 2411 2412 2421 2422
#  2431 2432]

# %% [markdown]
# # Dataset Selection

# %%
idx_EEG_START, idx_EEG_STOP, idx_MID, idx_TRIAL, idx_VERSION, idx_SUBID = 0, 1, 2, 3, 4, 5
TRIAL = dict(
    LISTEN=1,
    IMAGE=2,
    IMAGE_WOC=3,
)

# %%
def events_iter(batch_size, filter_trial_type=None, filter_subject_ids=None, custom_filter=None, shuffle=False):
    # Filter
    events_filter = np.ones(data_events_info.shape[0]).astype(bool)
    if filter_trial_type is not None:
        events_filter &= data_events_info[:, idx_TRIAL] == filter_trial_type
    if filter_subject_ids is not None:
        events_filter &= np.isin(data_events_info[:, idx_SUBID], filter_subject_ids)
    if custom_filter is not None:
        events_filter &= custom_filter
    
    events_idx = np.argwhere(events_filter).reshape(-1)
    
    # Shuffle
    if shuffle:
        np.random.shuffle(events_idx)
    
    # Return
    res = []
    for i in range(0, events_idx.shape[0], batch_size):
        j = min(events_idx.shape[0], i+batch_size)
        res.append(events_idx[i: j])
    return res

# %%
def array_iter(arr, shuffle=False, extend=None):
    indices = np.arange(arr.shape[0])
    if shuffle:
        np.random.shuffle(indices)
    
    res = []
    for idx in indices:
        res.append(arr[idx])
    
    if extend is not None:
        length = len(indices)
        for idx in range(extend-length):
            res.append(arr[indices[idx % length]])
    
    return res

# %%
def padding(arr, window_length, axis=0):
    if arr.shape[axis] < window_length:
        return np.pad(arr, [(0, window_length-d) if i == axis else (0, 0) for i, d in enumerate(arr.shape)], constant_values=(0))
    return arr

# %%
def make_iteration(indices, window_length, testing_mode=False, shuffle=True):
    io_indices = []
    music_data = []
    for eeg_start, eeg_stop, mid, _, version, _ in data_events_info[indices]:
        music = musics[version][mid]
        music_data.append(music['wav-low'])
        music_window_length = window_length/EEG_RATE*music['rate-low']
        if not music_window_length.is_integer():
            print(f'Warning: music_window_length is not integer ({music_window_length}), will be floored to {int(music_window_length)}')
        music_window_length = int(music_window_length)

        eeg_indices = [
            np.arange(eeg_start, eeg_stop, window_length),  # EEG-start
            np.concatenate([np.arange(eeg_start + window_length, eeg_stop, window_length), [eeg_stop]]) # EEG-stop
        ]
        
        cutoff = eeg_indices[0].shape[0]  # Bug: music fraction after eeg end.
        music_indices = [
            np.arange(0, music['sample-low'], music_window_length)[:cutoff],  # Music-start
            np.concatenate([np.arange(music_window_length, music['sample-low'], music_window_length), [(music['sample-low'])]])[:cutoff]  # Music-stop
        ]
        start_stop = np.stack(eeg_indices + music_indices, axis=1)
        io_indices.append(start_stop)

    max_iter = max(map(lambda x: len(x), io_indices))
    io_list = [array_iter(io, shuffle=shuffle, extend=None if testing_mode else max_iter) for io in io_indices]
    
    return max_iter, io_list, music_data

# %%
def training_iter(indices, window_length, shuffle=True):
    max_iter, io_list, music_data = make_iteration(indices, window_length, shuffle=shuffle)

    batch_data = []
    for it in range(max_iter):
        batch_input = []
        batch_output = []
        for io, wav in zip(io_list, music_data):
            sample_start, sample_stop, music_start, music_stop = io[it]
            batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
            batch_output.append(padding(wav[music_start: music_stop], window_length=music_window_length))
        batch_data.append((np.stack(batch_input), np.stack(batch_output)))
    return batch_data

# %%
def testing_iter(indices, window_length, shuffle=False):
    _, io_list, music_data = make_iteration(indices, window_length, testing_mode=True, shuffle=shuffle)
    
    batch_data = []
    for io, wav in zip(io_list, music_data):
        batch_input = []
        batch_output = []
        for sample_start, sample_stop, music_start, music_stop in io:
            batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
            batch_output.append(padding(wav[music_start: music_stop], window_length=music_window_length))
        batch_data.append((np.stack(batch_input), np.stack(batch_output)))
        
    return batch_data

# %% [markdown]
# ## Train-Test Split

# %% [markdown]
# ```
# Training Set - SUB[MID(------), (------),        ]
# Testing Set -  SUB[                   NEW(------)]
#            NEW-SUB[(------),            ,(------)]
# ```

# %% [markdown]
# SUBJECT v1 {1, 4, 6, 7} v2 {9, 11, 12, 13, 14}

# %% [markdown]
# | ID | Name                                | Meter | Length | Tempo   | Train/Test | Note |
# |----|-------------------------------------|-------|--------|---------|------------|------|
# |  1 | Chim Chim Cheree (lyrics)           |   3/4 |  13.3s | 212 BPM | Mixed      |
# |  2 | TakeMe Out to the Ballgame (lyrics) |   3/4 |   7.7s | 189 BPM | Mixed      |
# |  3 | Jingle Bells (lyrics)               |   4/4 |   9.7s | 200 BPM | Mixed      | Train/Test: Training Subject/Testing Only Subject (v1 == v2)
# |  4 | Mary Had a Little Lamb (lyrics)     |   4/4 |  11.6s | 160 BPM |  Test Only | (v1 == v2) > Unknown Song Experiment
# | 11 | Chim Chim Cheree                    |   3/4 |  13.5s | 212 BPM | Mixed      | No lyrics
# | 12 | TakeMe Out to the Ballgame          |   3/4 |   7.7s | 189 BPM | Mixed      | No lyrics
# | 13 | Jingle Bells                        |   4/4 |   9.0s | 200 BPM | Mixed      | Nixing - No lyrics (v1 == v2)
# | 14 | Mary Had a Little Lamb              |   4/4 |  12.2s | 160 BPM |  Test Only | Piano -  No lyrics (v1 == v2) > Unknown Song Experiment
# | 21 | EmperorWaltz                        |   3/4 |   8.3s | 178 BPM | Mixed      | Orchestra
# | 22 | Hedwig’s Theme (Harry Potter)       |   3/4 |  16.0s | 166 BPM | Mixed      | "Celesta" > Instrument Experiment
# | 23 | ImperialMarch (StarWars Theme)      |   4/4 |   9.2s | 104 BPM | Mixed      | "Trombone" > Instrument Experiment
# | 24 | Eine Kleine Nachtmusik              |   4/4 |   6.9s | 140 BPM | Mixed      | "Violin" > Instrument Experiment
# |    |                                mean |       |  10.4s | 176 BPM |

# %%
TRAIN_IDS = [
    ('02', 1),
    ('03', 1),
    ('12', 1),
    ('13', 1),
    ('21', 1),
    ('23', 1),
    ('24', 1),
    
    ('01', 4),
    ('03', 4),
    ('11', 4),
    ('13', 4),
    ('21', 4),
    ('22', 4),
    ('24', 4),
    
    ('01', 6),
    ('02', 6),
    ('11', 6),
    ('12', 6),
    ('21', 6),
    ('22', 6),
    ('23', 6),
    
    ('02', 7),
    ('03', 7),
    ('12', 7),
    ('13', 7),
    ('22', 7),
    ('23', 7),
    ('24', 7),
    
]

# %%
VALID_IDS = [
    ('01', 1),
    ('11', 1),
    ('22', 1),
    
    ('02', 4),
    ('12', 4),
    ('23', 4),
    
    ('03', 6),
    ('13', 6),
    ('24', 6), 
    
    ('01', 7),
    ('11', 7),
    ('21', 7),
]

# %%
TEST_NEW_SUB = [
    # New Subject (SUBID=9)
    ('01', 9),
    ('02', 9),
    ('03', 9),
    ('11', 9),
    ('12', 9),
    ('13', 9),
    ('21', 9),
    ('22', 9),
    ('23', 9),
    
    # New Subject (SUBID=11)
    ('01', 11),
    ('02', 11),
    ('03', 11),
    ('11', 11),
    ('12', 11),
    ('13', 11),
    ('21', 11),
    ('22', 11),
    ('23', 11),
]

TEST_NEW_MUSIC = [
    # New Music '04' '14'
    ('04', 1),
    ('04', 4),
    ('04', 6),
    ('04', 9),
    ('04', 11),
    
    ('14', 1),
    ('14', 4),
    ('14', 6),
    ('14', 9),
    ('14', 11),
]

TEST_INSTRUMENT_CELESTA = [
    # Celesta
    ('22', 9),
    ('22', 11),
]
TEST_INSTRUMENT_TROMBONE = [
    # Trombone
    ('23', 9),
    ('23', 11),
]
TEST_INSTRUMENT_VIOLIN = [
    # Violin
    ('24', 9),
    ('24', 11),
]

# %%
train_custom_filter = list(map(lambda x: tuple(x) in TRAIN_IDS, data_events_info[:, [idx_MID, idx_SUBID]]))
valid_custom_filter = list(map(lambda x: tuple(x) in VALID_IDS, data_events_info[:, [idx_MID, idx_SUBID]]))

experiments_list = [TEST_NEW_SUB, TEST_NEW_MUSIC, TEST_INSTRUMENT_CELESTA, TEST_INSTRUMENT_TROMBONE, TEST_INSTRUMENT_VIOLIN]
ID_TEST_NEW_SUB    = 0
ID_TEST_NEW_MUSIC  = 1
ID_TEST_INSTRUMENT_CELESTA  = 2
ID_TEST_INSTRUMENT_TROMBONE = 3
ID_TEST_INSTRUMENT_VIOLIN   = 4

test_filter_list = [list(map(lambda x: tuple(x) in exp, data_events_info[:, [idx_MID, idx_SUBID]])) for exp in experiments_list]
# These filter will be merged with filter_trial_type

# %% [markdown]
# ## Debug

# %%
# batch_size = 16
# window_length = 32
# trial_type = TRIAL['LISTEN']
# sub_ids = [1]
# seed = 42
# np.random.seed(seed)

# from collections import Counter
# Counter(data_events_info[(data_events_info[:, idx_TRIAL] == 1) & np.isin(data_events_info[:, idx_SUBID], [1])][:, idx_MID])

# %%
# total_time = 0
# last = time()
# progress = IntProgress(min=0, max=296, style={'description_width': '250px'})
# progress.description = '0/296'
# display(progress)

# epoch = 0
# for indices in events_iter(batch_size=batch_size, filter_trial_type=trial_type, filter_subject_ids=sub_ids, shuffle=True):
#     for batch_input, batch_output in training_iter(indices, window_length=window_length):
#         now = time()
#         epoch += 1
#         total_time += now - last
#         last = now
#         progress.value = epoch
#         if epoch % 10 == 0:
#             progress.description = f'total: {total_time:.2f}, avg: {total_time/epoch*1000:.2f} ms, {epoch}/296'
# progress.description = f'total: {total_time:.2f} secs, avg: {total_time/epoch*1000:.2f} ms, Done'

# %% [markdown]
# # Model

# %% [markdown]
# ## MLP (WAV)

# %%
class MLPModel(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        
        self.linears = nn.Sequential(
            nn.Linear(input_size, 2 ** 10),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 10),
            nn.Linear(2 ** 10, 2 ** 9),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 9),
            nn.Linear(2 ** 9, 2 ** 8),
            nn.Tanh(),
            nn.BatchNorm1d(2 ** 8),
            nn.Linear(2 ** 8, output_size),
            nn.Tanh(),
        )
        
    def forward(self, X):
        return self.linears(X)
    
    @staticmethod
    def transform_input(X):
        # batch_input = (batch_size, number_channel, window_length)
        # target (batch, input)
        return X.reshape(X.shape[0], -1)

# %% [markdown]
# ## BiLSTM (WAV)

# %%
# class LSTMModel(nn.Module):
#     def __init__(self, input_size, feature_size, num_layer, hidden_size, output_size):
#         super().__init__()
        
#         self.linears = nn.Sequential(
#             nn.Linear(input_size, feature_size),
#             nn.Tanh(),
#         )
        
#         self.lstm = nn.LSTM(
#             input_size=feature_size,
#             hidden_size=hidden_size,
#             num_layers=num_layer,
#             bidirectional=True,
#             batch_first=True
#         )
#         self.tanh = nn.Tanh()
        
#         self.mlp = nn.Sequential(
#             nn.Linear(hidden_size*2, hidden_size),
#             nn.Tanh(),
#             nn.Linear(hidden_size, hidden_size//2),
#             nn.Tanh(),
#             nn.Linear(hidden_size//2, output_size),
#         )
    
#     def forward(self, X, state=None):
#         out_1 = self.linears(X)
#         state = None
#         out_2 = []
#         for inp in out_1:
#             out, (hn, cn) = self.lstm(inp, state)
#             out_2.append(out)
#         out_2 = self.tanh(th.stack(out_2))
        
#         out_3 = self.mlp(out_2).flatten(start_dim=1)
        
#         return out_3, (hn, cn)
    
#     @staticmethod
#     def transform_input(X):
#         # batch_input = (batch_size, number_channel, window_length)
#         # target (batch, length, input)
#         return X.transpose(0, 2, 1)

# %% [markdown]
# # Configure

# %%
# Music Data
music_rate = 64
enable_stft = False
stft_window = None

# Data
trial_type = 'IMAGE' # 'IMAGE' 'IMAGE_WOC'
filter_trial_type = TRIAL[trial_type]
sub_ids = None

# Model
batch_size = 16
number_channel = 64
window_length = 32
feature_size = 256
hidden_size = 256
num_layer = 4

# Train/Test
num_iteration = 200

# State
seed = 42
np.random.seed(seed)



# DO NOT CHANGE
prepare_downsampling(target_sr=music_rate, stft=enable_stft, stft_window=stft_window)
music_window_length = window_length/EEG_RATE*music_rate
if not music_window_length.is_integer():
    raise Exception('Configure Error: music_window_length must be integer')
music_window_length = int(music_window_length)

output_size = 1

# %% [markdown]
# # Initialize

# %%
device = th.device('cuda' if th.cuda.is_available() else 'cpu')

# %%
# net = LSTMModel(
#     input_size=number_channel,
#     feature_size=feature_size,
#     num_layer=num_layer,
#     hidden_size=hidden_size,
#     output_size=output_size,
# ).to(device)
# net_has_state = True

# %%
net = MLPModel(
    input_size=number_channel * window_length,
    output_size=music_window_length,
).to(device)
net_has_state = False

# %%
summary(net, (1, number_channel * window_length))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPModel                                 [1, 32]                   --
# ├─Sequential: 1-1                        [1, 32]                   --
# │    └─Linear: 2-1                       [1, 1024]                 2,098,176
# │    └─Tanh: 2-2                         [1, 1024]                 --
# │    └─BatchNorm1d: 2-3                  [1, 1024]                 2,048
# │    └─Linear: 2-4                       [1, 512]                  524,800
# │    └─Tanh: 2-5                         [1, 512]                  --
# │    └─BatchNorm1d: 2-6                  [1, 512]                  1,024
# │    └─Linear: 2-7                       [1, 256]                  131,328
# │    └─Tanh: 2-8                         [1, 256]                  --
# │    └─BatchNorm1d: 2-9                  [1, 256]                  512
# │    └─Linear: 2-10                      [1, 32]                   8,224
# │    └─Tanh: 2-11                        [1, 32]                   --
# ==========================================================================================
# Total params: 2,766,112
# Trainable params: 2,766,112
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.77
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.03
# Params size (MB): 11.06
# Estimated Total Size (MB): 11.10
# ==========================================================================================

# %%
criterion = nn.L1Loss()  # Must edit a stats_dict if change.
optimizer = th.optim.Adam(net.parameters(), lr=0.001)

# %%
ssim_criterion = ssim.SSIM(size_average=False)

# %% [markdown]
# # Training Model

# %% [markdown]
# ## Stats

# %%
stats = []
stats_dict = dict(
    iteration=0,
    trial_type=trial_type,
    loss_mode='MAE',
    
    train_loss=0.0,
    train_loss_raw=[],
    train_epoch=0,
    train_batch=0,
    
    valid_loss_raw=[],
    valid_loss_data=[],
    valid_loss=0.0,  # Equal micro
    valid_loss_micro=0.0,
    valid_loss_macro=0.0,
    valid_epoch=0,
    valid_batch=0,
    valid_difference=[],
    valid_similarity=[],
    
    best_loss=0.0,
    best_iteration=None,
    
    best_sim=0.0,
    best_sim_iteration=None,
    
    test_epoch=0,
    test_batch=0,
    
    test_loss_data=dict(),
    test_loss_raw=dict(),
    test_loss_micro=[],
    test_loss_macro=[],
    test_difference_raw=dict(),
    test_difference=[],
    test_similarity_raw=dict(),
    test_similarity=[],
)

# %%
def compute_difference(ref_rec, input_rec, weightage=[0.33,0.33,0.33]):
    ## Time domain similarity
    ref_time = np.correlate(ref_rec,ref_rec)
    inp_time = np.correlate(ref_rec,input_rec)
    diff_time = abs(ref_time-inp_time)
    
    ## Freq domain similarity
    ref_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(ref_rec)) 
    inp_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(input_rec))
    diff_freq = abs(ref_freq-inp_freq)
    
    ## Power similarity
    ref_power = np.sum(ref_rec**2)
    inp_power = np.sum(input_rec**2)
    diff_power = abs(ref_power-inp_power)
    
    return diff_time[0], diff_freq[0], diff_power, weightage[0] * diff_time[0] + weightage[1] * diff_freq[0] + weightage[2] * diff_power

# %%
def stft_tensor(wav, n_fft=64):
    stft = th.abs(th.stft(th.Tensor(wav), n_fft=n_fft, return_complex=True))
    return stft.view((1, 1) + tuple(stft.size()))

# %% [markdown]
# ## Train/Valid

# %%
interation_progress = IntProgress(min=0, max=num_iteration)
interation_progress.value = 0
interation_progress.description = f'Iter: 0/{num_iteration}'
display(interation_progress)

train_progress = IntProgress(min=0, max=500)
train_progress.value = 0
max_train_epoch = '???'
train_progress.description = f'Train 0/{max_train_epoch}'
display(train_progress)

valid_progress = IntProgress(min=0, max=100)
valid_progress.value = 0
max_valid_epoch = '???'
valid_progress.description = f'Validate 0/{max_valid_epoch}'
display(valid_progress)

test_progress = IntProgress(min=0, max=100)
test_progress.value = 0
max_test_epoch = '???'
test_progress.description = f'Test 0/{max_test_epoch}'
display(test_progress)

best_loss = None
best_iter = 0

best_sim = None
best_sim_iter = 0

for iteration in range(1, num_iteration + 1):
    interation_progress.value = iteration
    interation_progress.description = f'Iter: {iteration}/{num_iteration}'
    
    monitor_loss = 0
    n_monitor = 50
    
    train_loss = []
    train_epoch = 0
    train_batch = 0
    net.train()
    for indices in events_iter(
            batch_size=batch_size, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=train_custom_filter,
            shuffle=True
    ):
        for batch_input, batch_output in training_iter(indices, window_length=window_length, shuffle=True):
            train_epoch += 1
            train_batch += batch_input.shape[0]
            train_progress.value = train_epoch
            train_progress.description = f'Train {train_epoch}/{max_train_epoch}'
            
            # batch_input = (batch_size, number_channel, window_length)
            X = th.Tensor(net.transform_input(batch_input)).to(device)
            Y = th.Tensor(batch_output).to(device)

            output = net(X)
            if net_has_state:
                output, state = output
            loss = criterion(output, Y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
            monitor_loss += loss.item()
            
            if train_epoch % n_monitor == 0:
                print(f'Iter: {iteration}, Epoch: {train_epoch}/{max_train_epoch}, MAELoss: {monitor_loss/n_monitor*1e6:.3f} / 1e6')
                monitor_loss = 0
    
    train_progress.max = max_train_epoch = train_epoch
    train_progress.description = f'Training Done'
    print(f'Iter: {iteration}, Validating ...')

    valid_loss = []
    valid_loss_data = []
    valid_difference = []
    valid_similarity = []
    valid_epoch = 0
    valid_batch = 0
    net.eval()
    for indices in events_iter(
            batch_size=1, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=valid_custom_filter,
            shuffle=False,
    ):
        valid_loss_data.append(data_events_info[indices][:, [idx_MID, idx_VERSION, idx_SUBID]])
        for batch_input, batch_output in testing_iter(indices, window_length=window_length, shuffle=False):
            valid_epoch += 1
            valid_batch += batch_input.shape[0]
            valid_progress.value = valid_epoch
            valid_progress.description = f'Validate {valid_epoch}/{max_valid_epoch}'
            
            # batch_input = (batch_size, number_channel, window_length)
            X = th.Tensor(net.transform_input(batch_input)).to(device)
            Y = th.Tensor(batch_output).to(device)
            
            with th.no_grad():
                output = net(X)
                if net_has_state:
                    output, state = output
                loss = criterion(output, Y)
            
            valid_loss.append(loss.item())
            
            wy = batch_output.flatten()
            wx = output.flatten().cpu().numpy()
            valid_difference.append(compute_difference(wy, wx))
            valid_similarity.append(ssim_criterion(stft_tensor(wx), stft_tensor(wy)).item())
    
    similarity = np.mean(np.abs(valid_similarity))
    difference = np.mean(valid_difference, axis=0)
    valid_progress.max = max_valid_epoch = valid_epoch
    valid_progress.description = f'Validate Done'
    
    temp_stats = stats_dict.copy()
    temp_stats['iteration'] = iteration
    
    temp_stats['train_epoch'] = train_epoch
    temp_stats['train_batch'] = train_batch
    
    temp_stats['train_loss'] = np.sum(train_loss)/train_batch  # batch
    temp_stats['train_loss_raw'] = np.asarray(train_loss)
    temp_stats['train_loss_epoch'] = np.mean(train_loss)
    temp_stats['train_loss_batch'] = np.sum(train_loss)/train_batch
    
    temp_stats['valid_epoch'] = valid_epoch
    temp_stats['valid_batch'] = valid_batch
    
    temp_stats['valid_loss_raw'] = np.asarray(valid_loss)
    temp_stats['valid_loss'] = np.sum(valid_loss)/valid_batch  # batch (*best model)
    temp_stats['valid_loss_micro'] = np.sum(valid_loss)/valid_batch  # by batch
    temp_stats['valid_loss_macro'] = np.mean(valid_loss)  # by number of songs
    temp_stats['valid_loss_data'] = np.concatenate(valid_loss_data)
    
    temp_stats['valid_similarity_raw'] = np.asarray(valid_similarity)
    temp_stats['valid_similarity'] = np.mean(np.abs(valid_similarity))  # (*best similar model)
    temp_stats['valid_difference_raw'] = np.asarray(valid_difference)
    temp_stats['valid_difference'] = difference[3]
    
    print(f'''====================================================================================================
Iter: {iteration},\tTraining-MAELoss: {temp_stats['train_loss_epoch']*1e6:.3f} / 1e6 (epoch), {temp_stats['train_loss_batch']*1e6:.3f} / 1e6 (batch)
\t\t Validating-MAELoss: {temp_stats['valid_loss_macro']*1e6:.3f} / 1e6 (song),  {temp_stats['valid_loss_micro']*1e6:.3f} / 1e6 (batch)
\t\tSimilarity: {similarity:.3f} Difference: {difference[3]:.2f} (Time: {difference[0]:.2f}, Frequency: {difference[1]:.2f}, Power: {difference[2]:.2f})
====================================================================================================''')
        
    if iteration % 20 == 0:
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-iter-{iteration:03d}.pt')
    
    if best_loss is None or temp_stats['valid_loss'] < best_loss:
        best_iter = iteration
        best_loss = temp_stats['valid_loss']
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-loss-iter-{best_iter:03d}.pt')
    
    if best_sim is None or similarity > best_sim:
        best_sim_iter = iteration
        best_sim = similarity
        th.save(net.state_dict(), f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-sim-iter-{best_sim_iter:03d}.pt')
        
    
    temp_stats['best_loss'] = best_loss
    temp_stats['best_iteration'] = best_iter
    
    temp_stats['best_sim'] = best_sim
    temp_stats['best_sim_iteration'] = best_sim_iter
    
    
    test_epoch = 0
    test_batch = 0
    test_loss_data = dict()
    test_loss = dict()
    test_difference = dict()
    test_similarity = dict()
    
    for test_id, experiment_filter in enumerate(test_filter_list):
        test_loss_data[test_id] = []
        test_loss[test_id] = []
        test_difference[test_id] = []
        test_similarity[test_id] = []
        
        for indices in events_iter(
            batch_size=1, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids,
            custom_filter=experiment_filter,
            shuffle=False,
        ):
            test_loss_data[test_id].append(data_events_info[indices][:, [idx_MID, idx_VERSION, idx_SUBID]])
            for batch_input, batch_output in testing_iter(indices, window_length=window_length, shuffle=False):
                test_epoch += 1
                test_batch += batch_input.shape[0]
                test_progress.value = test_epoch
                test_progress.description = f'Test {test_epoch}/{max_test_epoch}'

                # batch_input = (batch_size, number_channel, window_length)
                X = th.Tensor(net.transform_input(batch_input)).to(device)
                Y = th.Tensor(batch_output).to(device)

                with th.no_grad():
                    output = net(X)
                    if net_has_state:
                        output, state = output
                    loss = criterion(output, Y)

                test_loss[test_id].append(loss.item())

                wy = batch_output.flatten()
                wx = output.flatten().cpu().numpy()
                test_difference[test_id].append(compute_difference(wy, wx))
                test_similarity[test_id].append(ssim_criterion(stft_tensor(wx), stft_tensor(wy)).item())
    
    test_progress.max = max_test_epoch = test_epoch
    test_progress.description = f'Test Done'
    
    temp_stats['test_epoch'] = test_epoch
    temp_stats['test_batch'] = test_batch
    
    temp_stats['test_loss_data'] = test_loss_data
    temp_stats['test_loss_raw'] = test_loss
    temp_stats['test_difference_raw'] = test_difference
    temp_stats['test_similarity_raw'] = test_similarity
    
    temp_stats['test_loss_micro'] = []
    temp_stats['test_loss_macro'] = []
    temp_stats['test_difference'] = []
    temp_stats['test_similarity'] = []
    for test_id in range(len(experiments_list)):
        temp_stats['test_loss_micro'].append(np.sum(test_loss[test_id])/test_batch)
        temp_stats['test_loss_macro'].append(np.mean(test_loss[test_id]))
        temp_stats['test_difference'].append(np.mean(test_difference[test_id], axis=0)[3])
        temp_stats['test_similarity'].append(np.mean(np.abs(test_similarity[test_id])))
    
    stats.append(temp_stats)
# Out:
# IntProgress(value=0, description='Iter: 0/200', max=200)
# IntProgress(value=0, description='Train 0/???', max=500)
# IntProgress(value=0, description='Validate 0/???')
# IntProgress(value=0, description='Test 0/???')
# Iter: 1, Epoch: 50/???, MAELoss: 149147.893 / 1e6
# Iter: 1, Epoch: 100/???, MAELoss: 56588.713 / 1e6
# Iter: 1, Epoch: 150/???, MAELoss: 46928.890 / 1e6
# Iter: 1, Epoch: 200/???, MAELoss: 47128.089 / 1e6
# Iter: 1, Epoch: 250/???, MAELoss: 37077.447 / 1e6
# Iter: 1, Epoch: 300/???, MAELoss: 34518.631 / 1e6
# Iter: 1, Validating ...
# ====================================================================================================
# Iter: 1,	Training-MAELoss: 60465.255 / 1e6 (epoch), 3888.746 / 1e6 (batch)
# 		 Validating-MAELoss: 46752.753 / 1e6 (song),  1786.729 / 1e6 (batch)
# 		Similarity: 0.030 Difference: 1056.49 (Time: 2.78, Frequency: 3194.88, Power: 3.84)
# ====================================================================================================
# Iter: 2, Epoch: 50/328, MAELoss: 41824.947 / 1e6
# Iter: 2, Epoch: 100/328, MAELoss: 39158.907 / 1e6
# Iter: 2, Epoch: 150/328, MAELoss: 34437.708 / 1e6
# Iter: 2, Epoch: 200/328, MAELoss: 38193.583 / 1e6
# Iter: 2, Epoch: 250/328, MAELoss: 38122.067 / 1e6
# Iter: 2, Epoch: 300/328, MAELoss: 40991.106 / 1e6
# Iter: 2, Validating ...
# ====================================================================================================
# Iter: 2,	Training-MAELoss: 38954.504 / 1e6 (epoch), 2506.435 / 1e6 (batch)
# 		 Validating-MAELoss: 41281.576 / 1e6 (song),  1577.640 / 1e6 (batch)
# 		Similarity: 0.046 Difference: 1046.07 (Time: 2.76, Frequency: 3163.96, Power: 3.20)
# ====================================================================================================
# Iter: 3, Epoch: 50/323, MAELoss: 31049.490 / 1e6
# Iter: 3, Epoch: 100/323, MAELoss: 41500.074 / 1e6
# Iter: 3, Epoch: 150/323, MAELoss: 41786.723 / 1e6
# Iter: 3, Epoch: 200/323, MAELoss: 34988.458 / 1e6
# Iter: 3, Epoch: 250/323, MAELoss: 39339.260 / 1e6
# Iter: 3, Epoch: 300/323, MAELoss: 34946.981 / 1e6
# Iter: 3, Validating ...
# ====================================================================================================
# Iter: 3,	Training-MAELoss: 36806.716 / 1e6 (epoch), 2367.177 / 1e6 (batch)
# 		 Validating-MAELoss: 41935.982 / 1e6 (song),  1602.649 / 1e6 (batch)
# 		Similarity: 0.046 Difference: 1049.86 (Time: 2.76, Frequency: 3175.51, Power: 3.11)
# ====================================================================================================
# Iter: 4, Epoch: 50/328, MAELoss: 31374.409 / 1e6
# Iter: 4, Epoch: 100/328, MAELoss: 42049.595 / 1e6
# Iter: 4, Epoch: 150/328, MAELoss: 37540.908 / 1e6
# Iter: 4, Epoch: 200/328, MAELoss: 36217.176 / 1e6
# Iter: 4, Epoch: 250/328, MAELoss: 35702.506 / 1e6
# Iter: 4, Epoch: 300/328, MAELoss: 32658.820 / 1e6
# Iter: 4, Validating ...
# ====================================================================================================
# Iter: 4,	Training-MAELoss: 36555.760 / 1e6 (epoch), 2350.013 / 1e6 (batch)
# 		 Validating-MAELoss: 40863.204 / 1e6 (song),  1561.651 / 1e6 (batch)
# 		Similarity: 0.038 Difference: 1048.05 (Time: 2.76, Frequency: 3169.90, Power: 3.25)
# ====================================================================================================
# Iter: 5, Epoch: 50/333, MAELoss: 34688.774 / 1e6
# Iter: 5, Epoch: 100/333, MAELoss: 33584.489 / 1e6
# Iter: 5, Epoch: 150/333, MAELoss: 39006.273 / 1e6
# Iter: 5, Epoch: 200/333, MAELoss: 44593.211 / 1e6
# Iter: 5, Epoch: 250/333, MAELoss: 53256.275 / 1e6
# Iter: 5, Epoch: 300/333, MAELoss: 42720.614 / 1e6
# Iter: 5, Validating ...
# ====================================================================================================
# Iter: 5,	Training-MAELoss: 41171.395 / 1e6 (epoch), 2646.733 / 1e6 (batch)
# 		 Validating-MAELoss: 36482.115 / 1e6 (song),  1394.221 / 1e6 (batch)
# 		Similarity: 0.048 Difference: 1053.82 (Time: 2.78, Frequency: 3187.72, Power: 2.89)
# ====================================================================================================
# Iter: 6, Epoch: 50/333, MAELoss: 32424.984 / 1e6
# Iter: 6, Epoch: 100/333, MAELoss: 44486.572 / 1e6
# Iter: 6, Epoch: 150/333, MAELoss: 41694.060 / 1e6
# Iter: 6, Epoch: 200/333, MAELoss: 37126.961 / 1e6
# Iter: 6, Epoch: 250/333, MAELoss: 41609.543 / 1e6
# Iter: 6, Epoch: 300/333, MAELoss: 34379.965 / 1e6
# Iter: 6, Validating ...
# ====================================================================================================
# Iter: 6,	Training-MAELoss: 37590.231 / 1e6 (epoch), 2409.056 / 1e6 (batch)
# 		 Validating-MAELoss: 41095.816 / 1e6 (song),  1570.541 / 1e6 (batch)
# 		Similarity: 0.032 Difference: 1051.33 (Time: 2.77, Frequency: 3179.87, Power: 3.22)
# ====================================================================================================
# Iter: 7, Epoch: 50/323, MAELoss: 34694.600 / 1e6
# Iter: 7, Epoch: 100/323, MAELoss: 33946.993 / 1e6
# Iter: 7, Epoch: 150/323, MAELoss: 41796.675 / 1e6
# Iter: 7, Epoch: 200/323, MAELoss: 47229.269 / 1e6
# Iter: 7, Epoch: 250/323, MAELoss: 36927.205 / 1e6
# Iter: 7, Epoch: 300/323, MAELoss: 41921.116 / 1e6
# Iter: 7, Validating ...
# ====================================================================================================
# Iter: 7,	Training-MAELoss: 39685.345 / 1e6 (epoch), 2553.929 / 1e6 (batch)
# 		 Validating-MAELoss: 44192.896 / 1e6 (song),  1688.900 / 1e6 (batch)
# 		Similarity: 0.043 Difference: 1043.53 (Time: 2.75, Frequency: 3155.75, Power: 3.70)
# ====================================================================================================
# Iter: 8, Epoch: 50/321, MAELoss: 45671.461 / 1e6
# Iter: 8, Epoch: 100/321, MAELoss: 53162.234 / 1e6
# Iter: 8, Epoch: 150/321, MAELoss: 37946.390 / 1e6
# Iter: 8, Epoch: 200/321, MAELoss: 35443.706 / 1e6
# Iter: 8, Epoch: 250/321, MAELoss: 36683.035 / 1e6
# Iter: 8, Epoch: 300/321, MAELoss: 30884.232 / 1e6
# Iter: 8, Validating ...
# ====================================================================================================
# Iter: 8,	Training-MAELoss: 40047.189 / 1e6 (epoch), 2575.584 / 1e6 (batch)
# 		 Validating-MAELoss: 39357.241 / 1e6 (song),  1504.098 / 1e6 (batch)
# 		Similarity: 0.061 Difference: 1042.96 (Time: 2.75, Frequency: 3154.18, Power: 3.55)
# ====================================================================================================
# Iter: 9, Epoch: 50/328, MAELoss: 45820.030 / 1e6
# Iter: 9, Epoch: 100/328, MAELoss: 39634.305 / 1e6
# Iter: 9, Epoch: 150/328, MAELoss: 37010.916 / 1e6
# Iter: 9, Epoch: 200/328, MAELoss: 38571.585 / 1e6
# Iter: 9, Epoch: 250/328, MAELoss: 30152.331 / 1e6
# Iter: 9, Epoch: 300/328, MAELoss: 33130.475 / 1e6
# Iter: 9, Validating ...
# ====================================================================================================
# Iter: 9,	Training-MAELoss: 37969.290 / 1e6 (epoch), 2441.946 / 1e6 (batch)
# 		 Validating-MAELoss: 36513.616 / 1e6 (song),  1395.425 / 1e6 (batch)
# 		Similarity: 0.059 Difference: 1051.79 (Time: 2.77, Frequency: 3181.36, Power: 3.10)
# ====================================================================================================
# Iter: 10, Epoch: 50/328, MAELoss: 50028.664 / 1e6
# Iter: 10, Epoch: 100/328, MAELoss: 40200.257 / 1e6
# Iter: 10, Epoch: 150/328, MAELoss: 31367.475 / 1e6
# Iter: 10, Epoch: 200/328, MAELoss: 40944.419 / 1e6
# Iter: 10, Epoch: 250/328, MAELoss: 38293.250 / 1e6
# Iter: 10, Epoch: 300/328, MAELoss: 42225.042 / 1e6
# Iter: 10, Validating ...
# ====================================================================================================
# Iter: 10,	Training-MAELoss: 42071.208 / 1e6 (epoch), 2705.756 / 1e6 (batch)
# 		 Validating-MAELoss: 31705.973 / 1e6 (song),  1211.693 / 1e6 (batch)
# 		Similarity: 0.094 Difference: 1048.46 (Time: 2.76, Frequency: 3171.79, Power: 2.59)
# ====================================================================================================
# Iter: 11, Epoch: 50/328, MAELoss: 33546.130 / 1e6
# Iter: 11, Epoch: 100/328, MAELoss: 27028.137 / 1e6
# Iter: 11, Epoch: 150/328, MAELoss: 39460.453 / 1e6
# Iter: 11, Epoch: 200/328, MAELoss: 37717.294 / 1e6
# Iter: 11, Epoch: 250/328, MAELoss: 37152.653 / 1e6
# Iter: 11, Epoch: 300/328, MAELoss: 43678.901 / 1e6
# Iter: 11, Validating ...
# ====================================================================================================
# Iter: 11,	Training-MAELoss: 37064.267 / 1e6 (epoch), 2387.061 / 1e6 (batch)
# 		 Validating-MAELoss: 35397.715 / 1e6 (song),  1352.779 / 1e6 (batch)
# 		Similarity: 0.061 Difference: 1042.30 (Time: 2.74, Frequency: 3152.78, Power: 2.96)
# ====================================================================================================
# Iter: 12, Epoch: 50/313, MAELoss: 35021.098 / 1e6
# Iter: 12, Epoch: 100/313, MAELoss: 34227.611 / 1e6
# Iter: 12, Epoch: 150/313, MAELoss: 35973.961 / 1e6
# Iter: 12, Epoch: 200/313, MAELoss: 42600.987 / 1e6
# Iter: 12, Epoch: 250/313, MAELoss: 40307.266 / 1e6
# Iter: 12, Epoch: 300/313, MAELoss: 34663.940 / 1e6
# Iter: 12, Validating ...
# ====================================================================================================
# Iter: 12,	Training-MAELoss: 37563.256 / 1e6 (epoch), 2415.833 / 1e6 (batch)
# 		 Validating-MAELoss: 33839.369 / 1e6 (song),  1293.224 / 1e6 (batch)
# 		Similarity: 0.046 Difference: 1046.94 (Time: 2.76, Frequency: 3166.98, Power: 2.82)
# ====================================================================================================
# Iter: 13, Epoch: 50/328, MAELoss: 32884.307 / 1e6
# Iter: 13, Epoch: 100/328, MAELoss: 36653.283 / 1e6
# Iter: 13, Epoch: 150/328, MAELoss: 32723.552 / 1e6
# Iter: 13, Epoch: 200/328, MAELoss: 34515.750 / 1e6
# Iter: 13, Epoch: 250/328, MAELoss: 28622.022 / 1e6
# Iter: 13, Epoch: 300/328, MAELoss: 32705.968 / 1e6
# Iter: 13, Validating ...
# ====================================================================================================
# Iter: 13,	Training-MAELoss: 36439.015 / 1e6 (epoch), 2342.508 / 1e6 (batch)
# 		 Validating-MAELoss: 42796.655 / 1e6 (song),  1635.541 / 1e6 (batch)
# 		Similarity: 0.039 Difference: 1038.02 (Time: 2.73, Frequency: 3139.29, Power: 3.48)
# ====================================================================================================
# Iter: 14, Epoch: 50/333, MAELoss: 34948.859 / 1e6
# Iter: 14, Epoch: 100/333, MAELoss: 37205.288 / 1e6
# Iter: 14, Epoch: 150/333, MAELoss: 31394.679 / 1e6
# Iter: 14, Epoch: 200/333, MAELoss: 41340.964 / 1e6
# Iter: 14, Epoch: 250/333, MAELoss: 45819.114 / 1e6
# Iter: 14, Epoch: 300/333, MAELoss: 37663.753 / 1e6
# Iter: 14, Validating ...
# ====================================================================================================
# Iter: 14,	Training-MAELoss: 37939.374 / 1e6 (epoch), 2440.022 / 1e6 (batch)
# 		 Validating-MAELoss: 36099.540 / 1e6 (song),  1379.600 / 1e6 (batch)
# 		Similarity: 0.068 Difference: 1056.97 (Time: 2.79, Frequency: 3197.26, Power: 2.90)
# ====================================================================================================
# Iter: 15, Epoch: 50/328, MAELoss: 35814.823 / 1e6
# Iter: 15, Epoch: 100/328, MAELoss: 45629.566 / 1e6
# Iter: 15, Epoch: 150/328, MAELoss: 33891.897 / 1e6
# Iter: 15, Epoch: 200/328, MAELoss: 26010.218 / 1e6
# Iter: 15, Epoch: 250/328, MAELoss: 37161.023 / 1e6
# Iter: 15, Epoch: 300/328, MAELoss: 41751.072 / 1e6
# Iter: 15, Validating ...
# ====================================================================================================
# Iter: 15,	Training-MAELoss: 37625.287 / 1e6 (epoch), 2421.355 / 1e6 (batch)
# 		 Validating-MAELoss: 38136.250 / 1e6 (song),  1457.436 / 1e6 (batch)
# 		Similarity: 0.059 Difference: 1046.46 (Time: 2.76, Frequency: 3164.99, Power: 3.34)
# ====================================================================================================
# Iter: 16, Epoch: 50/321, MAELoss: 39270.042 / 1e6
# Iter: 16, Epoch: 100/321, MAELoss: 42345.343 / 1e6
# Iter: 16, Epoch: 150/321, MAELoss: 35492.026 / 1e6
# Iter: 16, Epoch: 200/321, MAELoss: 34013.803 / 1e6
# Iter: 16, Epoch: 250/321, MAELoss: 40365.805 / 1e6
# Iter: 16, Epoch: 300/321, MAELoss: 27542.226 / 1e6
# Iter: 16, Validating ...
# ====================================================================================================
# Iter: 16,	Training-MAELoss: 36169.637 / 1e6 (epoch), 2326.204 / 1e6 (batch)
# 		 Validating-MAELoss: 30414.154 / 1e6 (song),  1162.324 / 1e6 (batch)
# 		Similarity: 0.097 Difference: 1042.99 (Time: 2.75, Frequency: 3155.07, Power: 2.77)
# ====================================================================================================
# Iter: 17, Epoch: 50/328, MAELoss: 27567.902 / 1e6
# Iter: 17, Epoch: 100/328, MAELoss: 33456.498 / 1e6
# Iter: 17, Epoch: 150/328, MAELoss: 43367.654 / 1e6
# Iter: 17, Epoch: 200/328, MAELoss: 31701.177 / 1e6
# Iter: 17, Epoch: 250/328, MAELoss: 41838.952 / 1e6
# Iter: 17, Epoch: 300/328, MAELoss: 37592.688 / 1e6
# Iter: 17, Validating ...
# ====================================================================================================
# Iter: 17,	Training-MAELoss: 37921.909 / 1e6 (epoch), 2439.334 / 1e6 (batch)
# 		 Validating-MAELoss: 39242.026 / 1e6 (song),  1499.695 / 1e6 (batch)
# 		Similarity: 0.056 Difference: 1043.67 (Time: 2.75, Frequency: 3156.57, Power: 3.32)
# ====================================================================================================
# Iter: 18, Epoch: 50/326, MAELoss: 45372.523 / 1e6
# Iter: 18, Epoch: 100/326, MAELoss: 31839.712 / 1e6
# Iter: 18, Epoch: 150/326, MAELoss: 39771.422 / 1e6
# Iter: 18, Epoch: 200/326, MAELoss: 33623.737 / 1e6
# Iter: 18, Epoch: 250/326, MAELoss: 39101.965 / 1e6
# Iter: 18, Epoch: 300/326, MAELoss: 32492.554 / 1e6
# Iter: 18, Validating ...
# ====================================================================================================
# Iter: 18,	Training-MAELoss: 37149.281 / 1e6 (epoch), 2390.282 / 1e6 (batch)
# 		 Validating-MAELoss: 34072.319 / 1e6 (song),  1302.127 / 1e6 (batch)
# 		Similarity: 0.061 Difference: 1042.26 (Time: 2.75, Frequency: 3152.82, Power: 2.80)
# ====================================================================================================
# Iter: 19, Epoch: 50/323, MAELoss: 42946.071 / 1e6
# Iter: 19, Epoch: 100/323, MAELoss: 34342.343 / 1e6
# Iter: 19, Epoch: 150/323, MAELoss: 40671.464 / 1e6
# Iter: 19, Epoch: 200/323, MAELoss: 33436.787 / 1e6
# Iter: 19, Epoch: 250/323, MAELoss: 28462.051 / 1e6
# Iter: 19, Epoch: 300/323, MAELoss: 31259.895 / 1e6
# Iter: 19, Validating ...
# ====================================================================================================
# Iter: 19,	Training-MAELoss: 35087.936 / 1e6 (epoch), 2257.038 / 1e6 (batch)
# 		 Validating-MAELoss: 32892.996 / 1e6 (song),  1257.057 / 1e6 (batch)
# 		Similarity: 0.097 Difference: 1051.20 (Time: 2.77, Frequency: 3179.71, Power: 2.97)
# ====================================================================================================
# Iter: 20, Epoch: 50/326, MAELoss: 37937.857 / 1e6
# Iter: 20, Epoch: 100/326, MAELoss: 28039.534 / 1e6
# Iter: 20, Epoch: 150/326, MAELoss: 40670.142 / 1e6
# Iter: 20, Epoch: 200/326, MAELoss: 40076.887 / 1e6
# Iter: 20, Epoch: 250/326, MAELoss: 40338.854 / 1e6
# Iter: 20, Epoch: 300/326, MAELoss: 29605.446 / 1e6
# Iter: 20, Validating ...
# ====================================================================================================
# Iter: 20,	Training-MAELoss: 35370.687 / 1e6 (epoch), 2263.555 / 1e6 (batch)
# 		 Validating-MAELoss: 32193.364 / 1e6 (song),  1230.320 / 1e6 (batch)
# 		Similarity: 0.098 Difference: 1045.44 (Time: 2.75, Frequency: 3162.42, Power: 2.81)
# ====================================================================================================
# Iter: 21, Epoch: 50/321, MAELoss: 37991.408 / 1e6
# Iter: 21, Epoch: 100/321, MAELoss: 35053.748 / 1e6
# Iter: 21, Epoch: 150/321, MAELoss: 29291.478 / 1e6
# Iter: 21, Epoch: 200/321, MAELoss: 33394.605 / 1e6
# Iter: 21, Epoch: 250/321, MAELoss: 34879.446 / 1e6
# Iter: 21, Epoch: 300/321, MAELoss: 31806.240 / 1e6
# Iter: 21, Validating ...
# ====================================================================================================
# Iter: 21,	Training-MAELoss: 34469.378 / 1e6 (epoch), 2216.854 / 1e6 (batch)
# 		 Validating-MAELoss: 34702.759 / 1e6 (song),  1326.220 / 1e6 (batch)
# 		Similarity: 0.072 Difference: 1053.38 (Time: 2.78, Frequency: 3186.31, Power: 2.98)
# ====================================================================================================
# Iter: 22, Epoch: 50/328, MAELoss: 31744.830 / 1e6
# Iter: 22, Epoch: 100/328, MAELoss: 37055.956 / 1e6
# Iter: 22, Epoch: 150/328, MAELoss: 32842.413 / 1e6
# Iter: 22, Epoch: 200/328, MAELoss: 36481.938 / 1e6
# Iter: 22, Epoch: 250/328, MAELoss: 39638.694 / 1e6
# Iter: 22, Epoch: 300/328, MAELoss: 34949.200 / 1e6
# Iter: 22, Validating ...
# ====================================================================================================
# Iter: 22,	Training-MAELoss: 35789.548 / 1e6 (epoch), 2302.794 / 1e6 (batch)
# 		 Validating-MAELoss: 29831.863 / 1e6 (song),  1140.071 / 1e6 (batch)
# 		Similarity: 0.088 Difference: 1048.32 (Time: 2.76, Frequency: 3171.11, Power: 2.86)
# ====================================================================================================
# Iter: 23, Epoch: 50/323, MAELoss: 40437.709 / 1e6
# Iter: 23, Epoch: 100/323, MAELoss: 31065.377 / 1e6
# Iter: 23, Epoch: 150/323, MAELoss: 37630.520 / 1e6
# Iter: 23, Epoch: 200/323, MAELoss: 36507.992 / 1e6
# Iter: 23, Epoch: 250/323, MAELoss: 33907.133 / 1e6
# Iter: 23, Epoch: 300/323, MAELoss: 34176.765 / 1e6
# Iter: 23, Validating ...
# ====================================================================================================
# Iter: 23,	Training-MAELoss: 36447.593 / 1e6 (epoch), 2346.667 / 1e6 (batch)
# 		 Validating-MAELoss: 34765.444 / 1e6 (song),  1328.616 / 1e6 (batch)
# 		Similarity: 0.057 Difference: 1047.53 (Time: 2.76, Frequency: 3168.70, Power: 2.88)
# ====================================================================================================
# Iter: 24, Epoch: 50/316, MAELoss: 29649.737 / 1e6
# Iter: 24, Epoch: 100/316, MAELoss: 36288.812 / 1e6
# Iter: 24, Epoch: 150/316, MAELoss: 36828.749 / 1e6
# Iter: 24, Epoch: 200/316, MAELoss: 33766.663 / 1e6
# Iter: 24, Epoch: 250/316, MAELoss: 33059.712 / 1e6
# Iter: 24, Epoch: 300/316, MAELoss: 39997.197 / 1e6
# Iter: 24, Validating ...
# ====================================================================================================
# Iter: 24,	Training-MAELoss: 34898.305 / 1e6 (epoch), 2243.462 / 1e6 (batch)
# 		 Validating-MAELoss: 32165.716 / 1e6 (song),  1229.263 / 1e6 (batch)
# 		Similarity: 0.074 Difference: 1049.46 (Time: 2.76, Frequency: 3174.70, Power: 2.71)
# ====================================================================================================
# Iter: 25, Epoch: 50/333, MAELoss: 39563.938 / 1e6
# Iter: 25, Epoch: 100/333, MAELoss: 31634.896 / 1e6
# Iter: 25, Epoch: 150/333, MAELoss: 37938.670 / 1e6
# Iter: 25, Epoch: 200/333, MAELoss: 31765.569 / 1e6
# Iter: 25, Epoch: 250/333, MAELoss: 34427.098 / 1e6
# Iter: 25, Epoch: 300/333, MAELoss: 31325.382 / 1e6
# Iter: 25, Validating ...
# ====================================================================================================
# Iter: 25,	Training-MAELoss: 34031.285 / 1e6 (epoch), 2180.129 / 1e6 (batch)
# 		 Validating-MAELoss: 29868.244 / 1e6 (song),  1141.462 / 1e6 (batch)
# 		Similarity: 0.091 Difference: 1054.21 (Time: 2.78, Frequency: 3189.13, Power: 2.67)
# ====================================================================================================
# Iter: 26, Epoch: 50/328, MAELoss: 30956.058 / 1e6
# Iter: 26, Epoch: 100/328, MAELoss: 32261.870 / 1e6
# Iter: 26, Epoch: 150/328, MAELoss: 28792.253 / 1e6
# Iter: 26, Epoch: 200/328, MAELoss: 37940.457 / 1e6
# Iter: 26, Epoch: 250/328, MAELoss: 38014.682 / 1e6
# Iter: 26, Epoch: 300/328, MAELoss: 40462.871 / 1e6
# Iter: 26, Validating ...
# ====================================================================================================
# Iter: 26,	Training-MAELoss: 34751.629 / 1e6 (epoch), 2235.007 / 1e6 (batch)
# 		 Validating-MAELoss: 29989.979 / 1e6 (song),  1146.114 / 1e6 (batch)
# 		Similarity: 0.109 Difference: 1054.21 (Time: 2.78, Frequency: 3188.92, Power: 2.88)
# ====================================================================================================
# Iter: 27, Epoch: 50/328, MAELoss: 38037.339 / 1e6
# Iter: 27, Epoch: 100/328, MAELoss: 31901.701 / 1e6
# Iter: 27, Epoch: 150/328, MAELoss: 36604.901 / 1e6
# Iter: 27, Epoch: 200/328, MAELoss: 31064.559 / 1e6
# Iter: 27, Epoch: 250/328, MAELoss: 37151.778 / 1e6
# Iter: 27, Epoch: 300/328, MAELoss: 30083.672 / 1e6
# Iter: 27, Validating ...
# ====================================================================================================
# Iter: 27,	Training-MAELoss: 34143.103 / 1e6 (epoch), 2197.261 / 1e6 (batch)
# 		 Validating-MAELoss: 33794.611 / 1e6 (song),  1291.514 / 1e6 (batch)
# 		Similarity: 0.091 Difference: 1053.21 (Time: 2.78, Frequency: 3185.77, Power: 3.00)
# ====================================================================================================
# Iter: 28, Epoch: 50/321, MAELoss: 33020.622 / 1e6
# Iter: 28, Epoch: 100/321, MAELoss: 25799.908 / 1e6
# Iter: 28, Epoch: 150/321, MAELoss: 33033.304 / 1e6
# Iter: 28, Epoch: 200/321, MAELoss: 44132.332 / 1e6
# Iter: 28, Epoch: 250/321, MAELoss: 39928.517 / 1e6
# Iter: 28, Epoch: 300/321, MAELoss: 29116.777 / 1e6
# Iter: 28, Validating ...
# ====================================================================================================
# Iter: 28,	Training-MAELoss: 33927.788 / 1e6 (epoch), 2181.072 / 1e6 (batch)
# 		 Validating-MAELoss: 37425.745 / 1e6 (song),  1430.283 / 1e6 (batch)
# 		Similarity: 0.095 Difference: 1043.96 (Time: 2.75, Frequency: 3156.57, Power: 4.19)
# ====================================================================================================
# Iter: 29, Epoch: 50/333, MAELoss: 31579.391 / 1e6
# Iter: 29, Epoch: 100/333, MAELoss: 32590.808 / 1e6
# Iter: 29, Epoch: 150/333, MAELoss: 40041.824 / 1e6
# Iter: 29, Epoch: 200/333, MAELoss: 33096.385 / 1e6
# Iter: 29, Epoch: 250/333, MAELoss: 32863.567 / 1e6
# Iter: 29, Epoch: 300/333, MAELoss: 33487.559 / 1e6
# Iter: 29, Validating ...
# ====================================================================================================
# Iter: 29,	Training-MAELoss: 33769.246 / 1e6 (epoch), 2170.880 / 1e6 (batch)
# 		 Validating-MAELoss: 31878.363 / 1e6 (song),  1218.281 / 1e6 (batch)
# 		Similarity: 0.080 Difference: 1035.35 (Time: 2.73, Frequency: 3131.84, Power: 2.86)
# ====================================================================================================
# Iter: 30, Epoch: 50/333, MAELoss: 33646.197 / 1e6
# Iter: 30, Epoch: 100/333, MAELoss: 33600.605 / 1e6
# Iter: 30, Epoch: 150/333, MAELoss: 21417.165 / 1e6
# Iter: 30, Epoch: 200/333, MAELoss: 26596.958 / 1e6
# Iter: 30, Epoch: 250/333, MAELoss: 53484.087 / 1e6
# Iter: 30, Epoch: 300/333, MAELoss: 40035.724 / 1e6
# Iter: 30, Validating ...
# ====================================================================================================
# Iter: 30,	Training-MAELoss: 34647.820 / 1e6 (epoch), 2229.741 / 1e6 (batch)
# 		 Validating-MAELoss: 27246.162 / 1e6 (song),  1041.255 / 1e6 (batch)
# 		Similarity: 0.107 Difference: 1047.47 (Time: 2.76, Frequency: 3168.71, Power: 2.67)
# ====================================================================================================
# Iter: 31, Epoch: 50/321, MAELoss: 40026.531 / 1e6
# Iter: 31, Epoch: 100/321, MAELoss: 42589.992 / 1e6
# Iter: 31, Epoch: 150/321, MAELoss: 31290.964 / 1e6
# Iter: 31, Epoch: 200/321, MAELoss: 43779.323 / 1e6
# Iter: 31, Epoch: 250/321, MAELoss: 29916.439 / 1e6
# Iter: 31, Epoch: 300/321, MAELoss: 39889.728 / 1e6
# Iter: 31, Validating ...
# ====================================================================================================
# Iter: 31,	Training-MAELoss: 37530.025 / 1e6 (epoch), 2414.126 / 1e6 (batch)
# 		 Validating-MAELoss: 29996.883 / 1e6 (song),  1146.378 / 1e6 (batch)
# 		Similarity: 0.112 Difference: 1050.45 (Time: 2.77, Frequency: 3177.71, Power: 2.70)
# ====================================================================================================
# Iter: 32, Epoch: 50/326, MAELoss: 31545.558 / 1e6
# Iter: 32, Epoch: 100/326, MAELoss: 44084.046 / 1e6
# Iter: 32, Epoch: 150/326, MAELoss: 36218.989 / 1e6
# Iter: 32, Epoch: 200/326, MAELoss: 33458.007 / 1e6
# Iter: 32, Epoch: 250/326, MAELoss: 27902.932 / 1e6
# Iter: 32, Epoch: 300/326, MAELoss: 41092.341 / 1e6
# Iter: 32, Validating ...
# ====================================================================================================
# Iter: 32,	Training-MAELoss: 35472.278 / 1e6 (epoch), 2281.354 / 1e6 (batch)
# 		 Validating-MAELoss: 31548.083 / 1e6 (song),  1205.659 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1044.55 (Time: 2.75, Frequency: 3159.91, Power: 2.63)
# ====================================================================================================
# Iter: 33, Epoch: 50/328, MAELoss: 39612.121 / 1e6
# Iter: 33, Epoch: 100/328, MAELoss: 38057.581 / 1e6
# Iter: 33, Epoch: 150/328, MAELoss: 40625.729 / 1e6
# Iter: 33, Epoch: 200/328, MAELoss: 31503.935 / 1e6
# Iter: 33, Epoch: 250/328, MAELoss: 35703.195 / 1e6
# Iter: 33, Epoch: 300/328, MAELoss: 29369.145 / 1e6
# Iter: 33, Validating ...
# ====================================================================================================
# Iter: 33,	Training-MAELoss: 34899.081 / 1e6 (epoch), 2236.942 / 1e6 (batch)
# 		 Validating-MAELoss: 27636.570 / 1e6 (song),  1056.175 / 1e6 (batch)
# 		Similarity: 0.121 Difference: 1041.27 (Time: 2.74, Frequency: 3149.91, Power: 2.72)
# ====================================================================================================
# Iter: 34, Epoch: 50/321, MAELoss: 31299.886 / 1e6
# Iter: 34, Epoch: 100/321, MAELoss: 39178.315 / 1e6
# Iter: 34, Epoch: 150/321, MAELoss: 28257.468 / 1e6
# Iter: 34, Epoch: 200/321, MAELoss: 32298.125 / 1e6
# Iter: 34, Epoch: 250/321, MAELoss: 34203.527 / 1e6
# Iter: 34, Epoch: 300/321, MAELoss: 44792.803 / 1e6
# Iter: 34, Validating ...
# ====================================================================================================
# Iter: 34,	Training-MAELoss: 35015.406 / 1e6 (epoch), 2253.397 / 1e6 (batch)
# 		 Validating-MAELoss: 43098.616 / 1e6 (song),  1647.081 / 1e6 (batch)
# 		Similarity: 0.039 Difference: 1058.66 (Time: 2.79, Frequency: 3202.00, Power: 3.27)
# ====================================================================================================
# Iter: 35, Epoch: 50/321, MAELoss: 32972.491 / 1e6
# Iter: 35, Epoch: 100/321, MAELoss: 26074.041 / 1e6
# Iter: 35, Epoch: 150/321, MAELoss: 33399.451 / 1e6
# Iter: 35, Epoch: 200/321, MAELoss: 28550.347 / 1e6
# Iter: 35, Epoch: 250/321, MAELoss: 36033.064 / 1e6
# Iter: 35, Epoch: 300/321, MAELoss: 45121.161 / 1e6
# Iter: 35, Validating ...
# ====================================================================================================
# Iter: 35,	Training-MAELoss: 33589.840 / 1e6 (epoch), 2160.288 / 1e6 (batch)
# 		 Validating-MAELoss: 30792.709 / 1e6 (song),  1176.791 / 1e6 (batch)
# 		Similarity: 0.096 Difference: 1043.86 (Time: 2.75, Frequency: 3157.70, Power: 2.76)
# ====================================================================================================
# Iter: 36, Epoch: 50/328, MAELoss: 27705.776 / 1e6
# Iter: 36, Epoch: 100/328, MAELoss: 33145.859 / 1e6
# Iter: 36, Epoch: 150/328, MAELoss: 33064.812 / 1e6
# Iter: 36, Epoch: 200/328, MAELoss: 31044.468 / 1e6
# Iter: 36, Epoch: 250/328, MAELoss: 38209.192 / 1e6
# Iter: 36, Epoch: 300/328, MAELoss: 33248.848 / 1e6
# Iter: 36, Validating ...
# ====================================================================================================
# Iter: 36,	Training-MAELoss: 31888.725 / 1e6 (epoch), 2042.871 / 1e6 (batch)
# 		 Validating-MAELoss: 30688.701 / 1e6 (song),  1172.817 / 1e6 (batch)
# 		Similarity: 0.075 Difference: 1048.88 (Time: 2.76, Frequency: 3172.93, Power: 2.73)
# ====================================================================================================
# Iter: 37, Epoch: 50/328, MAELoss: 39747.305 / 1e6
# Iter: 37, Epoch: 100/328, MAELoss: 37608.151 / 1e6
# Iter: 37, Epoch: 150/328, MAELoss: 28548.333 / 1e6
# Iter: 37, Epoch: 200/328, MAELoss: 30912.910 / 1e6
# Iter: 37, Epoch: 250/328, MAELoss: 22363.516 / 1e6
# Iter: 37, Epoch: 300/328, MAELoss: 29570.104 / 1e6
# Iter: 37, Validating ...
# ====================================================================================================
# Iter: 37,	Training-MAELoss: 32269.150 / 1e6 (epoch), 2075.349 / 1e6 (batch)
# 		 Validating-MAELoss: 27348.141 / 1e6 (song),  1045.152 / 1e6 (batch)
# 		Similarity: 0.128 Difference: 1047.09 (Time: 2.76, Frequency: 3167.43, Power: 2.80)
# ====================================================================================================
# Iter: 38, Epoch: 50/328, MAELoss: 30405.349 / 1e6
# Iter: 38, Epoch: 100/328, MAELoss: 28243.064 / 1e6
# Iter: 38, Epoch: 150/328, MAELoss: 36853.639 / 1e6
# Iter: 38, Epoch: 200/328, MAELoss: 23429.435 / 1e6
# Iter: 38, Epoch: 250/328, MAELoss: 42079.107 / 1e6
# Iter: 38, Epoch: 300/328, MAELoss: 32783.358 / 1e6
# Iter: 38, Validating ...
# ====================================================================================================
# Iter: 38,	Training-MAELoss: 33797.709 / 1e6 (epoch), 2173.657 / 1e6 (batch)
# 		 Validating-MAELoss: 35047.900 / 1e6 (song),  1339.410 / 1e6 (batch)
# 		Similarity: 0.087 Difference: 1042.83 (Time: 2.75, Frequency: 3154.30, Power: 3.05)
# ====================================================================================================
# Iter: 39, Epoch: 50/328, MAELoss: 36973.715 / 1e6
# Iter: 39, Epoch: 100/328, MAELoss: 34229.363 / 1e6
# Iter: 39, Epoch: 150/328, MAELoss: 33867.391 / 1e6
# Iter: 39, Epoch: 200/328, MAELoss: 25519.263 / 1e6
# Iter: 39, Epoch: 250/328, MAELoss: 26655.649 / 1e6
# Iter: 39, Epoch: 300/328, MAELoss: 33441.957 / 1e6
# Iter: 39, Validating ...
# ====================================================================================================
# Iter: 39,	Training-MAELoss: 32245.289 / 1e6 (epoch), 2072.911 / 1e6 (batch)
# 		 Validating-MAELoss: 26126.154 / 1e6 (song),  998.452 / 1e6 (batch)
# 		Similarity: 0.147 Difference: 1048.68 (Time: 2.76, Frequency: 3172.38, Power: 2.67)
# ====================================================================================================
# Iter: 40, Epoch: 50/333, MAELoss: 25857.433 / 1e6
# Iter: 40, Epoch: 100/333, MAELoss: 31140.794 / 1e6
# Iter: 40, Epoch: 150/333, MAELoss: 38296.951 / 1e6
# Iter: 40, Epoch: 200/333, MAELoss: 30537.155 / 1e6
# Iter: 40, Epoch: 250/333, MAELoss: 30294.336 / 1e6
# Iter: 40, Epoch: 300/333, MAELoss: 40372.317 / 1e6
# Iter: 40, Validating ...
# ====================================================================================================
# Iter: 40,	Training-MAELoss: 31910.650 / 1e6 (epoch), 2045.067 / 1e6 (batch)
# 		 Validating-MAELoss: 24167.411 / 1e6 (song),  923.595 / 1e6 (batch)
# 		Similarity: 0.145 Difference: 1048.50 (Time: 2.76, Frequency: 3171.79, Power: 2.71)
# ====================================================================================================
# Iter: 41, Epoch: 50/323, MAELoss: 22279.477 / 1e6
# Iter: 41, Epoch: 100/323, MAELoss: 21404.586 / 1e6
# Iter: 41, Epoch: 150/323, MAELoss: 40964.936 / 1e6
# Iter: 41, Epoch: 200/323, MAELoss: 33208.057 / 1e6
# Iter: 41, Epoch: 250/323, MAELoss: 41420.201 / 1e6
# Iter: 41, Epoch: 300/323, MAELoss: 36869.420 / 1e6
# Iter: 41, Validating ...
# ====================================================================================================
# Iter: 41,	Training-MAELoss: 32138.461 / 1e6 (epoch), 2057.487 / 1e6 (batch)
# 		 Validating-MAELoss: 25623.173 / 1e6 (song),  979.230 / 1e6 (batch)
# 		Similarity: 0.140 Difference: 1043.81 (Time: 2.75, Frequency: 3157.62, Power: 2.68)
# ====================================================================================================
# Iter: 42, Epoch: 50/316, MAELoss: 35091.048 / 1e6
# Iter: 42, Epoch: 100/316, MAELoss: 32865.747 / 1e6
# Iter: 42, Epoch: 150/316, MAELoss: 32538.360 / 1e6
# Iter: 42, Epoch: 200/316, MAELoss: 35059.956 / 1e6
# Iter: 42, Epoch: 250/316, MAELoss: 29693.014 / 1e6
# Iter: 42, Epoch: 300/316, MAELoss: 33548.639 / 1e6
# Iter: 42, Validating ...
# ====================================================================================================
# Iter: 42,	Training-MAELoss: 32417.564 / 1e6 (epoch), 2077.554 / 1e6 (batch)
# 		 Validating-MAELoss: 32341.238 / 1e6 (song),  1235.971 / 1e6 (batch)
# 		Similarity: 0.080 Difference: 1052.67 (Time: 2.78, Frequency: 3184.37, Power: 2.76)
# ====================================================================================================
# Iter: 43, Epoch: 50/323, MAELoss: 31640.906 / 1e6
# Iter: 43, Epoch: 100/323, MAELoss: 22946.650 / 1e6
# Iter: 43, Epoch: 150/323, MAELoss: 33281.301 / 1e6
# Iter: 43, Epoch: 200/323, MAELoss: 37811.665 / 1e6
# Iter: 43, Epoch: 250/323, MAELoss: 36657.808 / 1e6
# Iter: 43, Epoch: 300/323, MAELoss: 28840.863 / 1e6
# Iter: 43, Validating ...
# ====================================================================================================
# Iter: 43,	Training-MAELoss: 31384.612 / 1e6 (epoch), 2018.461 / 1e6 (batch)
# 		 Validating-MAELoss: 25976.693 / 1e6 (song),  992.740 / 1e6 (batch)
# 		Similarity: 0.121 Difference: 1049.83 (Time: 2.77, Frequency: 3175.84, Power: 2.69)
# ====================================================================================================
# Iter: 44, Epoch: 50/328, MAELoss: 29198.103 / 1e6
# Iter: 44, Epoch: 100/328, MAELoss: 36057.248 / 1e6
# Iter: 44, Epoch: 150/328, MAELoss: 32286.930 / 1e6
# Iter: 44, Epoch: 200/328, MAELoss: 22683.601 / 1e6
# Iter: 44, Epoch: 250/328, MAELoss: 40708.892 / 1e6
# Iter: 44, Epoch: 300/328, MAELoss: 27333.201 / 1e6
# Iter: 44, Validating ...
# ====================================================================================================
# Iter: 44,	Training-MAELoss: 31386.007 / 1e6 (epoch), 2018.910 / 1e6 (batch)
# 		 Validating-MAELoss: 25232.995 / 1e6 (song),  964.318 / 1e6 (batch)
# 		Similarity: 0.117 Difference: 1042.57 (Time: 2.75, Frequency: 3153.86, Power: 2.69)
# ====================================================================================================
# Iter: 45, Epoch: 50/326, MAELoss: 30320.921 / 1e6
# Iter: 45, Epoch: 100/326, MAELoss: 21270.752 / 1e6
# Iter: 45, Epoch: 150/326, MAELoss: 25829.708 / 1e6
# Iter: 45, Epoch: 200/326, MAELoss: 28173.945 / 1e6
# Iter: 45, Epoch: 250/326, MAELoss: 36928.757 / 1e6
# Iter: 45, Epoch: 300/326, MAELoss: 31000.219 / 1e6
# Iter: 45, Validating ...
# ====================================================================================================
# Iter: 45,	Training-MAELoss: 31168.131 / 1e6 (epoch), 2004.539 / 1e6 (batch)
# 		 Validating-MAELoss: 24298.765 / 1e6 (song),  928.615 / 1e6 (batch)
# 		Similarity: 0.122 Difference: 1050.24 (Time: 2.77, Frequency: 3176.99, Power: 2.78)
# ====================================================================================================
# Iter: 46, Epoch: 50/328, MAELoss: 24372.005 / 1e6
# Iter: 46, Epoch: 100/328, MAELoss: 28855.442 / 1e6
# Iter: 46, Epoch: 150/328, MAELoss: 26241.328 / 1e6
# Iter: 46, Epoch: 200/328, MAELoss: 38231.435 / 1e6
# Iter: 46, Epoch: 250/328, MAELoss: 36194.954 / 1e6
# Iter: 46, Epoch: 300/328, MAELoss: 26127.838 / 1e6
# Iter: 46, Validating ...
# ====================================================================================================
# Iter: 46,	Training-MAELoss: 30757.636 / 1e6 (epoch), 1978.490 / 1e6 (batch)
# 		 Validating-MAELoss: 26387.459 / 1e6 (song),  1008.438 / 1e6 (batch)
# 		Similarity: 0.132 Difference: 1048.69 (Time: 2.76, Frequency: 3172.32, Power: 2.78)
# ====================================================================================================
# Iter: 47, Epoch: 50/326, MAELoss: 31029.914 / 1e6
# Iter: 47, Epoch: 100/326, MAELoss: 31391.464 / 1e6
# Iter: 47, Epoch: 150/326, MAELoss: 27771.238 / 1e6
# Iter: 47, Epoch: 200/326, MAELoss: 40133.120 / 1e6
# Iter: 47, Epoch: 250/326, MAELoss: 24162.058 / 1e6
# Iter: 47, Epoch: 300/326, MAELoss: 30944.817 / 1e6
# Iter: 47, Validating ...
# ====================================================================================================
# Iter: 47,	Training-MAELoss: 30292.947 / 1e6 (epoch), 1947.404 / 1e6 (batch)
# 		 Validating-MAELoss: 25394.173 / 1e6 (song),  970.478 / 1e6 (batch)
# 		Similarity: 0.124 Difference: 1057.27 (Time: 2.79, Frequency: 3198.24, Power: 2.82)
# ====================================================================================================
# Iter: 48, Epoch: 50/333, MAELoss: 24710.170 / 1e6
# Iter: 48, Epoch: 100/333, MAELoss: 33470.499 / 1e6
# Iter: 48, Epoch: 150/333, MAELoss: 24299.931 / 1e6
# Iter: 48, Epoch: 200/333, MAELoss: 25696.285 / 1e6
# Iter: 48, Epoch: 250/333, MAELoss: 34280.720 / 1e6
# Iter: 48, Epoch: 300/333, MAELoss: 40532.555 / 1e6
# Iter: 48, Validating ...
# ====================================================================================================
# Iter: 48,	Training-MAELoss: 30977.552 / 1e6 (epoch), 1992.282 / 1e6 (batch)
# 		 Validating-MAELoss: 25901.997 / 1e6 (song),  989.885 / 1e6 (batch)
# 		Similarity: 0.109 Difference: 1044.69 (Time: 2.75, Frequency: 3160.19, Power: 2.78)
# ====================================================================================================
# Iter: 49, Epoch: 50/328, MAELoss: 34369.523 / 1e6
# Iter: 49, Epoch: 100/328, MAELoss: 32022.370 / 1e6
# Iter: 49, Epoch: 150/328, MAELoss: 25481.057 / 1e6
# Iter: 49, Epoch: 200/328, MAELoss: 30646.554 / 1e6
# Iter: 49, Epoch: 250/328, MAELoss: 26569.069 / 1e6
# Iter: 49, Epoch: 300/328, MAELoss: 37660.739 / 1e6
# Iter: 49, Validating ...
# ====================================================================================================
# Iter: 49,	Training-MAELoss: 31359.749 / 1e6 (epoch), 2019.281 / 1e6 (batch)
# 		 Validating-MAELoss: 25692.769 / 1e6 (song),  981.889 / 1e6 (batch)
# 		Similarity: 0.118 Difference: 1052.15 (Time: 2.77, Frequency: 3182.76, Power: 2.79)
# ====================================================================================================
# Iter: 50, Epoch: 50/315, MAELoss: 28774.133 / 1e6
# Iter: 50, Epoch: 100/315, MAELoss: 30999.519 / 1e6
# Iter: 50, Epoch: 150/315, MAELoss: 26237.577 / 1e6
# Iter: 50, Epoch: 200/315, MAELoss: 39659.902 / 1e6
# Iter: 50, Epoch: 250/315, MAELoss: 29235.033 / 1e6
# Iter: 50, Epoch: 300/315, MAELoss: 25706.863 / 1e6
# Iter: 50, Validating ...
# ====================================================================================================
# Iter: 50,	Training-MAELoss: 30883.734 / 1e6 (epoch), 1985.383 / 1e6 (batch)
# 		 Validating-MAELoss: 25669.141 / 1e6 (song),  980.986 / 1e6 (batch)
# 		Similarity: 0.143 Difference: 1044.11 (Time: 2.75, Frequency: 3158.46, Power: 2.76)
# ====================================================================================================
# Iter: 51, Epoch: 50/333, MAELoss: 50678.673 / 1e6
# Iter: 51, Epoch: 100/333, MAELoss: 30916.819 / 1e6
# Iter: 51, Epoch: 150/333, MAELoss: 22998.643 / 1e6
# Iter: 51, Epoch: 200/333, MAELoss: 25138.684 / 1e6
# Iter: 51, Epoch: 250/333, MAELoss: 29793.834 / 1e6
# Iter: 51, Epoch: 300/333, MAELoss: 26690.921 / 1e6
# Iter: 51, Validating ...
# ====================================================================================================
# Iter: 51,	Training-MAELoss: 31447.686 / 1e6 (epoch), 2023.427 / 1e6 (batch)
# 		 Validating-MAELoss: 23908.453 / 1e6 (song),  913.699 / 1e6 (batch)
# 		Similarity: 0.125 Difference: 1051.85 (Time: 2.77, Frequency: 3181.94, Power: 2.72)
# ====================================================================================================
# Iter: 52, Epoch: 50/323, MAELoss: 37506.214 / 1e6
# Iter: 52, Epoch: 100/323, MAELoss: 28834.934 / 1e6
# Iter: 52, Epoch: 150/323, MAELoss: 35978.502 / 1e6
# Iter: 52, Epoch: 200/323, MAELoss: 36720.074 / 1e6
# Iter: 52, Epoch: 250/323, MAELoss: 17058.819 / 1e6
# Iter: 52, Epoch: 300/323, MAELoss: 27527.297 / 1e6
# Iter: 52, Validating ...
# ====================================================================================================
# Iter: 52,	Training-MAELoss: 30536.413 / 1e6 (epoch), 1964.793 / 1e6 (batch)
# 		 Validating-MAELoss: 28104.686 / 1e6 (song),  1074.064 / 1e6 (batch)
# 		Similarity: 0.120 Difference: 1040.27 (Time: 2.74, Frequency: 3146.72, Power: 2.87)
# ====================================================================================================
# Iter: 53, Epoch: 50/323, MAELoss: 38012.519 / 1e6
# Iter: 53, Epoch: 100/323, MAELoss: 31748.804 / 1e6
# Iter: 53, Epoch: 150/323, MAELoss: 26926.917 / 1e6
# Iter: 53, Epoch: 200/323, MAELoss: 34749.006 / 1e6
# Iter: 53, Epoch: 250/323, MAELoss: 26131.405 / 1e6
# Iter: 53, Epoch: 300/323, MAELoss: 28825.278 / 1e6
# Iter: 53, Validating ...
# ====================================================================================================
# Iter: 53,	Training-MAELoss: 30557.019 / 1e6 (epoch), 1964.380 / 1e6 (batch)
# 		 Validating-MAELoss: 24089.377 / 1e6 (song),  920.613 / 1e6 (batch)
# 		Similarity: 0.094 Difference: 1047.91 (Time: 2.76, Frequency: 3169.92, Power: 2.80)
# ====================================================================================================
# Iter: 54, Epoch: 50/333, MAELoss: 23449.959 / 1e6
# Iter: 54, Epoch: 100/333, MAELoss: 19168.533 / 1e6
# Iter: 54, Epoch: 150/333, MAELoss: 33914.828 / 1e6
# Iter: 54, Epoch: 200/333, MAELoss: 40627.321 / 1e6
# Iter: 54, Epoch: 250/333, MAELoss: 30655.187 / 1e6
# Iter: 54, Epoch: 300/333, MAELoss: 35027.925 / 1e6
# Iter: 54, Validating ...
# ====================================================================================================
# Iter: 54,	Training-MAELoss: 30056.092 / 1e6 (epoch), 1915.219 / 1e6 (batch)
# 		 Validating-MAELoss: 24580.172 / 1e6 (song),  939.370 / 1e6 (batch)
# 		Similarity: 0.130 Difference: 1048.46 (Time: 2.76, Frequency: 3171.61, Power: 2.79)
# ====================================================================================================
# Iter: 55, Epoch: 50/313, MAELoss: 34645.369 / 1e6
# Iter: 55, Epoch: 100/313, MAELoss: 21165.368 / 1e6
# Iter: 55, Epoch: 150/313, MAELoss: 39684.050 / 1e6
# Iter: 55, Epoch: 200/313, MAELoss: 22243.399 / 1e6
# Iter: 55, Epoch: 250/313, MAELoss: 23964.690 / 1e6
# Iter: 55, Epoch: 300/313, MAELoss: 37454.884 / 1e6
# Iter: 55, Validating ...
# ====================================================================================================
# Iter: 55,	Training-MAELoss: 30393.282 / 1e6 (epoch), 1955.943 / 1e6 (batch)
# 		 Validating-MAELoss: 26749.293 / 1e6 (song),  1022.266 / 1e6 (batch)
# 		Similarity: 0.127 Difference: 1024.90 (Time: 2.70, Frequency: 3100.17, Power: 2.89)
# ====================================================================================================
# Iter: 56, Epoch: 50/321, MAELoss: 37197.539 / 1e6
# Iter: 56, Epoch: 100/321, MAELoss: 28974.082 / 1e6
# Iter: 56, Epoch: 150/321, MAELoss: 26114.020 / 1e6
# Iter: 56, Epoch: 200/321, MAELoss: 31302.460 / 1e6
# Iter: 56, Epoch: 250/321, MAELoss: 29673.089 / 1e6
# Iter: 56, Epoch: 300/321, MAELoss: 26663.261 / 1e6
# Iter: 56, Validating ...
# ====================================================================================================
# Iter: 56,	Training-MAELoss: 30395.933 / 1e6 (epoch), 1955.224 / 1e6 (batch)
# 		 Validating-MAELoss: 24200.945 / 1e6 (song),  924.877 / 1e6 (batch)
# 		Similarity: 0.117 Difference: 1048.52 (Time: 2.76, Frequency: 3171.79, Power: 2.78)
# ====================================================================================================
# Iter: 57, Epoch: 50/326, MAELoss: 26237.672 / 1e6
# Iter: 57, Epoch: 100/326, MAELoss: 32105.128 / 1e6
# Iter: 57, Epoch: 150/326, MAELoss: 30256.747 / 1e6
# Iter: 57, Epoch: 200/326, MAELoss: 28930.269 / 1e6
# Iter: 57, Epoch: 250/326, MAELoss: 33849.230 / 1e6
# Iter: 57, Epoch: 300/326, MAELoss: 24478.363 / 1e6
# Iter: 57, Validating ...
# ====================================================================================================
# Iter: 57,	Training-MAELoss: 29102.210 / 1e6 (epoch), 1870.856 / 1e6 (batch)
# 		 Validating-MAELoss: 26164.854 / 1e6 (song),  999.931 / 1e6 (batch)
# 		Similarity: 0.091 Difference: 1055.32 (Time: 2.78, Frequency: 3192.33, Power: 2.84)
# ====================================================================================================
# Iter: 58, Epoch: 50/333, MAELoss: 37274.782 / 1e6
# Iter: 58, Epoch: 100/333, MAELoss: 23119.946 / 1e6
# Iter: 58, Epoch: 150/333, MAELoss: 36103.551 / 1e6
# Iter: 58, Epoch: 200/333, MAELoss: 36128.237 / 1e6
# Iter: 58, Epoch: 250/333, MAELoss: 29025.606 / 1e6
# Iter: 58, Epoch: 300/333, MAELoss: 20977.328 / 1e6
# Iter: 58, Validating ...
# ====================================================================================================
# Iter: 58,	Training-MAELoss: 29991.807 / 1e6 (epoch), 1923.176 / 1e6 (batch)
# 		 Validating-MAELoss: 27344.301 / 1e6 (song),  1045.005 / 1e6 (batch)
# 		Similarity: 0.118 Difference: 1038.87 (Time: 2.74, Frequency: 3142.43, Power: 2.93)
# ====================================================================================================
# Iter: 59, Epoch: 50/316, MAELoss: 28624.558 / 1e6
# Iter: 59, Epoch: 100/316, MAELoss: 31380.343 / 1e6
# Iter: 59, Epoch: 150/316, MAELoss: 31359.018 / 1e6
# Iter: 59, Epoch: 200/316, MAELoss: 33763.835 / 1e6
# Iter: 59, Epoch: 250/316, MAELoss: 32932.336 / 1e6
# Iter: 59, Epoch: 300/316, MAELoss: 21540.581 / 1e6
# Iter: 59, Validating ...
# ====================================================================================================
# Iter: 59,	Training-MAELoss: 29781.282 / 1e6 (epoch), 1916.558 / 1e6 (batch)
# 		 Validating-MAELoss: 24746.141 / 1e6 (song),  945.712 / 1e6 (batch)
# 		Similarity: 0.121 Difference: 1053.61 (Time: 2.78, Frequency: 3187.20, Power: 2.79)
# ====================================================================================================
# Iter: 60, Epoch: 50/321, MAELoss: 32768.586 / 1e6
# Iter: 60, Epoch: 100/321, MAELoss: 35429.791 / 1e6
# Iter: 60, Epoch: 150/321, MAELoss: 31381.426 / 1e6
# Iter: 60, Epoch: 200/321, MAELoss: 26563.943 / 1e6
# Iter: 60, Epoch: 250/321, MAELoss: 35959.530 / 1e6
# Iter: 60, Epoch: 300/321, MAELoss: 20366.058 / 1e6
# Iter: 60, Validating ...
# ====================================================================================================
# Iter: 60,	Training-MAELoss: 29827.207 / 1e6 (epoch), 1912.779 / 1e6 (batch)
# 		 Validating-MAELoss: 26201.286 / 1e6 (song),  1001.323 / 1e6 (batch)
# 		Similarity: 0.129 Difference: 1050.33 (Time: 2.77, Frequency: 3177.23, Power: 2.82)
# ====================================================================================================
# Iter: 61, Epoch: 50/315, MAELoss: 22091.762 / 1e6
# Iter: 61, Epoch: 100/315, MAELoss: 18217.404 / 1e6
# Iter: 61, Epoch: 150/315, MAELoss: 21880.956 / 1e6
# Iter: 61, Epoch: 200/315, MAELoss: 36461.008 / 1e6
# Iter: 61, Epoch: 250/315, MAELoss: 27573.074 / 1e6
# Iter: 61, Epoch: 300/315, MAELoss: 43181.630 / 1e6
# Iter: 61, Validating ...
# ====================================================================================================
# Iter: 61,	Training-MAELoss: 30199.178 / 1e6 (epoch), 1943.996 / 1e6 (batch)
# 		 Validating-MAELoss: 25314.220 / 1e6 (song),  967.422 / 1e6 (batch)
# 		Similarity: 0.111 Difference: 1038.86 (Time: 2.74, Frequency: 3142.52, Power: 2.81)
# ====================================================================================================
# Iter: 62, Epoch: 50/318, MAELoss: 28251.643 / 1e6
# Iter: 62, Epoch: 100/318, MAELoss: 27668.303 / 1e6
# Iter: 62, Epoch: 150/318, MAELoss: 38533.049 / 1e6
# Iter: 62, Epoch: 200/318, MAELoss: 26870.300 / 1e6
# Iter: 62, Epoch: 250/318, MAELoss: 25620.760 / 1e6
# Iter: 62, Epoch: 300/318, MAELoss: 26889.288 / 1e6
# Iter: 62, Validating ...
# ====================================================================================================
# Iter: 62,	Training-MAELoss: 29660.593 / 1e6 (epoch), 1907.923 / 1e6 (batch)
# 		 Validating-MAELoss: 25877.879 / 1e6 (song),  988.964 / 1e6 (batch)
# 		Similarity: 0.114 Difference: 1039.63 (Time: 2.74, Frequency: 3144.75, Power: 2.90)
# ====================================================================================================
# Iter: 63, Epoch: 50/326, MAELoss: 35779.936 / 1e6
# Iter: 63, Epoch: 100/326, MAELoss: 27553.970 / 1e6
# Iter: 63, Epoch: 150/326, MAELoss: 22590.015 / 1e6
# Iter: 63, Epoch: 200/326, MAELoss: 30246.273 / 1e6
# Iter: 63, Epoch: 250/326, MAELoss: 35997.049 / 1e6
# Iter: 63, Epoch: 300/326, MAELoss: 25328.635 / 1e6
# Iter: 63, Validating ...
# ====================================================================================================
# ...
# Iter: 180, Epoch: 300/333, MAELoss: 20305.217 / 1e6
# Iter: 180, Validating ...
# ====================================================================================================
# Iter: 180,	Training-MAELoss: 23810.834 / 1e6 (epoch), 1531.363 / 1e6 (batch)
# 		 Validating-MAELoss: 25207.426 / 1e6 (song),  963.341 / 1e6 (batch)
# 		Similarity: 0.089 Difference: 1047.92 (Time: 2.76, Frequency: 3167.79, Power: 4.96)
# ====================================================================================================
# Iter: 181, Epoch: 50/328, MAELoss: 40794.057 / 1e6
# Iter: 181, Epoch: 100/328, MAELoss: 12562.211 / 1e6
# Iter: 181, Epoch: 150/328, MAELoss: 28018.549 / 1e6
# Iter: 181, Epoch: 200/328, MAELoss: 30487.955 / 1e6
# Iter: 181, Epoch: 250/328, MAELoss: 15531.911 / 1e6
# Iter: 181, Epoch: 300/328, MAELoss: 19992.123 / 1e6
# Iter: 181, Validating ...
# ====================================================================================================
# Iter: 181,	Training-MAELoss: 24341.329 / 1e6 (epoch), 1567.209 / 1e6 (batch)
# 		 Validating-MAELoss: 23494.756 / 1e6 (song),  897.889 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1050.65 (Time: 2.77, Frequency: 3176.31, Power: 4.70)
# ====================================================================================================
# Iter: 182, Epoch: 50/316, MAELoss: 21784.115 / 1e6
# Iter: 182, Epoch: 100/316, MAELoss: 23473.375 / 1e6
# Iter: 182, Epoch: 150/316, MAELoss: 18791.906 / 1e6
# Iter: 182, Epoch: 200/316, MAELoss: 20329.191 / 1e6
# Iter: 182, Epoch: 250/316, MAELoss: 22319.416 / 1e6
# Iter: 182, Epoch: 300/316, MAELoss: 35056.226 / 1e6
# Iter: 182, Validating ...
# ====================================================================================================
# Iter: 182,	Training-MAELoss: 24095.953 / 1e6 (epoch), 1549.700 / 1e6 (batch)
# 		 Validating-MAELoss: 49875.326 / 1e6 (song),  1906.063 / 1e6 (batch)
# 		Similarity: 0.047 Difference: 1021.11 (Time: 2.67, Frequency: 3066.12, Power: 25.47)
# ====================================================================================================
# Iter: 183, Epoch: 50/328, MAELoss: 24266.182 / 1e6
# Iter: 183, Epoch: 100/328, MAELoss: 43912.662 / 1e6
# Iter: 183, Epoch: 150/328, MAELoss: 30467.479 / 1e6
# Iter: 183, Epoch: 200/328, MAELoss: 21136.387 / 1e6
# Iter: 183, Epoch: 250/328, MAELoss: 12226.900 / 1e6
# Iter: 183, Epoch: 300/328, MAELoss: 15378.684 / 1e6
# Iter: 183, Validating ...
# ====================================================================================================
# Iter: 183,	Training-MAELoss: 24329.620 / 1e6 (epoch), 1566.455 / 1e6 (batch)
# 		 Validating-MAELoss: 24353.793 / 1e6 (song),  930.718 / 1e6 (batch)
# 		Similarity: 0.074 Difference: 1043.54 (Time: 2.75, Frequency: 3156.14, Power: 3.35)
# ====================================================================================================
# Iter: 184, Epoch: 50/316, MAELoss: 12605.842 / 1e6
# Iter: 184, Epoch: 100/316, MAELoss: 26207.779 / 1e6
# Iter: 184, Epoch: 150/316, MAELoss: 26493.694 / 1e6
# Iter: 184, Epoch: 200/316, MAELoss: 39586.898 / 1e6
# Iter: 184, Epoch: 250/316, MAELoss: 21253.102 / 1e6
# Iter: 184, Epoch: 300/316, MAELoss: 19536.315 / 1e6
# Iter: 184, Validating ...
# ====================================================================================================
# Iter: 184,	Training-MAELoss: 24023.491 / 1e6 (epoch), 1545.735 / 1e6 (batch)
# 		 Validating-MAELoss: 24438.118 / 1e6 (song),  933.941 / 1e6 (batch)
# 		Similarity: 0.071 Difference: 1050.36 (Time: 2.77, Frequency: 3175.20, Power: 4.94)
# ====================================================================================================
# Iter: 185, Epoch: 50/323, MAELoss: 23977.468 / 1e6
# Iter: 185, Epoch: 100/323, MAELoss: 18146.616 / 1e6
# Iter: 185, Epoch: 150/323, MAELoss: 16754.635 / 1e6
# Iter: 185, Epoch: 200/323, MAELoss: 23551.219 / 1e6
# Iter: 185, Epoch: 250/323, MAELoss: 22640.905 / 1e6
# Iter: 185, Epoch: 300/323, MAELoss: 34816.045 / 1e6
# Iter: 185, Validating ...
# ====================================================================================================
# Iter: 185,	Training-MAELoss: 24638.075 / 1e6 (epoch), 1585.279 / 1e6 (batch)
# 		 Validating-MAELoss: 24450.231 / 1e6 (song),  934.404 / 1e6 (batch)
# 		Similarity: 0.074 Difference: 1046.25 (Time: 2.76, Frequency: 3164.48, Power: 3.23)
# ====================================================================================================
# Iter: 186, Epoch: 50/323, MAELoss: 17740.417 / 1e6
# Iter: 186, Epoch: 100/323, MAELoss: 33016.147 / 1e6
# Iter: 186, Epoch: 150/323, MAELoss: 24656.697 / 1e6
# Iter: 186, Epoch: 200/323, MAELoss: 23277.472 / 1e6
# Iter: 186, Epoch: 250/323, MAELoss: 21335.457 / 1e6
# Iter: 186, Epoch: 300/323, MAELoss: 21735.780 / 1e6
# Iter: 186, Validating ...
# ====================================================================================================
# Iter: 186,	Training-MAELoss: 24079.635 / 1e6 (epoch), 1548.651 / 1e6 (batch)
# 		 Validating-MAELoss: 29638.665 / 1e6 (song),  1132.688 / 1e6 (batch)
# 		Similarity: 0.074 Difference: 1050.91 (Time: 2.77, Frequency: 3175.74, Power: 6.06)
# ====================================================================================================
# Iter: 187, Epoch: 50/328, MAELoss: 24637.602 / 1e6
# Iter: 187, Epoch: 100/328, MAELoss: 26261.632 / 1e6
# Iter: 187, Epoch: 150/328, MAELoss: 21765.628 / 1e6
# Iter: 187, Epoch: 200/328, MAELoss: 15075.961 / 1e6
# Iter: 187, Epoch: 250/328, MAELoss: 23414.427 / 1e6
# Iter: 187, Epoch: 300/328, MAELoss: 26952.648 / 1e6
# Iter: 187, Validating ...
# ====================================================================================================
# Iter: 187,	Training-MAELoss: 24367.387 / 1e6 (epoch), 1567.157 / 1e6 (batch)
# 		 Validating-MAELoss: 24754.367 / 1e6 (song),  946.027 / 1e6 (batch)
# 		Similarity: 0.084 Difference: 1045.65 (Time: 2.75, Frequency: 3160.99, Power: 4.89)
# ====================================================================================================
# Iter: 188, Epoch: 50/328, MAELoss: 25367.095 / 1e6
# Iter: 188, Epoch: 100/328, MAELoss: 26898.510 / 1e6
# Iter: 188, Epoch: 150/328, MAELoss: 21328.387 / 1e6
# Iter: 188, Epoch: 200/328, MAELoss: 33166.748 / 1e6
# Iter: 188, Epoch: 250/328, MAELoss: 19849.778 / 1e6
# Iter: 188, Epoch: 300/328, MAELoss: 17730.706 / 1e6
# Iter: 188, Validating ...
# ====================================================================================================
# Iter: 188,	Training-MAELoss: 23687.736 / 1e6 (epoch), 1522.783 / 1e6 (batch)
# 		 Validating-MAELoss: 33525.160 / 1e6 (song),  1281.216 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1032.53 (Time: 2.72, Frequency: 3115.19, Power: 10.98)
# ====================================================================================================
# Iter: 189, Epoch: 50/333, MAELoss: 29266.895 / 1e6
# Iter: 189, Epoch: 100/333, MAELoss: 25721.708 / 1e6
# Iter: 189, Epoch: 150/333, MAELoss: 24791.772 / 1e6
# Iter: 189, Epoch: 200/333, MAELoss: 23520.857 / 1e6
# Iter: 189, Epoch: 250/333, MAELoss: 27712.880 / 1e6
# Iter: 189, Epoch: 300/333, MAELoss: 16461.091 / 1e6
# Iter: 189, Validating ...
# ====================================================================================================
# Iter: 189,	Training-MAELoss: 24068.569 / 1e6 (epoch), 1540.857 / 1e6 (batch)
# 		 Validating-MAELoss: 29773.196 / 1e6 (song),  1137.829 / 1e6 (batch)
# 		Similarity: 0.086 Difference: 1029.54 (Time: 2.71, Frequency: 3110.72, Power: 6.39)
# ====================================================================================================
# Iter: 190, Epoch: 50/316, MAELoss: 12068.896 / 1e6
# Iter: 190, Epoch: 100/316, MAELoss: 25768.324 / 1e6
# Iter: 190, Epoch: 150/316, MAELoss: 27595.093 / 1e6
# Iter: 190, Epoch: 200/316, MAELoss: 31613.251 / 1e6
# Iter: 190, Epoch: 250/316, MAELoss: 30811.870 / 1e6
# Iter: 190, Epoch: 300/316, MAELoss: 20421.167 / 1e6
# Iter: 190, Validating ...
# ====================================================================================================
# Iter: 190,	Training-MAELoss: 24051.690 / 1e6 (epoch), 1542.276 / 1e6 (batch)
# 		 Validating-MAELoss: 32176.995 / 1e6 (song),  1229.694 / 1e6 (batch)
# 		Similarity: 0.062 Difference: 1061.58 (Time: 2.79, Frequency: 3207.45, Power: 6.67)
# ====================================================================================================
# Iter: 191, Epoch: 50/316, MAELoss: 20966.676 / 1e6
# Iter: 191, Epoch: 100/316, MAELoss: 18286.158 / 1e6
# Iter: 191, Epoch: 150/316, MAELoss: 19473.728 / 1e6
# Iter: 191, Epoch: 200/316, MAELoss: 29504.534 / 1e6
# Iter: 191, Epoch: 250/316, MAELoss: 30556.805 / 1e6
# Iter: 191, Epoch: 300/316, MAELoss: 22049.080 / 1e6
# Iter: 191, Validating ...
# ====================================================================================================
# Iter: 191,	Training-MAELoss: 24624.802 / 1e6 (epoch), 1584.425 / 1e6 (batch)
# 		 Validating-MAELoss: 24901.278 / 1e6 (song),  951.641 / 1e6 (batch)
# 		Similarity: 0.079 Difference: 1050.88 (Time: 2.77, Frequency: 3177.84, Power: 3.89)
# ====================================================================================================
# Iter: 192, Epoch: 50/323, MAELoss: 32724.990 / 1e6
# Iter: 192, Epoch: 100/323, MAELoss: 23232.979 / 1e6
# Iter: 192, Epoch: 150/323, MAELoss: 32796.961 / 1e6
# Iter: 192, Epoch: 200/323, MAELoss: 19281.377 / 1e6
# Iter: 192, Epoch: 250/323, MAELoss: 28978.892 / 1e6
# Iter: 192, Epoch: 300/323, MAELoss: 11673.255 / 1e6
# Iter: 192, Validating ...
# ====================================================================================================
# Iter: 192,	Training-MAELoss: 24022.266 / 1e6 (epoch), 1540.389 / 1e6 (batch)
# 		 Validating-MAELoss: 22485.443 / 1e6 (song),  859.316 / 1e6 (batch)
# 		Similarity: 0.070 Difference: 1047.43 (Time: 2.76, Frequency: 3167.32, Power: 3.94)
# ====================================================================================================
# Iter: 193, Epoch: 50/316, MAELoss: 19291.558 / 1e6
# Iter: 193, Epoch: 100/316, MAELoss: 24592.114 / 1e6
# Iter: 193, Epoch: 150/316, MAELoss: 27012.235 / 1e6
# Iter: 193, Epoch: 200/316, MAELoss: 23806.436 / 1e6
# Iter: 193, Epoch: 250/316, MAELoss: 16114.788 / 1e6
# Iter: 193, Epoch: 300/316, MAELoss: 34206.875 / 1e6
# Iter: 193, Validating ...
# ====================================================================================================
# Iter: 193,	Training-MAELoss: 23821.459 / 1e6 (epoch), 1532.047 / 1e6 (batch)
# 		 Validating-MAELoss: 29698.458 / 1e6 (song),  1134.973 / 1e6 (batch)
# 		Similarity: 0.053 Difference: 1050.70 (Time: 2.76, Frequency: 3173.47, Power: 7.70)
# ====================================================================================================
# Iter: 194, Epoch: 50/328, MAELoss: 19059.440 / 1e6
# Iter: 194, Epoch: 100/328, MAELoss: 31080.391 / 1e6
# Iter: 194, Epoch: 150/328, MAELoss: 27185.647 / 1e6
# Iter: 194, Epoch: 200/328, MAELoss: 18821.778 / 1e6
# Iter: 194, Epoch: 250/328, MAELoss: 31663.429 / 1e6
# Iter: 194, Epoch: 300/328, MAELoss: 20222.127 / 1e6
# Iter: 194, Validating ...
# ====================================================================================================
# Iter: 194,	Training-MAELoss: 24247.757 / 1e6 (epoch), 1560.596 / 1e6 (batch)
# 		 Validating-MAELoss: 21412.502 / 1e6 (song),  818.312 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1047.14 (Time: 2.76, Frequency: 3167.24, Power: 3.15)
# ====================================================================================================
# Iter: 195, Epoch: 50/320, MAELoss: 24570.776 / 1e6
# Iter: 195, Epoch: 100/320, MAELoss: 31084.056 / 1e6
# Iter: 195, Epoch: 150/320, MAELoss: 18262.272 / 1e6
# Iter: 195, Epoch: 200/320, MAELoss: 23344.499 / 1e6
# Iter: 195, Epoch: 250/320, MAELoss: 27772.005 / 1e6
# Iter: 195, Epoch: 300/320, MAELoss: 17994.522 / 1e6
# Iter: 195, Validating ...
# ====================================================================================================
# Iter: 195,	Training-MAELoss: 24243.405 / 1e6 (epoch), 1559.884 / 1e6 (batch)
# 		 Validating-MAELoss: 21459.176 / 1e6 (song),  820.096 / 1e6 (batch)
# 		Similarity: 0.062 Difference: 1047.08 (Time: 2.76, Frequency: 3167.06, Power: 3.15)
# ====================================================================================================
# Iter: 196, Epoch: 50/323, MAELoss: 26807.031 / 1e6
# Iter: 196, Epoch: 100/323, MAELoss: 21643.396 / 1e6
# Iter: 196, Epoch: 150/323, MAELoss: 24347.932 / 1e6
# Iter: 196, Epoch: 200/323, MAELoss: 20527.982 / 1e6
# Iter: 196, Epoch: 250/323, MAELoss: 23619.353 / 1e6
# Iter: 196, Epoch: 300/323, MAELoss: 19342.636 / 1e6
# Iter: 196, Validating ...
# ====================================================================================================
# Iter: 196,	Training-MAELoss: 24187.914 / 1e6 (epoch), 1554.937 / 1e6 (batch)
# 		 Validating-MAELoss: 42845.863 / 1e6 (song),  1637.422 / 1e6 (batch)
# 		Similarity: 0.066 Difference: 1066.39 (Time: 2.80, Frequency: 3213.12, Power: 15.57)
# ====================================================================================================
# Iter: 197, Epoch: 50/333, MAELoss: 26761.601 / 1e6
# Iter: 197, Epoch: 100/333, MAELoss: 35468.887 / 1e6
# Iter: 197, Epoch: 150/333, MAELoss: 17349.465 / 1e6
# Iter: 197, Epoch: 200/333, MAELoss: 20956.439 / 1e6
# Iter: 197, Epoch: 250/333, MAELoss: 20913.744 / 1e6
# Iter: 197, Epoch: 300/333, MAELoss: 19623.335 / 1e6
# Iter: 197, Validating ...
# ====================================================================================================
# Iter: 197,	Training-MAELoss: 24155.371 / 1e6 (epoch), 1553.522 / 1e6 (batch)
# 		 Validating-MAELoss: 25816.913 / 1e6 (song),  986.634 / 1e6 (batch)
# 		Similarity: 0.084 Difference: 1046.58 (Time: 2.76, Frequency: 3163.84, Power: 4.86)
# ====================================================================================================
# Iter: 198, Epoch: 50/328, MAELoss: 21453.123 / 1e6
# Iter: 198, Epoch: 100/328, MAELoss: 29400.739 / 1e6
# Iter: 198, Epoch: 150/328, MAELoss: 21931.531 / 1e6
# Iter: 198, Epoch: 200/328, MAELoss: 25104.797 / 1e6
# Iter: 198, Epoch: 250/328, MAELoss: 24488.045 / 1e6
# Iter: 198, Epoch: 300/328, MAELoss: 25151.119 / 1e6
# Iter: 198, Validating ...
# ====================================================================================================
# Iter: 198,	Training-MAELoss: 23687.688 / 1e6 (epoch), 1515.343 / 1e6 (batch)
# 		 Validating-MAELoss: 23070.022 / 1e6 (song),  881.657 / 1e6 (batch)
# 		Similarity: 0.079 Difference: 1042.01 (Time: 2.74, Frequency: 3151.23, Power: 3.64)
# ====================================================================================================
# Iter: 199, Epoch: 50/326, MAELoss: 26112.722 / 1e6
# Iter: 199, Epoch: 100/326, MAELoss: 17189.159 / 1e6
# Iter: 199, Epoch: 150/326, MAELoss: 18218.252 / 1e6
# Iter: 199, Epoch: 200/326, MAELoss: 24146.698 / 1e6
# Iter: 199, Epoch: 250/326, MAELoss: 24400.083 / 1e6
# Iter: 199, Epoch: 300/326, MAELoss: 25258.508 / 1e6
# Iter: 199, Validating ...
# ====================================================================================================
# Iter: 199,	Training-MAELoss: 24169.709 / 1e6 (epoch), 1553.767 / 1e6 (batch)
# 		 Validating-MAELoss: 28446.091 / 1e6 (song),  1087.112 / 1e6 (batch)
# 		Similarity: 0.077 Difference: 1050.24 (Time: 2.76, Frequency: 3173.75, Power: 6.04)
# ====================================================================================================
# Iter: 200, Epoch: 50/333, MAELoss: 22684.143 / 1e6
# Iter: 200, Epoch: 100/333, MAELoss: 25112.000 / 1e6
# Iter: 200, Epoch: 150/333, MAELoss: 25022.560 / 1e6
# Iter: 200, Epoch: 200/333, MAELoss: 16307.631 / 1e6
# Iter: 200, Epoch: 250/333, MAELoss: 23162.613 / 1e6
# Iter: 200, Epoch: 300/333, MAELoss: 30605.952 / 1e6
# Iter: 200, Validating ...
# ====================================================================================================
# Iter: 200,	Training-MAELoss: 23934.742 / 1e6 (epoch), 1539.332 / 1e6 (batch)
# 		 Validating-MAELoss: 27759.496 / 1e6 (song),  1060.872 / 1e6 (batch)
# 		Similarity: 0.070 Difference: 1055.30 (Time: 2.78, Frequency: 3188.84, Power: 6.26)
# ====================================================================================================

# %% [markdown]
# ## Save Stats

# %%
np.save(f'experiments/{trial_type}_MLP/stats.npy', stats)

# %% [markdown]
# # Results

# %% [markdown]
# # Load Stats to Dataframe

# %%
stats = list(np.load(f'experiments/{trial_type}_MLP/stats.npy', allow_pickle=True))
stats_df = pd.DataFrame(list(stats))
stats_df.to_excel(f'experiments/{trial_type}_MLP/stats.xlsx')
stats_df
# Out:
#      iteration trial_type loss_mode  train_loss  \
# 0            1      IMAGE       MAE    0.003889
# 1            2      IMAGE       MAE    0.002506
# 2            3      IMAGE       MAE    0.002367
# 3            4      IMAGE       MAE    0.002350
# 4            5      IMAGE       MAE    0.002647
# ..         ...        ...       ...         ...
# 195        196      IMAGE       MAE    0.001555
# 196        197      IMAGE       MAE    0.001554
# 197        198      IMAGE       MAE    0.001515
# 198        199      IMAGE       MAE    0.001554
# 199        200      IMAGE       MAE    0.001539
#
#                                         train_loss_raw  train_epoch  \
# 0    [0.2623947560787201, 0.32935869693756104, 0.31...          328
# 1    [0.03306101635098457, 0.03676531836390495, 0.0...          323
# 2    [0.036653030663728714, 0.025183560326695442, 0...          328
# 3    [0.03184261918067932, 0.030164547264575958, 0....          333
# 4    [0.03145034238696098, 0.02908259630203247, 0.0...          333
# ..                                                 ...          ...
# 195  [0.033768199384212494, 0.03215254470705986, 0....          333
# 196  [0.016004707664251328, 0.01870572194457054, 0....          328
# 197  [0.021098393946886063, 0.012480080127716064, 0...          326
# 198  [0.031110230833292007, 0.0290357805788517, 0.0...          333
# 199  [0.022100601345300674, 0.02679987996816635, 0....          328
#
#      train_batch                                     valid_loss_raw  \
# 0           5100  [0.04950182884931564, 0.041741907596588135, 0....
# 1           5020  [0.04141770303249359, 0.0346207395195961, 0.12...
# 2           5100  [0.03667116165161133, 0.036132510751485825, 0....
# 3           5180  [0.03485389053821564, 0.04287661239504814, 0.1...
# 4           5180  [0.027890942990779877, 0.029365023598074913, 0...
# ..           ...                                                ...
# 195         5180  [0.1303103268146515, 0.1068577766418457, 0.181...
# 196         5100  [0.021887119859457016, 0.05744059011340141, 0....
# 197         5096  [0.011138888075947762, 0.03588870167732239, 0....
# 198         5180  [0.023899264633655548, 0.03977476805448532, 0....
# 199         5100  [0.031515732407569885, 0.017991138622164726, 0...
#
#                                        valid_loss_data  valid_loss  ...  \
# 0    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001787  ...
# 1    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001578  ...
# 2    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001603  ...
# 3    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001562  ...
# 4    [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001394  ...
# ..                                                 ...         ...  ...
# 195  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001637  ...
# 196  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.000987  ...
# 197  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.000882  ...
# 198  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001087  ...
# 199  [[11, v1, 1], [01, v1, 1], [22, v1, 1], [22, v...    0.001061  ...
#
#                                        test_loss_micro  \
# 0    [0.001018248562738219, 0.000434778191896704, 0...
# 1    [0.0007231004901849207, 0.0003176060550421187,...
# 2    [0.0008513485930434065, 0.0003568307702563213,...
# 3    [0.0008685245627724237, 0.00034488578444545707...
# 4    [0.0008206014277286899, 0.00029568959754904754...
# ..                                                 ...
# 195  [0.0004926721415730613, 0.0002980457190846162,...
# 196  [0.0004922477429995901, 0.00014450797417322667...
# 197  [0.0004919544674110516, 0.00010511657241189364...
# 198  [0.0004922809081298762, 0.0001448442354725981,...
# 199  [0.0004914730176442135, 0.0001758491429535445,...
#
#                                        test_loss_macro  \
# 0    [0.052439800981018275, 0.04030393838882446, 0....
# 1    [0.03723967524452342, 0.029442081302404402, 0....
# 2    [0.04384445254173544, 0.03307821240276098, 0.1...
# 3    [0.04472901498277982, 0.03197091221809387, 0.1...
# 4    [0.04226097352802753, 0.027410425692796708, 0....
# ..                                                 ...
# 195  [0.02537261529101266, 0.027628838159143923, 0....
# 196  [0.025350758764478894, 0.013395889205858111, 0...
# 197  [0.025335655071669155, 0.00974430626258254, 0....
# 198  [0.025352466768688627, 0.013427060628309846, 0...
# 199  [0.025310860408676996, 0.016301215551793577, 0...
#
#                                    test_difference_raw  \
# 0    {0: [(0.3429066148010536, 219.46023347267445, ...
# 1    {0: [(0.3500057662204179, 224.0036903810676, 0...
# 2    {0: [(0.3343414200252222, 213.97850881614235, ...
# 3    {0: [(0.317219632716221, 203.0205649383816, 0....
# 4    {0: [(0.3399040822606433, 217.53861264681186, ...
# ..                                                 ...
# 195  {0: [(0.34127354822553013, 218.41507086433947,...
# 196  {0: [(0.338845272914442, 216.86097466524305, 0...
# 197  {0: [(0.3407716271398921, 218.0938413695311, 0...
# 198  {0: [(0.3405313273554262, 217.9400495074729, 0...
# 199  {0: [(0.33956182741483865, 217.3195695454969, ...
#
#                                        test_difference  \
# 0    [1424.2740534525967, 38.581196777138494, 12152...
# 1    [1404.9766631889975, 39.902352033488576, 11917...
# 2    [1404.6214650010388, 37.48366522988847, 11916....
# 3    [1397.80530081125, 37.39279593671939, 11849.84...
# 4    [1414.6092080401072, 36.36783134892322, 12040....
# ..                                                 ...
# 195  [1405.0504859011198, 40.071565117336206, 11915...
# 196  [1405.046129667867, 39.571621049316434, 11918....
# 197  [1404.8616194216545, 37.071874514699815, 11917...
# 198  [1404.3828450986334, 38.63971393912577, 11913....
# 199  [1405.2138582460136, 39.04348670514923, 11919....
#
#                                    test_similarity_raw  \
# 0    {0: [0.042236413806676865, 0.02235143445432186...
# 1    {0: [0.08786670118570328, 0.05253855884075165,...
# 2    {0: [0.06354960054159164, 0.034401535987854004...
# 3    {0: [0.06064753234386444, 0.026036487892270088...
# 4    {0: [0.047526996582746506, 0.03078824467957019...
# ..                                                 ...
# 195  {0: [0.051664799451828, 0.09387671947479248, 0...
# 196  {0: [0.06125881150364876, 0.11360669881105423,...
# 197  {0: [0.057020124047994614, 0.10135192424058914...
# 198  {0: [0.06009801849722862, 0.10117563605308533,...
# 199  {0: [0.04679661989212036, 0.0880550742149353, ...
#
#                                        test_similarity  train_loss_epoch  \
# 0    [0.03852671786314911, 0.01414993651676923, 0.0...          0.060465
# 1    [0.07909473774747716, 0.0314110854268074, 0.02...          0.038955
# 2    [0.04400372641781966, 0.02406906273216009, 0.0...          0.036807
# 3    [0.03738178985917734, 0.021420519221574067, 0....          0.036556
# 4    [0.03480880892214676, 0.03241453034803271, 0.0...          0.041171
# ..                                                 ...               ...
# 195  [0.058447226235229105, 0.1696369664440863, 0.0...          0.024188
# 196  [0.065987216681242, 0.21865209817886352, 0.005...          0.024155
# 197  [0.06257169879972935, 0.21389731138944626, 0.0...          0.023688
# 198  [0.06552401723133193, 0.20987920984625816, 0.0...          0.024170
# 199  [0.04972797108348459, 0.1873475681245327, 0.00...          0.023935
#
#      train_loss_batch                               valid_similarity_raw  \
# 0            0.003889  [0.021533075720071793, 0.04411483556032181, 0....
# 1            0.002506  [0.042202673852443695, 0.055035244673490524, 0...
# 2            0.002367  [0.025023428723216057, 0.06642603129148483, 0....
# 3            0.002350  [0.030964242294430733, 0.04735634848475456, 0....
# 4            0.002647  [0.0314190536737442, 0.0675109252333641, 0.050...
# ..                ...                                                ...
# 195          0.001555  [0.05934683978557587, 0.028717176988720894, 0....
# 196          0.001554  [0.11285329610109329, 0.04769580811262131, 0.0...
# 197          0.001515  [0.10745637863874435, 0.07381130754947662, 0.0...
# 198          0.001554  [0.06848958134651184, 0.066456638276577, 0.002...
# 199          0.001539  [0.12420631945133209, 0.10820117592811584, 0.0...
#
#                                   valid_difference_raw
# 0    [[0.208347731015964, 213.34807656034704, 6.366...
# 1    [[0.2101583709081655, 215.20217180996147, 4.88...
# 2    [[0.2434816271421047, 249.32518619351515, 2.16...
# 3    [[0.21247673119527735, 217.57617274396392, 1.4...
# 4    [[0.23274096304250394, 238.326746155524, 0.736...
# ..                                                 ...
# 195  [[0.5213658336417517, 533.8786136491539, 99.70...
# 196  [[0.1794826069314245, 183.7901894977786, 5.451...
# 197  [[0.22794210685899968, 233.41271742361562, 0.2...
# 198  [[0.276383954660213, 283.01716957205804, 4.422...
# 199  [[0.165172603122197, 169.13674559712965, 13.46...
#
# [200 rows x 34 columns]

# %% [markdown]
# ## Training - Validating Plots

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot')
line_train = ax.plot(range(1, num_iteration + 1), stats_df['train_loss'], color='tab:blue')
line_valid = ax.plot(range(1, num_iteration + 1), stats_df['valid_loss'], color='tab:orange')
line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

# ax2 = ax.twinx()
# line_valid_macro = ax2.plot(range(1, num_iteration + 1), stats_df['valid_loss_macro'], color='tab:green', alpha=.7)

ax.legend(line_train + line_valid + [line_best], ['Train', 'Valid', 'best'])

# ax.set_ylim(stats_df['train_loss'].min() * .2, stats_df['train_loss'].max() * .6)
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.subplots()
ax1.set_title('MAE vs Structural Similarity Plot')
line_train = ax1.plot(range(1, num_iteration + 1), stats_df['train_loss_raw'].apply(lambda x: np.sum(x))/stats_df['train_batch'], color='tab:blue')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
line_valid = ax2.plot(range(1, num_iteration + 1), stats_df['valid_similarity'], color='tab:orange')
line_best = ax2.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')

ax1.legend(line_train + line_valid + [line_best], ['Train (MAE)', 'Valid (SSIM)', 'Best (SSIM)'])
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Mean Absolute Error', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2.set_ylabel('Structural Similarity', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')
# line_best = ax.vlines(stats_df['best_sim'], ymin=0, ymax=stats_df['best_sim'], colors='tab:green', linewidth=0.3, linestyles='--')

ax1.set_xticks(range(0, num_iteration + 1, 10))
plt.show()

# %% [markdown]
# ## Testing Plots

# %% [markdown]
# ### Known / Unknown / New Subjects

# %%
stat_to_plot = np.stack(stats_df['test_loss_micro'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot - Known vs Unknown vs New-Subject')
line_known = ax.plot(range(1, num_iteration + 1), stats_df['valid_loss'], color='tab:blue')
line_unknown = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_MUSIC], color='tab:orange')
line_newsub = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_SUB], color='tab:green', alpha=.7)
line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_known + line_newsub + line_unknown + [line_best], ['Known-Songs (Valid)', 'New-Subject', 'Unknown-Songs', 'Best'])
plt.show()

# %%
stat_to_plot = np.stack(stats_df['test_similarity'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Structural Similarity Plot - Known vs Unknown vs New-Subject')
line_known = ax.plot(range(1, num_iteration + 1), stats_df['valid_similarity'], color='tab:blue')
line_unknown = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_MUSIC], color='tab:orange')
line_newsub = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_NEW_SUB], color='tab:green')
line_best = ax.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Structural Similarity')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_unknown + line_known + line_newsub + [line_best], ['Unknown-Songs', 'Known-Songs (Valid)', 'New-Subject', 'Best'])
plt.show()

# %% [markdown]
# ### By Instruments

# %%
stat_to_plot = np.stack(stats_df['test_loss_macro'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Mean Absolute Error Plot - By Instruments')
line_celesta = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_CELESTA], color='tab:blue')
line_trombone = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_TROMBONE], color='tab:orange')
line_violin = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_VIOLIN], color='tab:green', alpha=.7)
# line_best = ax.vlines(stats_df['best_iteration'], ymin=0, ymax=stats_df['best_loss'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Mean Absolute Error')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_celesta + line_trombone + line_violin, ['Celesta', 'Trombone', 'Violin'])
plt.show()

# %%
stat_to_plot = np.stack(stats_df['test_similarity'].to_numpy())

fig = plt.figure(figsize=(12, 6))
ax = fig.subplots()
ax.set_title('Structural Similarity Plot - By Instruments')
line_celesta = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_CELESTA], color='tab:blue')
line_trombone = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_TROMBONE], color='tab:orange')
line_violin = ax.plot(range(1, num_iteration + 1), stat_to_plot[:, ID_TEST_INSTRUMENT_VIOLIN], color='tab:green', alpha=.7)
line_best = ax.vlines(stats_df['best_sim_iteration'], ymin=0, ymax=stats_df['best_sim'], colors='tab:red', linewidth=0.3, linestyles='--')
ax.set_xlabel('Iteration')
ax.set_ylabel('Structural Similarity')
ax.set_xticks(range(0, num_iteration + 1, 10))

ax.legend(line_celesta + line_trombone + line_violin + [line_best], ['Celesta', 'Trombone', 'Violin', 'Best'])
plt.show()

# %% [markdown]
# ## Recovered Music

# %%
def predict_sample():
    sample_event_idx = events_iter(batch_size=batch_size, filter_trial_type=filter_trial_type, filter_subject_ids=sub_ids, shuffle=True)[0][0]
    eeg_start, eeg_stop, mid, _, version, _ = data_events_info[sample_event_idx]
    sample_music = musics[version][mid]
    
    eeg_indices = [
        np.arange(eeg_start, eeg_stop, window_length),  # EEG-start
        np.concatenate([np.arange(eeg_start + window_length, eeg_stop, window_length), [eeg_stop]]) # EEG-stop
    ]
    batch_input = []
    for sample_start, sample_stop in zip(*eeg_indices):
        batch_input.append(padding(data_eeg_raw[:, sample_start:sample_stop], window_length=window_length, axis=1))
    batch_input = net.transform_input(np.stack(batch_input))
    cutoff = eeg_indices[0].shape[0] * music_window_length
    sample_wav = padding(sample_music['wav-low'][:cutoff], cutoff)
    with th.no_grad():
        outputs = net(th.Tensor(batch_input).to(device))
        if net_has_state:
            outputs, states = outputs
        predict_wav = outputs.flatten().cpu().numpy()
    
    fig = plt.figure(figsize=(6, 9))
    axes = fig.subplots(nrows=3)

    axes[0].plot(sample_wav, color='tab:blue')
    axes[0].plot(predict_wav, color='tab:orange')
    axes[0].set_title('Music wave')
    axes[0].set_xticks([])

    org_D = librosa.amplitude_to_db(np.abs(librosa.stft(sample_wav, n_fft=64)), ref=np.max)
    pred_D = librosa.amplitude_to_db(np.abs(librosa.stft(predict_wav, n_fft=64)), ref=np.max)
    librosa.display.specshow(org_D, y_axis='linear', ax=axes[1])
    librosa.display.specshow(pred_D, y_axis='linear',  ax=axes[2])
    axes[1].set(title='Original - Spectrogram')
    axes[2].set(title='Predict - Spectrogram')
    plt.show()
    
    return sample_wav, predict_wav

# %% [markdown]
# ### By Best Similarity Model

# %%
net.load_state_dict(th.load(f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-sim-iter-{best_sim_iter:03d}.pt'))
# Out:
# <All keys matched successfully>

# %%
predict_sample();

# %%
predict_sample();

# %% [markdown]
# ### By Best Loss Model

# %%
net.load_state_dict(th.load(f'experiments/{trial_type}_MLP/mlp-{2**10}-{2**8}-best-loss-iter-{best_iter:03d}.pt'))
# Out:
# <All keys matched successfully>

# %%
predict_sample();

# %%
predict_sample();
